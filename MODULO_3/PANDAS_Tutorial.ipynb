# %% [markdown]
# UNIDAD 1. DESCARGAR BASES DE DATOS E INFORMACION BASICA DE LA BASE DE DATOS

# %%
import pandas as pd

# %%
df=pd.read_excel('Advertising.xlsx', index_col=0)
df
# Out:
#         TV  Radio  Newspaper  Sales
# ID
# 1    230.1   37.8       69.2   22.1
# 2     44.5   39.3       45.1   10.4
# 3     17.2   45.9       69.3    9.3
# 4    151.5   41.3       58.5   18.5
# 5    180.8   10.8       58.4   12.9
# ..     ...    ...        ...    ...
# 196   38.2    3.7       13.8    7.6
# 197   94.2    4.9        8.1    9.7
# 198  177.0    9.3        6.4   12.8
# 199  283.6   42.0       66.2   25.5
# 200  232.1    8.6        8.7   13.4
#
# [200 rows x 4 columns]

# %% [markdown]
# shift + ENTER
#
# Descargamos base de datos en csv

# %%
df= pd.read_csv('ds_salaries.csv')

df
# Out:
#       work_year experience_level employment_type                 job_title  \
# 0          2023               SE              FT  Principal Data Scientist
# 1          2023               MI              CT               ML Engineer
# 2          2023               MI              CT               ML Engineer
# 3          2023               SE              FT            Data Scientist
# 4          2023               SE              FT            Data Scientist
# ...         ...              ...             ...                       ...
# 3750       2020               SE              FT            Data Scientist
# 3751       2021               MI              FT  Principal Data Scientist
# 3752       2020               EN              FT            Data Scientist
# 3753       2020               EN              CT     Business Data Analyst
# 3754       2021               SE              FT      Data Science Manager
#
#        salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0       80000             EUR          85847                 ES           100
# 1       30000             USD          30000                 US           100
# 2       25500             USD          25500                 US           100
# 3      175000             USD         175000                 CA           100
# 4      120000             USD         120000                 CA           100
# ...       ...             ...            ...                ...           ...
# 3750   412000             USD         412000                 US           100
# 3751   151000             USD         151000                 US           100
# 3752   105000             USD         105000                 US           100
# 3753   100000             USD         100000                 US           100
# 3754  7000000             INR          94665                 IN            50
#
#      company_location company_size
# 0                  ES            L
# 1                  US            S
# 2                  US            S
# 3                  CA            M
# 4                  CA            M
# ...               ...          ...
# 3750               US            L
# 3751               US            L
# 3752               US            S
# 3753               US            L
# 3754               IN            L
#
# [3755 rows x 11 columns]

# %% [markdown]
# Para ver el numero de filas y columnas

# %%
df.shape
# Out:
# (3755, 11)

# %%
#para poder ver toda toda toda la DF usamos
print(df.to_string())
# Out:
#       work_year experience_level employment_type                                 job_title    salary salary_currency  salary_in_usd employee_residence  remote_ratio company_location company_size
# 0          2023               SE              FT                  Principal Data Scientist     80000             EUR          85847                 ES           100               ES            L
# 1          2023               MI              CT                               ML Engineer     30000             USD          30000                 US           100               US            S
# 2          2023               MI              CT                               ML Engineer     25500             USD          25500                 US           100               US            S
# 3          2023               SE              FT                            Data Scientist    175000             USD         175000                 CA           100               CA            M
# 4          2023               SE              FT                            Data Scientist    120000             USD         120000                 CA           100               CA            M
# 5          2023               SE              FT                         Applied Scientist    222200             USD         222200                 US             0               US            L
# 6          2023               SE              FT                         Applied Scientist    136000             USD         136000                 US             0               US            L
# 7          2023               SE              FT                            Data Scientist    219000             USD         219000                 CA             0               CA            M
# 8          2023               SE              FT                            Data Scientist    141000             USD         141000                 CA             0               CA            M
# 9          2023               SE              FT                            Data Scientist    147100             USD         147100                 US             0               US            M
# 10         2023               SE              FT                            Data Scientist     90700             USD          90700                 US             0               US            M
# 11         2023               SE              FT                              Data Analyst    130000             USD         130000                 US           100               US            M
# 12         2023               SE              FT                              Data Analyst    100000             USD         100000                 US           100               US            M
# 13         2023               EN              FT                         Applied Scientist    213660             USD         213660                 US             0               US            L
# 14         2023               EN              FT                         Applied Scientist    130760             USD         130760                 US             0               US            L
# 15         2023               SE              FT                              Data Modeler    147100             USD         147100                 US             0               US            M
# 16         2023               SE              FT                              Data Modeler     90700             USD          90700                 US             0               US            M
# 17         2023               SE              FT                            Data Scientist    170000             USD         170000                 US             0               US            M
# 18         2023               SE              FT                            Data Scientist    150000             USD         150000                 US             0               US            M
# 19         2023               MI              FT                              Data Analyst    150000             USD         150000                 US           100               US            M
# 20         2023               MI              FT                              Data Analyst    110000             USD         110000                 US           100               US            M
# 21         2023               SE              FT                         Research Engineer    275000             USD         275000                 DE             0               DE            M
# 22         2023               SE              FT                         Research Engineer    174000             USD         174000                 DE             0               DE            M
# 23         2023               SE              FT                        Analytics Engineer    230000             USD         230000                 GB           100               GB            M
# 24         2023               SE              FT                        Analytics Engineer    143200             USD         143200                 GB           100               GB            M
# 25         2023               SE              FT            Business Intelligence Engineer    225000             USD         225000                 US             0               US            M
# 26         2023               SE              FT            Business Intelligence Engineer    156400             USD         156400                 US             0               US            M
# 27         2023               SE              FT                 Machine Learning Engineer    200000             USD         200000                 US             0               US            M
# 28         2023               SE              FT                 Machine Learning Engineer    130000             USD         130000                 US             0               US            M
# 29         2023               SE              FT                           Data Strategist     90000             USD          90000                 CA             0               CA            M
# 30         2023               SE              FT                           Data Strategist     72000             USD          72000                 CA             0               CA            M
# 31         2023               SE              FT                             Data Engineer    253200             USD         253200                 US             0               US            M
# 32         2023               SE              FT                             Data Engineer     90700             USD          90700                 US             0               US            M
# 33         2023               SE              FT                  Computer Vision Engineer    342810             USD         342810                 US             0               US            M
# 34         2023               SE              FT                  Computer Vision Engineer    184590             USD         184590                 US             0               US            M
# 35         2023               MI              FT                             Data Engineer    162500             USD         162500                 US             0               US            M
# 36         2023               MI              FT                             Data Engineer    130000             USD         130000                 US             0               US            M
# 37         2023               MI              FT                              Data Analyst    105380             USD         105380                 US             0               US            M
# 38         2023               MI              FT                              Data Analyst     64500             USD          64500                 US             0               US            M
# 39         2023               EN              FT                      Data Quality Analyst    100000             USD         100000                 NG           100               NG            L
# 40         2023               EN              FT                   Compliance Data Analyst     30000             USD          30000                 NG           100               NG            L
# 41         2022               MI              FT                 Machine Learning Engineer   1650000             INR          20984                 IN            50               IN            L
# 42         2023               EN              FT                         Applied Scientist    204620             USD         204620                 US             0               US            L
# 43         2023               EN              FT                         Applied Scientist    110680             USD         110680                 US             0               US            L
# 44         2023               SE              FT                             Data Engineer    270703             USD         270703                 US             0               US            M
# 45         2023               SE              FT                             Data Engineer    221484             USD         221484                 US             0               US            M
# 46         2023               SE              FT                            Data Scientist    212750             USD         212750                 US           100               US            M
# 47         2023               SE              FT                            Data Scientist    185000             USD         185000                 US           100               US            M
# 48         2023               SE              FT                            Data Scientist    262000             USD         262000                 US           100               US            M
# 49         2023               SE              FT                            Data Scientist    245000             USD         245000                 US           100               US            M
# 50         2023               SE              FT                            Data Scientist    275300             USD         275300                 US           100               US            M
# 51         2023               SE              FT                            Data Scientist    183500             USD         183500                 US           100               US            M
# 52         2023               SE              FT                            Data Scientist    218500             USD         218500                 US           100               US            M
# 53         2023               SE              FT                            Data Scientist    199098             USD         199098                 US           100               US            M
# 54         2023               SE              FT                             Data Engineer    203300             USD         203300                 US           100               US            M
# 55         2023               SE              FT                             Data Engineer    123600             USD         123600                 US           100               US            M
# 56         2023               SE              FT                         Research Engineer    189110             USD         189110                 US             0               US            M
# 57         2023               SE              FT                         Research Engineer    139000             USD         139000                 US             0               US            M
# 58         2023               EX              FT                            Data Scientist    258750             USD         258750                 US             0               US            M
# 59         2023               EX              FT                            Data Scientist    185000             USD         185000                 US             0               US            M
# 60         2023               SE              FT                             Data Engineer    231500             USD         231500                 US           100               US            M
# 61         2023               SE              FT                             Data Engineer    166000             USD         166000                 US           100               US            M
# 62         2023               SE              FT                            Data Scientist    172500             USD         172500                 US           100               US            M
# 63         2023               SE              FT                            Data Scientist    110500             USD         110500                 US           100               US            M
# 64         2023               SE              FT                             Data Engineer    238000             USD         238000                 US             0               US            M
# 65         2023               SE              FT                             Data Engineer    176000             USD         176000                 US             0               US            M
# 66         2023               SE              FT                             Data Engineer    237000             USD         237000                 US           100               US            M
# 67         2023               SE              FT                             Data Engineer    201450             USD         201450                 US           100               US            M
# 68         2023               SE              FT                         Applied Scientist    309400             USD         309400                 US             0               US            L
# 69         2023               SE              FT                         Applied Scientist    159100             USD         159100                 US             0               US            L
# 70         2023               SE              FT                             Data Engineer    115000             USD         115000                 US             0               US            M
# 71         2023               SE              FT                             Data Engineer     81500             USD          81500                 US             0               US            M
# 72         2023               SE              FT                            Data Scientist    237000             USD         237000                 US           100               US            M
# 73         2023               SE              FT                            Data Scientist    201450             USD         201450                 US           100               US            M
# 74         2023               SE              FT                  Computer Vision Engineer    280000             USD         280000                 US             0               US            M
# 75         2023               SE              FT                  Computer Vision Engineer    210000             USD         210000                 US             0               US            M
# 76         2023               SE              FT                            Data Architect    280100             USD         280100                 US           100               US            M
# 77         2023               SE              FT                            Data Architect    168100             USD         168100                 US           100               US            M
# 78         2023               SE              FT                             Data Engineer    193500             USD         193500                 US           100               US            M
# 79         2023               SE              FT                             Data Engineer    139000             USD         139000                 US           100               US            M
# 80         2023               MI              FT                            Data Scientist    510000             HKD          65062                 HK             0               HK            L
# 81         2023               SE              FT                 Machine Learning Engineer    150000             USD         150000                 PT           100               US            M
# 82         2023               MI              FT         Applied Machine Learning Engineer     65000             EUR          69751                 IN           100               DE            S
# 83         2022               EN              FT                              AI Developer    300000             USD         300000                 IN            50               IN            L
# 84         2023               MI              FT                 Machine Learning Engineer     90000             EUR          96578                 NL           100               NL            L
# 85         2023               SE              FT            Business Intelligence Engineer    185900             USD         185900                 US             0               US            M
# 86         2023               SE              FT            Business Intelligence Engineer    129300             USD         129300                 US             0               US            M
# 87         2023               SE              FT                             Data Engineer    225000             USD         225000                 US           100               US            M
# 88         2023               SE              FT                             Data Engineer    175000             USD         175000                 US           100               US            M
# 89         2023               SE              FT                             Data Engineer    185000             USD         185000                 US             0               US            M
# 90         2023               SE              FT                             Data Engineer    140000             USD         140000                 US             0               US            M
# 91         2023               SE              FT                            Data Scientist     45000             EUR          48289                 ES             0               ES            M
# 92         2023               SE              FT                            Data Scientist     36000             EUR          38631                 ES             0               ES            M
# 93         2023               SE              FT                            Data Scientist    105000             USD         105000                 US             0               US            M
# 94         2023               SE              FT                            Data Scientist     70000             USD          70000                 US             0               US            M
# 95         2023               EN              FT                 Machine Learning Engineer    163196             USD         163196                 US             0               US            M
# 96         2023               EN              FT                 Machine Learning Engineer    145885             USD         145885                 US             0               US            M
# 97         2023               SE              FT                             Data Engineer    217000             USD         217000                 US           100               US            M
# 98         2023               SE              FT                             Data Engineer    185000             USD         185000                 US           100               US            M
# 99         2023               SE              FT                              Data Analyst    202800             USD         202800                 US             0               US            L
# 100        2023               SE              FT                              Data Analyst    104300             USD         104300                 US             0               US            L
# 101        2023               SE              FT                              Data Analyst    145000             USD         145000                 US             0               US            M
# 102        2023               SE              FT                              Data Analyst     65000             USD          65000                 US             0               US            M
# 103        2023               SE              FT                             Data Engineer    165000             USD         165000                 US             0               US            M
# 104        2023               SE              FT                             Data Engineer    132300             USD         132300                 US             0               US            M
# 105        2023               SE              FT                             Data Engineer    179170             USD         179170                 US             0               US            M
# 106        2023               SE              FT                             Data Engineer     94300             USD          94300                 US             0               US            M
# 107        2023               SE              FT                        Analytics Engineer    152500             USD         152500                 US             0               US            M
# 108        2023               SE              FT                        Analytics Engineer    116450             USD         116450                 US             0               US            M
# 109        2023               SE              FT                             Data Engineer    247300             USD         247300                 US             0               US            M
# 110        2023               SE              FT                             Data Engineer    133800             USD         133800                 US             0               US            M
# 111        2023               SE              FT                         Research Engineer    203000             USD         203000                 US             0               US            M
# 112        2023               SE              FT                         Research Engineer    133000             USD         133000                 US             0               US            M
# 113        2023               EN              FT                        Research Scientist    220000             USD         220000                 US            50               US            L
# 114        2022               EN              FT                 Machine Learning Engineer     54000             CHF          56536                 CH           100               CH            S
# 115        2023               SE              FT                            Data Scientist    150000             USD         150000                 US             0               US            M
# 116        2023               SE              FT                            Data Scientist    120000             USD         120000                 US             0               US            M
# 117        2023               SE              FT                        Analytics Engineer    289800             USD         289800                 US             0               US            M
# 118        2023               SE              FT                        Analytics Engineer    214000             USD         214000                 US             0               US            M
# 119        2023               SE              FT                        Analytics Engineer    179820             USD         179820                 US             0               US            M
# 120        2023               SE              FT                        Analytics Engineer    143860             USD         143860                 US             0               US            M
# 121        2023               SE              FT                 Machine Learning Engineer    283200             USD         283200                 US           100               US            M
# 122        2023               SE              FT                 Machine Learning Engineer    188800             USD         188800                 US           100               US            M
# 123        2023               SE              FT                        Analytics Engineer    289800             USD         289800                 US             0               US            M
# 124        2023               SE              FT                        Analytics Engineer    214200             USD         214200                 US             0               US            M
# 125        2023               SE              FT                             Data Engineer    185900             USD         185900                 US             0               US            M
# 126        2023               SE              FT                             Data Engineer    129300             USD         129300                 US             0               US            M
# 127        2023               SE              FT                             Data Engineer    252000             USD         252000                 US             0               US            M
# 128        2023               SE              FT                             Data Engineer    129000             USD         129000                 US             0               US            M
# 129        2023               MI              FT                    Data Analytics Manager    155000             USD         155000                 US             0               US            M
# 130        2023               MI              FT                    Data Analytics Manager    140000             USD         140000                 US             0               US            M
# 131        2023               SE              FT                             Data Engineer    161800             USD         161800                 US           100               US            M
# 132        2023               SE              FT                             Data Engineer    141600             USD         141600                 US           100               US            M
# 133        2023               SE              FT                 Machine Learning Engineer    342300             USD         342300                 US             0               US            L
# 134        2023               SE              FT                 Machine Learning Engineer    176100             USD         176100                 US             0               US            L
# 135        2023               MI              FT                             Data Engineer    100000             USD         100000                 US           100               US            M
# 136        2023               MI              FT                             Data Engineer     70000             USD          70000                 US           100               US            M
# 137        2023               EN              FT                             Data Engineer     85000             USD          85000                 US             0               US            M
# 138        2023               EN              FT                             Data Engineer     65000             USD          65000                 US             0               US            M
# 139        2023               SE              FT                            Data Scientist    138784             USD         138784                 US           100               US            M
# 140        2023               SE              FT                            Data Scientist     83270             USD          83270                 US           100               US            M
# 141        2023               EN              FT                              Data Analyst     75000             USD          75000                 US             0               US            M
# 142        2023               EN              FT                              Data Analyst     70000             USD          70000                 US             0               US            M
# 143        2023               SE              FT                              Data Analyst    204500             USD         204500                 US             0               US            M
# 144        2023               SE              FT                              Data Analyst    138900             USD         138900                 US             0               US            M
# 145        2023               SE              FT                 Machine Learning Engineer    318300             USD         318300                 US           100               US            M
# 146        2023               SE              FT                 Machine Learning Engineer    212200             USD         212200                 US           100               US            M
# 147        2023               SE              FT                             Data Engineer     95000             USD          95000                 US           100               US            M
# 148        2023               SE              FT                             Data Engineer     75000             USD          75000                 US           100               US            M
# 149        2023               SE              FT                            Data Scientist    195000             USD         195000                 US             0               US            M
# 150        2023               SE              FT                            Data Scientist    160000             USD         160000                 US             0               US            M
# 151        2023               SE              FT                        Analytics Engineer    230000             USD         230000                 US             0               US            M
# 152        2023               SE              FT                        Analytics Engineer    143200             USD         143200                 US             0               US            M
# 153        2023               MI              FT                             Data Engineer    100000             USD         100000                 US           100               US            M
# 154        2023               MI              FT                             Data Engineer     70000             USD          70000                 US           100               US            M
# 155        2023               MI              FT                     Business Data Analyst    105000             USD         105000                 US            50               US            L
# 156        2023               MI              FT                    Applied Data Scientist   1700000             INR          20670                 IN           100               IN            L
# 157        2023               MI              FT                              Data Analyst     38000             GBP          46178                 GB             0               GB            M
# 158        2023               MI              FT                              Data Analyst     35000             GBP          42533                 GB             0               GB            M
# 159        2023               SE              FT                             Data Engineer    145000             USD         145000                 US             0               US            M
# 160        2023               SE              FT                             Data Engineer    115000             USD         115000                 US             0               US            M
# 161        2023               SE              FT                              Data Analyst    168400             USD         168400                 US             0               US            M
# 162        2023               SE              FT                              Data Analyst    105200             USD         105200                 US             0               US            M
# 163        2023               SE              FT                         Applied Scientist    309400             USD         309400                 US             0               US            L
# 164        2023               SE              FT                         Applied Scientist    159100             USD         159100                 US             0               US            L
# 165        2023               SE              FT                 Machine Learning Engineer    190000             USD         190000                 US             0               US            M
# 166        2023               SE              FT                 Machine Learning Engineer    150000             USD         150000                 US             0               US            M
# 167        2023               MI              FT                             Data Engineer    162500             USD         162500                 US             0               US            M
# 168        2023               MI              FT                             Data Engineer    130000             USD         130000                 US             0               US            M
# 169        2023               SE              FT                        Analytics Engineer    150000             USD         150000                 US           100               US            M
# 170        2023               SE              FT                        Analytics Engineer    120000             USD         120000                 US           100               US            M
# 171        2023               SE              FT                             Data Engineer    145000             USD         145000                 US             0               US            M
# 172        2023               SE              FT                             Data Engineer    120000             USD         120000                 US             0               US            M
# 173        2023               SE              FT                         Applied Scientist    222200             USD         222200                 US             0               US            L
# 174        2023               SE              FT                         Applied Scientist    136000             USD         136000                 US             0               US            L
# 175        2023               SE              FT                              Data Analyst     45000             GBP          54685                 CF           100               CF            M
# 176        2023               SE              FT                              Data Analyst     35000             GBP          42533                 CF           100               CF            M
# 177        2023               SE              FT                             Data Engineer    241000             USD         241000                 US             0               US            M
# 178        2023               SE              FT                             Data Engineer    155000             USD         155000                 US             0               US            M
# 179        2023               SE              FT                             Data Engineer    220000             USD         220000                 US           100               US            M
# 180        2023               SE              FT                             Data Engineer    190000             USD         190000                 US           100               US            M
# 181        2023               MI              FT                            Data Scientist     55000             GBP          66837                 GB             0               GB            M
# 182        2023               MI              FT                            Data Scientist     45000             GBP          54685                 GB             0               GB            M
# 183        2020               EX              FT                        Staff Data Analyst     15000             USD          15000                 NG             0               CA            M
# 184        2023               MI              FT                              ETL Engineer     70000             GBP          85066                 GB           100               GB            M
# 185        2023               MI              FT                              ETL Engineer     47500             GBP          57723                 GB           100               GB            M
# 186        2023               EN              FT                              Data Analyst     85000             USD          85000                 US           100               US            M
# 187        2023               EN              FT                              Data Analyst     75000             USD          75000                 US           100               US            M
# 188        2023               SE              FT                             Data Engineer    160000             USD         160000                 US             0               US            M
# 189        2023               SE              FT                             Data Engineer    140000             USD         140000                 US             0               US            M
# 190        2023               MI              FT                 Machine Learning Engineer    300000             USD         300000                 US             0               US            M
# 191        2023               MI              FT                 Machine Learning Engineer    250000             USD         250000                 US             0               US            M
# 192        2023               SE              FT                            Data Scientist    228000             USD         228000                 US             0               US            M
# 193        2023               SE              FT                            Data Scientist    186000             USD         186000                 US             0               US            M
# 194        2023               SE              FT                            Data Scientist    190000             USD         190000                 US             0               US            M
# 195        2023               SE              FT                            Data Scientist    170000             USD         170000                 US             0               US            M
# 196        2023               MI              FT                         Research Engineer    230000             USD         230000                 US             0               US            M
# 197        2023               MI              FT                         Research Engineer    200000             USD         200000                 US             0               US            M
# 198        2023               SE              FT                            Data Architect    180000             USD         180000                 US           100               US            M
# 199        2023               SE              FT                            Data Architect    115000             USD         115000                 US           100               US            M
# 200        2023               SE              FT                            Data Architect    200000             USD         200000                 US           100               US            M
# 201        2023               SE              FT                            Data Architect    115000             USD         115000                 US           100               US            M
# 202        2023               SE              FT                      Data DevOps Engineer     50000             EUR          53654                 FR            50               FR            S
# 203        2023               EX              FT                             Data Engineer    220000             USD         220000                 US             0               US            M
# 204        2023               EX              FT                             Data Engineer    205000             USD         205000                 US             0               US            M
# 205        2023               MI              FT                             Data Engineer    180000             USD         180000                 US             0               US            M
# 206        2023               MI              FT                             Data Engineer    130000             USD         130000                 US             0               US            M
# 207        2023               SE              FT                             Data Engineer    200000             USD         200000                 US           100               US            M
# 208        2023               SE              FT                             Data Engineer    150000             USD         150000                 US           100               US            M
# 209        2023               SE              FT                  Computer Vision Engineer    215000             USD         215000                 US             0               US            M
# 210        2023               SE              FT                  Computer Vision Engineer    170000             USD         170000                 US             0               US            M
# 211        2023               SE              FT                 Machine Learning Engineer    247500             USD         247500                 US             0               US            M
# 212        2023               SE              FT                 Machine Learning Engineer    172200             USD         172200                 US             0               US            M
# 213        2023               SE              FT                            Data Scientist    224000             USD         224000                 CA             0               CA            M
# 214        2023               SE              FT                            Data Scientist    176000             USD         176000                 CA             0               CA            M
# 215        2023               SE              FT                              Data Analyst    120000             USD         120000                 US           100               US            M
# 216        2023               SE              FT                              Data Analyst     75000             USD          75000                 US           100               US            M
# 217        2023               EN              FT                             Data Engineer   1400000             INR          17022                 IN           100               IN            L
# 218        2023               SE              FT                    Applied Data Scientist    100000             AUD          68318                 AU           100               FI            M
# 219        2023               MI              FT                              AI Developer    100000             SGD          75020                 FI             0               FI            M
# 220        2023               SE              FT                              Data Analyst    140000             USD         140000                 US             0               US            M
# 221        2023               SE              FT                              Data Analyst    120000             USD         120000                 US             0               US            M
# 222        2023               SE              FT                             Data Engineer    128000             USD         128000                 US             0               US            M
# 223        2023               SE              FT                             Data Engineer     81500             USD          81500                 US             0               US            M
# 224        2023               SE              FT                             Data Engineer    145000             USD         145000                 US             0               US            M
# 225        2023               SE              FT                             Data Engineer    115000             USD         115000                 US             0               US            M
# 226        2023               SE              FT                             Data Engineer    185000             USD         185000                 US             0               US            M
# 227        2023               SE              FT                             Data Engineer    140000             USD         140000                 US             0               US            M
# 228        2023               EX              FT                              Head of Data    329500             USD         329500                 US             0               US            M
# 229        2023               EX              FT                              Head of Data    269600             USD         269600                 US             0               US            M
# 230        2023               SE              FT                      Data Quality Analyst    100000             USD         100000                 US             0               US            M
# 231        2023               SE              FT                      Data Quality Analyst     80000             USD          80000                 US             0               US            M
# 232        2023               SE              FT                            Data Scientist    250000             USD         250000                 US             0               US            M
# 233        2023               SE              FT                            Data Scientist    162500             USD         162500                 US             0               US            M
# 234        2023               MI              FT                              AI Developer    200000             USD         200000                 US           100               US            M
# 235        2023               SE              FT                             Data Engineer    145000             USD         145000                 US             0               US            M
# 236        2023               SE              FT                             Data Engineer    100000             USD         100000                 US             0               US            M
# 237        2023               EX              FT                             Data Engineer    145000             USD         145000                 US             0               US            M
# 238        2023               EX              FT                             Data Engineer    115000             USD         115000                 US             0               US            M
# 239        2023               SE              FT                            Data Scientist    203500             USD         203500                 US             0               US            M
# 240        2023               SE              FT                            Data Scientist    152000             USD         152000                 US             0               US            M
# 241        2023               SE              FT                            Data Scientist    239000             USD         239000                 US             0               US            L
# 242        2023               SE              FT                            Data Scientist    122900             USD         122900                 US             0               US            L
# 243        2023               SE              FT                            Data Scientist    237000             USD         237000                 US             0               US            M
# 244        2023               SE              FT                            Data Scientist    145000             USD         145000                 US             0               US            M
# ...
# 3673       2021               MI              FT                            Data Scientist     32000             EUR          37825                 ES           100               ES            L
# 3674       2020               MI              FT                              Data Analyst     85000             USD          85000                 US           100               US            L
# 3675       2021               EX              CT                  Principal Data Scientist    416000             USD         416000                 US           100               US            S
# 3676       2021               SE              FT                Machine Learning Scientist    225000             USD         225000                 US           100               CA            L
# 3677       2021               MI              FT                            Data Scientist     40900             GBP          56256                 GB            50               GB            L
# 3678       2021               MI              FT                            Data Scientist   2500000             INR          33808                 IN             0               IN            M
# 3679       2021               MI              FT                            Data Scientist     85000             GBP         116914                 GB            50               GB            L
# 3680       2021               MI              FT                 Machine Learning Engineer    180000             PLN          46597                 PL           100               PL            L
# 3681       2020               MI              FT                              Data Analyst      8000             USD           8000                 PK            50               PK            L
# 3682       2020               EN              FT                             Data Engineer   4450000             JPY          41689                 JP           100               JP            S
# 3683       2020               SE              FT                         Big Data Engineer    100000             EUR         114047                 PL           100               GB            S
# 3684       2021               MI              FT                 Machine Learning Engineer     75000             EUR          88654                 BE           100               BE            M
# 3685       2020               EN              FT                   Data Science Consultant    423000             INR           5707                 IN            50               IN            M
# 3686       2020               MI              FT                        Lead Data Engineer     56000             USD          56000                 PT           100               US            M
# 3687       2021               EN              PT                  Computer Vision Engineer    180000             DKK          28609                 DK            50               DK            S
# 3688       2021               MI              FT                            Data Scientist     75000             EUR          88654                 DE            50               DE            L
# 3689       2020               MI              FT                      Product Data Analyst    450000             INR           6072                 IN           100               IN            L
# 3690       2020               SE              FT                             Data Engineer     42000             EUR          47899                 GR            50               GR            L
# 3691       2020               MI              FT                           BI Data Analyst     98000             USD          98000                 US             0               US            M
# 3692       2021               MI              FT                             Data Engineer     48000             GBP          66022                 HK            50               GB            S
# 3693       2021               MI              FT                        Research Scientist     48000             EUR          56738                 FR            50               FR            S
# 3694       2021               MI              FT                 Machine Learning Engineer     21000             EUR          24823                 SI            50               SI            L
# 3695       2021               SE              FT                    Data Analytics Manager    120000             USD         120000                 US             0               US            L
# 3696       2021               MI              FL                             Data Engineer     20000             USD          20000                 IT             0               US            L
# 3697       2020               EX              FT                  Director of Data Science    325000             USD         325000                 US           100               US            L
# 3698       2021               SE              FT                 Machine Learning Engineer    200000             USD         200000                 US           100               US            L
# 3699       2020               EN              FT                              AI Scientist    300000             DKK          45896                 DK            50               DK            S
# 3700       2021               MI              FT                            Data Scientist    160000             USD         160000                 US           100               US            L
# 3701       2021               SE              FT                        Research Scientist     50000             USD          50000                 FR           100               US            S
# 3702       2021               MI              FT                     Data Science Engineer     34000             EUR          40189                 GR           100               GR            M
# 3703       2021               MI              FT                            Data Scientist     69600             BRL          12901                 BR             0               BR            S
# 3704       2021               SE              FT                             Data Engineer    165000             USD         165000                 US             0               US            M
# 3705       2021               EN              FT                         Big Data Engineer    435000             INR           5882                 IN             0               CH            L
# 3706       2020               MI              FT                            Data Scientist     37000             EUR          42197                 FR            50               FR            S
# 3707       2021               SE              FT                   Principal Data Engineer    185000             USD         185000                 US           100               US            L
# 3708       2020               EN              FT                            Data Scientist     55000             EUR          62726                 DE            50               DE            S
# 3709       2021               MI              FT                            Data Scientist     76760             EUR          90734                 DE            50               DE            L
# 3710       2020               EN              PT                            Data Scientist     19000             EUR          21669                 IT            50               IT            S
# 3711       2020               MI              FT                             Data Engineer    110000             USD         110000                 US           100               US            L
# 3712       2021               SE              FT                    Data Analytics Manager    140000             USD         140000                 US           100               US            L
# 3713       2020               SE              FT                            Data Scientist    120000             USD         120000                 US            50               US            L
# 3714       2021               SE              FT                            Data Scientist    110000             CAD          87738                 CA           100               CA            S
# 3715       2021               SE              FT                      Finance Data Analyst     45000             GBP          61896                 GB            50               GB            L
# 3716       2021               MI              FL                Machine Learning Scientist     12000             USD          12000                 PK            50               PK            M
# 3717       2021               SE              FT                             Data Engineer     65000             EUR          76833                 RO            50               GB            S
# 3718       2021               MI              FT                 Machine Learning Engineer     74000             USD          74000                 JP            50               JP            S
# 3719       2021               SE              FT                      Data Science Manager    152000             USD         152000                 US           100               FR            L
# 3720       2021               MI              FT                         Big Data Engineer     18000             USD          18000                 MD             0               MD            S
# 3721       2020               SE              FL                  Computer Vision Engineer     60000             USD          60000                 RU           100               US            S
# 3722       2021               MI              FT                            Data Scientist    130000             USD         130000                 US            50               US            L
# 3723       2021               SE              FT                  Computer Vision Engineer    102000             BRL          18907                 BR             0               BR            M
# 3724       2021               EN              FT                     Business Data Analyst     50000             EUR          59102                 LU           100               LU            L
# 3725       2021               SE              FT                  Principal Data Scientist    147000             EUR         173762                 DE           100               DE            M
# 3726       2020               SE              FT                  Principal Data Scientist    130000             EUR         148261                 DE           100               DE            M
# 3727       2020               MI              FT                            Data Scientist     34000             EUR          38776                 ES           100               ES            M
# 3728       2021               MI              FT                            Data Scientist     39600             EUR          46809                 ES           100               ES            M
# 3729       2021               EN              FT                              AI Scientist   1335000             INR          18053                 IN           100               AS            S
# 3730       2020               SE              FT                            Data Scientist     80000             EUR          91237                 AT             0               AT            S
# 3731       2020               MI              FT                            Data Scientist     55000             EUR          62726                 FR            50               LU            S
# 3732       2021               MI              FT                            Data Scientist    115000             USD         115000                 US            50               US            L
# 3733       2021               SE              FT                  Principal Data Scientist    235000             USD         235000                 US           100               US            L
# 3734       2021               MI              FT                         Lead Data Analyst   1450000             INR          19609                 IN           100               IN            L
# 3735       2021               EN              PT                              AI Scientist     12000             USD          12000                 BR           100               US            S
# 3736       2021               MI              FT                              Data Analyst     75000             USD          75000                 US             0               US            L
# 3737       2021               MI              FT                              Data Analyst     62000             USD          62000                 US             0               US            L
# 3738       2021               MI              FT                            Data Scientist     73000             USD          73000                 US             0               US            L
# 3739       2021               MI              FT                             Data Engineer     38400             EUR          45391                 NL           100               NL            L
# 3740       2020               SE              FT                      Data Science Manager    190200             USD         190200                 US           100               US            M
# 3741       2020               MI              FT                            Data Scientist    118000             USD         118000                 US           100               US            M
# 3742       2020               MI              FT                            Data Scientist    138350             USD         138350                 US           100               US            M
# 3743       2020               MI              FT                             Data Engineer    130800             USD         130800                 ES           100               US            M
# 3744       2020               SE              FT                 Machine Learning Engineer     40000             EUR          45618                 HR           100               HR            S
# 3745       2021               SE              FT                  Director of Data Science    168000             USD         168000                 JP             0               JP            S
# 3746       2021               MI              FT                            Data Scientist    160000             SGD         119059                 SG           100               IL            M
# 3747       2021               MI              FT        Applied Machine Learning Scientist    423000             USD         423000                 US            50               US            L
# 3748       2021               MI              FT                             Data Engineer     24000             EUR          28369                 MT            50               MT            L
# 3749       2021               SE              FT                           Data Specialist    165000             USD         165000                 US           100               US            L
# 3750       2020               SE              FT                            Data Scientist    412000             USD         412000                 US           100               US            L
# 3751       2021               MI              FT                  Principal Data Scientist    151000             USD         151000                 US           100               US            L
# 3752       2020               EN              FT                            Data Scientist    105000             USD         105000                 US           100               US            S
# 3753       2020               EN              CT                     Business Data Analyst    100000             USD         100000                 US           100               US            L
# 3754       2021               SE              FT                      Data Science Manager   7000000             INR          94665                 IN            50               IN            L

# %% [markdown]
# Para ver mas informacion usamos el info() esta vez va con parentesis porque es una funcion (metodo).
# Objects son strings

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3755 entries, 0 to 3754
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   work_year           3755 non-null   int64
#  1   experience_level    3755 non-null   object
#  2   employment_type     3755 non-null   object
#  3   job_title           3755 non-null   object
#  4   salary              3755 non-null   int64
#  5   salary_currency     3755 non-null   object
#  6   salary_in_usd       3755 non-null   int64
#  7   employee_residence  3755 non-null   object
#  8   remote_ratio        3755 non-null   int64
#  9   company_location    3755 non-null   object
#  10  company_size        3755 non-null   object
# dtypes: int64(4), object(7)
# memory usage: 322.8+ KB

# %%
#para que nos muestre las 20 primeras filas
df.head(20)
# Out:
#     work_year experience_level employment_type                 job_title  \
# 0        2023               SE              FT  Principal Data Scientist
# 1        2023               MI              CT               ML Engineer
# 2        2023               MI              CT               ML Engineer
# 3        2023               SE              FT            Data Scientist
# 4        2023               SE              FT            Data Scientist
# 5        2023               SE              FT         Applied Scientist
# 6        2023               SE              FT         Applied Scientist
# 7        2023               SE              FT            Data Scientist
# 8        2023               SE              FT            Data Scientist
# 9        2023               SE              FT            Data Scientist
# 10       2023               SE              FT            Data Scientist
# 11       2023               SE              FT              Data Analyst
# 12       2023               SE              FT              Data Analyst
# 13       2023               EN              FT         Applied Scientist
# 14       2023               EN              FT         Applied Scientist
# 15       2023               SE              FT              Data Modeler
# 16       2023               SE              FT              Data Modeler
# 17       2023               SE              FT            Data Scientist
# 18       2023               SE              FT            Data Scientist
# 19       2023               MI              FT              Data Analyst
#
#     salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0    80000             EUR          85847                 ES           100
# 1    30000             USD          30000                 US           100
# 2    25500             USD          25500                 US           100
# 3   175000             USD         175000                 CA           100
# 4   120000             USD         120000                 CA           100
# 5   222200             USD         222200                 US             0
# 6   136000             USD         136000                 US             0
# 7   219000             USD         219000                 CA             0
# 8   141000             USD         141000                 CA             0
# 9   147100             USD         147100                 US             0
# 10   90700             USD          90700                 US             0
# 11  130000             USD         130000                 US           100
# 12  100000             USD         100000                 US           100
# 13  213660             USD         213660                 US             0
# 14  130760             USD         130760                 US             0
# 15  147100             USD         147100                 US             0
# 16   90700             USD          90700                 US             0
# 17  170000             USD         170000                 US             0
# 18  150000             USD         150000                 US             0
# 19  150000             USD         150000                 US           100
#
#    company_location company_size
# 0                ES            L
# 1                US            S
# 2                US            S
# 3                CA            M
# 4                CA            M
# 5                US            L
# 6                US            L
# 7                CA            M
# 8                CA            M
# 9                US            M
# 10               US            M
# 11               US            M
# 12               US            M
# 13               US            L
# 14               US            L
# 15               US            M
# 16               US            M
# 17               US            M
# 18               US            M
# 19               US            M

# %%
#para que nos muestre las 15 ultimas filas
df.tail(15)
# Out:
#       work_year experience_level employment_type  \
# 3740       2020               SE              FT
# 3741       2020               MI              FT
# 3742       2020               MI              FT
# 3743       2020               MI              FT
# 3744       2020               SE              FT
# 3745       2021               SE              FT
# 3746       2021               MI              FT
# 3747       2021               MI              FT
# 3748       2021               MI              FT
# 3749       2021               SE              FT
# 3750       2020               SE              FT
# 3751       2021               MI              FT
# 3752       2020               EN              FT
# 3753       2020               EN              CT
# 3754       2021               SE              FT
#
#                                job_title   salary salary_currency  \
# 3740                Data Science Manager   190200             USD
# 3741                      Data Scientist   118000             USD
# 3742                      Data Scientist   138350             USD
# 3743                       Data Engineer   130800             USD
# 3744           Machine Learning Engineer    40000             EUR
# 3745            Director of Data Science   168000             USD
# 3746                      Data Scientist   160000             SGD
# 3747  Applied Machine Learning Scientist   423000             USD
# 3748                       Data Engineer    24000             EUR
# 3749                     Data Specialist   165000             USD
# 3750                      Data Scientist   412000             USD
# 3751            Principal Data Scientist   151000             USD
# 3752                      Data Scientist   105000             USD
# 3753               Business Data Analyst   100000             USD
# 3754                Data Science Manager  7000000             INR
#
#       salary_in_usd employee_residence  remote_ratio company_location  \
# 3740         190200                 US           100               US
# 3741         118000                 US           100               US
# 3742         138350                 US           100               US
# 3743         130800                 ES           100               US
# 3744          45618                 HR           100               HR
# 3745         168000                 JP             0               JP
# 3746         119059                 SG           100               IL
# 3747         423000                 US            50               US
# 3748          28369                 MT            50               MT
# 3749         165000                 US           100               US
# 3750         412000                 US           100               US
# 3751         151000                 US           100               US
# 3752         105000                 US           100               US
# 3753         100000                 US           100               US
# 3754          94665                 IN            50               IN
#
#      company_size
# 3740            M
# 3741            M
# 3742            M
# 3743            M
# 3744            S
# 3745            S
# 3746            M
# 3747            L
# 3748            L
# 3749            L
# 3750            L
# 3751            L
# 3752            S
# 3753            L
# 3754            L

# %% [markdown]
# Para que nos muestre todas las columnas. Le cambiamos el setting

# %%
pd.set_option('display.max_columns', 11)

# %%
df
# Out:
#       work_year experience_level employment_type                 job_title  \
# 0          2023               SE              FT  Principal Data Scientist
# 1          2023               MI              CT               ML Engineer
# 2          2023               MI              CT               ML Engineer
# 3          2023               SE              FT            Data Scientist
# 4          2023               SE              FT            Data Scientist
# ...         ...              ...             ...                       ...
# 3750       2020               SE              FT            Data Scientist
# 3751       2021               MI              FT  Principal Data Scientist
# 3752       2020               EN              FT            Data Scientist
# 3753       2020               EN              CT     Business Data Analyst
# 3754       2021               SE              FT      Data Science Manager
#
#        salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0       80000             EUR          85847                 ES           100
# 1       30000             USD          30000                 US           100
# 2       25500             USD          25500                 US           100
# 3      175000             USD         175000                 CA           100
# 4      120000             USD         120000                 CA           100
# ...       ...             ...            ...                ...           ...
# 3750   412000             USD         412000                 US           100
# 3751   151000             USD         151000                 US           100
# 3752   105000             USD         105000                 US           100
# 3753   100000             USD         100000                 US           100
# 3754  7000000             INR          94665                 IN            50
#
#      company_location company_size
# 0                  ES            L
# 1                  US            S
# 2                  US            S
# 3                  CA            M
# 4                  CA            M
# ...               ...          ...
# 3750               US            L
# 3751               US            L
# 3752               US            S
# 3753               US            L
# 3754               IN            L
#
# [3755 rows x 11 columns]

# %%
df.describe()
#round(df.describe(),2)
# Out:
#          work_year        salary  salary_in_usd  remote_ratio
# count  3755.000000  3.755000e+03    3755.000000   3755.000000
# mean   2022.373635  1.906956e+05  137570.389880     46.271638
# std       0.691448  6.716765e+05   63055.625278     48.589050
# min    2020.000000  6.000000e+03    5132.000000      0.000000
# 25%    2022.000000  1.000000e+05   95000.000000      0.000000
# 50%    2022.000000  1.380000e+05  135000.000000      0.000000
# 75%    2023.000000  1.800000e+05  175000.000000    100.000000
# max    2023.000000  3.040000e+07  450000.000000    100.000000

# %% [markdown]
# UNIDAD 2: DataFrame y Series

# %%
#usando los diccionarios tenemos
gente= {
    'nombre':'Marta',
    'apellido': 'Ruiz',
    'email': 'martaruiz@gmail.com'
}

# %%
#diccionario con listas de una sola persona
gente={
    'nombre': ['Marta'],
    'apellido': ['Ruiz'],
    'email': ['martaruiz@gmail.com']
}

# %%
#diccionario con listas de varias personas
gente={
    'nombre': ['Marta', 'Luis', 'Ana'],
    'apellido': ['Ruiz', 'Lopez', 'Santana'],
    'email': ['martaruiz@gmail.com', 'luislopez@gmail.com', 'anasantana@gmail.com']
}

# %%
gente['email']
# Out:
# ['martaruiz@gmail.com', 'luislopez@gmail.com', 'anasantana@gmail.com']

# %%
#para crear una tabla con los diccionarios anteriores usamos esta sintaxis

df=pd.DataFrame(gente)

df
# Out:
#   nombre apellido                 email
# 0  Marta     Ruiz   martaruiz@gmail.com
# 1   Luis    Lopez   luislopez@gmail.com
# 2    Ana  Santana  anasantana@gmail.com

# %%
#para acceder a informacion y ver los indices
df['email']
# Out:
# 0     martaruiz@gmail.com
# 1     luislopez@gmail.com
# 2    anasantana@gmail.com
# Name: email, dtype: object

# %%
#Para ver que la columna email es un series podemos acceder al tipo

type(df['email'])
# Out:
# pandas.core.series.Series

# %%
#tambien podemos hacerlo de otra manera

df.email
# Out:
# 0     martaruiz@gmail.com
# 1     luislopez@gmail.com
# 2    anasantana@gmail.com
# Name: email, dtype: object

# %%
#si queremos acceder a varias columnas, hace falta el doble corchete
#para evitar que pandas piense que los dos strings son el nombre de una sola
#columna

df[['apellido', 'email']]
# Out:
#   apellido                 email
# 0     Ruiz   martaruiz@gmail.com
# 1    Lopez   luislopez@gmail.com
# 2  Santana  anasantana@gmail.com

# %%
#para ver las columnas usamos
df.columns
# Out:
# Index(['nombre', 'apellido', 'email'], dtype='object')

# %%
#para ver las filas usamos los indices y la funcion iloc(integer location)

df.iloc[0]
# Out:
# nombre                    Marta
# apellido                   Ruiz
# email       martaruiz@gmail.com
# Name: 0, dtype: object

# %%
#si queremos ver dos filas

df.iloc[[0,1]]
# Out:
#   nombre apellido                email
# 0  Marta     Ruiz  martaruiz@gmail.com
# 1   Luis    Lopez  luislopez@gmail.com

# %%
#si queremos mostrar dos filas y la columna con el indice 2

df.iloc[[0, 1], 2]
# Out:
# 0    martaruiz@gmail.com
# 1    luislopez@gmail.com
# Name: email, dtype: object

# %%
#hay otra funcion parecida que es loc (no solo sirve para localizar integers
#tambien sirve para usar strings) para que nos muestre otra vez nuestra
#tabla o DataFrame
df
# Out:
#   nombre apellido                 email
# 0  Marta     Ruiz   martaruiz@gmail.com
# 1   Luis    Lopez   luislopez@gmail.com
# 2    Ana  Santana  anasantana@gmail.com

# %%
df.loc[0]
# Out:
# nombre                    Marta
# apellido                   Ruiz
# email       martaruiz@gmail.com
# Name: 0, dtype: object

# %%
#como hicimos con el iloc podemos hacer lo siguiente

df.loc[[0,1], ['email', 'apellido']]
# Out:
#                  email apellido
# 0  martaruiz@gmail.com     Ruiz
# 1  luislopez@gmail.com    Lopez

# %%
#tambien podemos usar el slicing o loncheado
#no hay doble corchete porque no estamos pasando una lista como antes
df.loc[0:2, 'email']
# Out:
# 0     martaruiz@gmail.com
# 1     luislopez@gmail.com
# 2    anasantana@gmail.com
# Name: email, dtype: object

# %%
#tambien podemos usar el slicing para filas y columnas
df.loc[0:2, 'nombre': 'email']
# Out:
#   nombre apellido                 email
# 0  Marta     Ruiz   martaruiz@gmail.com
# 1   Luis    Lopez   luislopez@gmail.com
# 2    Ana  Santana  anasantana@gmail.com

# %% [markdown]
# UNIDAD 3: INDICES (set, reset, etc.)

# %%
import pandas as pd

#diccionario con listas de varias personas
gente={
    'nombre': ['Marta', 'Luis', 'Ana'],
    'apellido': ['Ruiz', 'Lopez', 'Santana'],
    'email': ['martaruiz@gmail.com', 'luislopez@gmail.com', 'anasantana@gmail.com']
}

# %%
df=pd.DataFrame(gente)

df
# Out:
#   nombre apellido                 email
# 0  Marta     Ruiz   martaruiz@gmail.com
# 1   Luis    Lopez   luislopez@gmail.com
# 2    Ana  Santana  anasantana@gmail.com

# %%
#vamos a cambiar los indices de default(0, 1, 2, etc) por los emails
#que tambien son unicos para cada personas. inplace=True sirve para
#dejar definitivos los cambios

df.set_index('email', inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-5-df89c4c6b520> in <cell line: 5>()
#       3 #dejar definitivos los cambios
#       4
# ----> 5 df.set_index('email', inplace=True)
#       6
#       7 df
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    6010
#    6011         if missing:
# -> 6012             raise KeyError(f"None of {missing} are in the columns")
#    6013
#    6014         if inplace:
#
# KeyError: "None of ['email'] are in the columns"

# %%
#si queremos poner los nuevos indices por orden alfabetico usamos
#la funcion sort_index()
df.sort_index()
# Out:
#                      nombre apellido
# email
# anasantana@gmail.com    Ana  Santana
# luislopez@gmail.com    Luis    Lopez
# martaruiz@gmail.com   Marta     Ruiz

# %%
#para que el orden sea contrario al alfabetico usamos
df.sort_index(ascending=False)
# Out:
#                      nombre apellido
# email
# martaruiz@gmail.com   Marta     Ruiz
# luislopez@gmail.com    Luis    Lopez
# anasantana@gmail.com    Ana  Santana

# %%
df.index
# Out:
# Index(['martaruiz@gmail.com', 'luislopez@gmail.com', 'anasantana@gmail.com'], dtype='object', name='email')

# %%
#antes usabamos el numero del indice como por ejemplo el 0
#ahora usamos el string del email
df.loc['anasantana@gmail.com']
# Out:
# nombre          Ana
# apellido    Santana
# Name: anasantana@gmail.com, dtype: object

# %%
#tambien podemos detallar mas la consulta
df.loc['anasantana@gmail.com', 'apellido']
# Out:
# 'Santana'

# %%
#si queremos usar el loc con los indices numericos nos da error
#ya que ahora los indices son los emails
df.loc[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-54-49a3fe4b9a3e> in <cell line: 3>()
#       1 #si queremos usar el loc con los indices numericos nos da error
#       2 #ya que ahora los indices son los emails
# ----> 3 df.loc[0]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1071
#    1072             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1073             return self._getitem_axis(maybe_callable, axis=axis)
#    1074
#    1075     def _is_scalar_access(self, key: tuple):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1310         # fall thru to straight lookup
#    1311         self._validate_key(key, axis)
# -> 1312         return self._get_label(key, axis=axis)
#    1313
#    1314     def _get_slice_axis(self, slice_obj: slice, axis: int):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in _get_label(self, label, axis)
#    1258     def _get_label(self, label, axis: int):
#    1259         # GH#5567 this will fail if the label is not present in the axis.
# -> 1260         return self.obj.xs(label, axis=axis)
#    1261
#    1262     def _handle_lowerdim_multi_index_axis0(self, tup: tuple):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in xs(self, key, axis, level, drop_level)
#    4054                     new_index = index[loc]
#    4055         else:
# -> 4056             loc = index.get_loc(key)
#    4057
#    4058             if isinstance(loc, np.ndarray):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
# -> 3804                 raise KeyError(key) from err
#    3805             except TypeError:
#    3806                 # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 0

# %%
#sin embargo con el iloc si podemos seguir usando los indices numericos
#anteriores
df.iloc[0]
# Out:
# nombre      Marta
# apellido     Ruiz
# Name: martaruiz@gmail.com, dtype: object

# %%
#si queremos volver a poner los indices de default usamos la funcion
#reset_index()
df.reset_index(inplace=True)
df
# Out:
#    index                 email nombre apellido
# 0      0   martaruiz@gmail.com  Marta     Ruiz
# 1      1   luislopez@gmail.com   Luis    Lopez
# 2      2  anasantana@gmail.com    Ana  Santana

# %% [markdown]
# UNIDAD 4. FILTRAR DATAFRAME Y BUSCAR DATOS QUE CUMPLAN DETERMINADAS
# CONDICIONES. EL and Y EL or

# %%
import pandas as pd

# %%
gente={
    'nombre': ['Marta', 'Luis', 'Ana', 'Andres', 'Monica', 'Ana'],
    'apellido': ['Ruiz', 'Lopez', 'Santana', 'Lopez', 'Castro', 'Perez'],
    'email': ['martaruiz@gmail.com', 'luislopez@gmail.com', 'anasantana@gmail.com', 'andreslopez@gmail.com', 'monicacastro@gmail.com', 'saraperez@gmail.com'],
    'edad': [35, 28, 35, 'NaN', 53, 67],
    'salario': [20000, 25000, 50000, 17000, 20000, 65000],
    'ciudad' :['Madrid', 'Valencia', 'Malaga', 'Cadiz', 'Burgos', 'Madrid'],
    'casado': ['Yes', 'No', 'Yes', 'No', 'NaN', 'Yes']
}

#NaN =   not a number

# %%
df=pd.DataFrame(gente)

df
# Out:
#    nombre apellido                   email edad  salario    ciudad casado
# 0   Marta     Ruiz     martaruiz@gmail.com   35    20000    Madrid    Yes
# 1    Luis    Lopez     luislopez@gmail.com   28    25000  Valencia     No
# 2     Ana  Santana    anasantana@gmail.com   35    50000    Malaga    Yes
# 3  Andres    Lopez   andreslopez@gmail.com  NaN    17000     Cadiz     No
# 4  Monica   Castro  monicacastro@gmail.com   53    20000    Burgos    NaN
# 5     Ana    Perez     saraperez@gmail.com   67    65000    Madrid    Yes

# %%
#¿Quienes tienen el apellido Lopez?
df['apellido'] == 'Lopez'
# Out:
# 0    False
# 1     True
# 2    False
# 3     True
# 4    False
# 5    False
# Name: apellido, dtype: bool

# %%
#vamos a crear una variable llamada filt(no uses filter porque es una palabra clave de
#de Python) para que la consulta de antes nos muestre todos los datos
# de los Lopez

filt= df['apellido'] == 'Lopez'

# %%
df[filt]
# Out:
#    nombre apellido                  email edad  salario    ciudad casado
# 1    Luis    Lopez    luislopez@gmail.com   28    25000  Valencia     No
# 3  Andres    Lopez  andreslopez@gmail.com  NaN    17000     Cadiz     No

# %%
#si usamos el loc podemos buscar alguna columna de la busqueda anterior

df.loc[filt, 'email']
# Out:
# 1      luislopez@gmail.com
# 3    andreslopez@gmail.com
# Name: email, dtype: object

# %%
#en Pandas el and es el & y el or es el palito vertical |

filt= (df['apellido'] == 'Lopez') & (df['nombre'] == 'Andres')

df[filt]
# Out:
#    nombre apellido                  email edad  salario ciudad casado
# 3  Andres    Lopez  andreslopez@gmail.com  NaN    17000  Cadiz     No

# %%
#vamos a usar ahora el 'o' que en Pandas es igual a |
filt= (df['apellido'] == 'Lopez') | (df['nombre'] == 'Ana')
df[filt]
# Out:
#    nombre apellido                  email edad  salario    ciudad casado
# 1    Luis    Lopez    luislopez@gmail.com   28    25000  Valencia     No
# 2     Ana  Santana   anasantana@gmail.com   35    50000    Malaga    Yes
# 3  Andres    Lopez  andreslopez@gmail.com  NaN    17000     Cadiz     No
# 5     Ana    Perez    saraperez@gmail.com   67    65000    Madrid    Yes

# %%
#para conseguir el opuesto a la busqueda usamos el simbolo ~

filt= (df['apellido'] == 'Lopez') | (df['nombre'] == 'Ana')
df[~filt]
# Out:
#    nombre apellido                   email edad  salario  ciudad casado
# 0   Marta     Ruiz     martaruiz@gmail.com   35    20000  Madrid    Yes
# 4  Monica   Castro  monicacastro@gmail.com   53    20000  Burgos    NaN

# %%
#vamos a buscar las personas de nuestro dataframe que ganan mas de 35000
#euros de salario
#creamos una variable que se puede llamar salario_alto
salario_alto = (df['salario'] > 35000)

df[salario_alto]
# Out:
#   nombre apellido                 email edad  salario  ciudad casado
# 2    Ana  Santana  anasantana@gmail.com   35    50000  Malaga    Yes
# 5    Ana    Perez   saraperez@gmail.com   67    65000  Madrid    Yes

# %%
#podemos filtrar aun mas la busqueda
df.loc[salario_alto, ['edad', 'ciudad']]
# Out:
#   edad  ciudad
# 2   35  Malaga
# 5   67  Madrid

# %%
#vamos a filtrar que nuestra busqueda solo sea para Madrid y Malaga
#creamos otra variable. usamos la funcion isin (esta dentro de)
ciudades=['Madrid', 'Malaga']
filt= df['ciudad'].isin(ciudades)
df.loc[filt]
# Out:
#   nombre apellido                 email edad  salario  ciudad casado
# 0  Marta     Ruiz   martaruiz@gmail.com   35    20000  Madrid    Yes
# 2    Ana  Santana  anasantana@gmail.com   35    50000  Malaga    Yes
# 5    Ana    Perez   saraperez@gmail.com   67    65000  Madrid    Yes

# %%
#para hacer una busqueda de ciudades que tengan en su nombre algun caracter
#usamos la funcion str.contains()

filt = df['ciudad'].str.contains('g')
df.loc[filt]
# Out:
#    nombre apellido                   email edad  salario  ciudad casado
# 2     Ana  Santana    anasantana@gmail.com   35    50000  Malaga    Yes
# 4  Monica   Castro  monicacastro@gmail.com   53    20000  Burgos    NaN

# %% [markdown]
# UNIDAD 5. CAMBIAR DATOS EN EL DATAFRAME

# %%
#vamos a ver que columnas tiene nuestro DF
df.columns
# Out:
# Index(['nombre', 'apellido', 'email', 'edad', 'salario', 'ciudad', 'casado'], dtype='object')

# %%
#vamos a cambiar el nombre de todas las columnas al ingles
df.columns=['name', 'last_name', 'email', 'age', 'salary', 'city', 'married']

df.columns
# Out:
# Index(['name', 'last_name', 'email', 'age', 'salary', 'city', 'married'], dtype='object')

# %%
#para ver todo el DF
df
# Out:
#      name last_name                   email  age  salary      city married
# 0   Marta      Ruiz     martaruiz@gmail.com   35   20000    Madrid     Yes
# 1    Luis     Lopez     luislopez@gmail.com   28   25000  Valencia      No
# 2     Ana   Santana    anasantana@gmail.com   35   50000    Malaga     Yes
# 3  Andres     Lopez   andreslopez@gmail.com  NaN   17000     Cadiz      No
# 4  Monica    Castro  monicacastro@gmail.com   53   20000    Burgos     NaN
# 5     Ana     Perez     saraperez@gmail.com   67   65000    Madrid     Yes

# %%
#si queremos que los nombres de las columnas esten en mayuscula
df.columns = [x.upper() for x in df.columns]

df
# Out:
#      NAME LAST_NAME                   EMAIL  AGE  SALARY      CITY MARRIED
# 0   Marta      Ruiz     martaruiz@gmail.com   35   20000    Madrid     Yes
# 1    Luis     Lopez     luislopez@gmail.com   28   25000  Valencia      No
# 2     Ana   Santana    anasantana@gmail.com   35   50000    Malaga     Yes
# 3  Andres     Lopez   andreslopez@gmail.com  NaN   17000     Cadiz      No
# 4  Monica    Castro  monicacastro@gmail.com   53   20000    Burgos     NaN
# 5     Ana     Perez     saraperez@gmail.com   67   65000    Madrid     Yes

# %%
#si quieres quitar espacios entre palabras y meter guiones bajos por ejemplo,
#o hacer lo contrario
df.columns= df.columns.str.replace('_', ' ')

df
# Out:
#      NAME LAST NAME                   EMAIL  AGE  SALARY      CITY MARRIED
# 0   Marta      Ruiz     martaruiz@gmail.com   35   20000    Madrid     Yes
# 1    Luis     Lopez     luislopez@gmail.com   28   25000  Valencia      No
# 2     Ana   Santana    anasantana@gmail.com   35   50000    Malaga     Yes
# 3  Andres     Lopez   andreslopez@gmail.com  NaN   17000     Cadiz      No
# 4  Monica    Castro  monicacastro@gmail.com   53   20000    Burgos     NaN
# 5     Ana     Perez     saraperez@gmail.com   67   65000    Madrid     Yes

# %%
#vamos a dejar los nombres de las columnas en minusculas otra vez

df.columns = [x.lower() for x in df.columns]

df
# Out:
#      name last name                   email  age  salary      city married
# 0   Marta      Ruiz     martaruiz@gmail.com   35   20000    Madrid     Yes
# 1    Luis     Lopez     luislopez@gmail.com   28   25000  Valencia      No
# 2     Ana   Santana    anasantana@gmail.com   35   50000    Malaga     Yes
# 3  Andres     Lopez   andreslopez@gmail.com  NaN   17000     Cadiz      No
# 4  Monica    Castro  monicacastro@gmail.com   53   20000    Burgos     NaN
# 5     Ana     Perez     saraperez@gmail.com   67   65000    Madrid     Yes

# %%
#que pasa si solo queremos cambiar el nombre de algunas columnas. usamos
#funcion rename y un diccionario

df.rename(columns={'name': 'nombre', 'last name': 'apellido', 'age':'edad', 'city': 'ciudad'}, inplace=True)

df
# Out:
#    nombre apellido                   email edad  salary    ciudad married
# 0   Marta     Ruiz     martaruiz@gmail.com   35   20000    Madrid     Yes
# 1    Luis    Lopez     luislopez@gmail.com   28   25000  Valencia      No
# 2     Ana  Santana    anasantana@gmail.com   35   50000    Malaga     Yes
# 3  Andres    Lopez   andreslopez@gmail.com  NaN   17000     Cadiz      No
# 4  Monica   Castro  monicacastro@gmail.com   53   20000    Burgos     NaN
# 5     Ana    Perez     saraperez@gmail.com   67   65000    Madrid     Yes

# %%
#vamos a cambiar un solo valor dentro del DF
#le queremos cambiar el apellido a Monica Castro

df.loc[4, 'apellido'] = 'Romero'

df
# Out:
#    nombre apellido                   email edad  salary    ciudad married
# 0   Marta     Ruiz     martaruiz@gmail.com   35   20000    Madrid     Yes
# 1    Luis    Lopez     luislopez@gmail.com   28   25000  Valencia      No
# 2     Ana  Santana    anasantana@gmail.com   35   50000    Malaga     Yes
# 3  Andres    Lopez   andreslopez@gmail.com  NaN   17000     Cadiz      No
# 4  Monica   Romero  monicacastro@gmail.com   53   20000    Burgos     NaN
# 5     Ana    Perez     saraperez@gmail.com   67   65000    Madrid     Yes

# %%
#vamos cambiar la edad y el salario a Marta Ruiz

df.loc[0, ['edad', 'salary']] =[70, 78000]

df
# Out:
#    nombre apellido                   email edad  salary    ciudad married
# 0   Marta     Ruiz     martaruiz@gmail.com   70   78000    Madrid     Yes
# 1    Luis    Lopez     luislopez@gmail.com   28   25000  Valencia      No
# 2     Ana  Santana    anasantana@gmail.com   35   50000    Malaga     Yes
# 3  Andres    Lopez   andreslopez@gmail.com  NaN   17000     Cadiz      No
# 4  Monica   Romero  monicacastro@gmail.com   53   20000    Burgos     NaN
# 5     Ana    Perez     saraperez@gmail.com   67   65000    Madrid     Yes

# %%
#una funcion parecida a loc es la funcion at pero solo para cambiar un dato
#vamos a darle a Marta Ruiz de nuevo su edad a 35
#usar otra vez el at para cambiar solo salary

df.at[0, 'edad'] = 35

df
# Out:
#    nombre apellido                   email edad  salary    ciudad married
# 0   Marta     Ruiz     martaruiz@gmail.com   35   78000    Madrid     Yes
# 1    Luis    Lopez     luislopez@gmail.com   28   25000  Valencia      No
# 2     Ana  Santana    anasantana@gmail.com   35   50000    Malaga     Yes
# 3  Andres    Lopez   andreslopez@gmail.com  NaN   17000     Cadiz      No
# 4  Monica   Romero  monicacastro@gmail.com   53   20000    Burgos     NaN
# 5     Ana    Perez     saraperez@gmail.com   67   65000    Madrid     Yes

# %%
#vamos a cambiar los nombres de columnas que quedaban en ingles al
#español (salary y married)
df.rename(columns={'salary': 'salario', 'married': 'casado'}, inplace=True)

df
# Out:
#    nombre apellido                   email edad  salario    ciudad casado
# 0   Marta     Ruiz     martaruiz@gmail.com   35    78000    Madrid    Yes
# 1    Luis    Lopez     luislopez@gmail.com   28    25000  Valencia     No
# 2     Ana  Santana    anasantana@gmail.com   35    50000    Malaga    Yes
# 3  Andres    Lopez   andreslopez@gmail.com  NaN    17000     Cadiz     No
# 4  Monica   Romero  monicacastro@gmail.com   53    20000    Burgos    NaN
# 5     Ana    Perez     saraperez@gmail.com   67    65000    Madrid    Yes

# %%
#esta vez queremos cambiar la ciudad de la fila en la que el email es
#saraperez@gmail.com
filt= (df['email'] == 'saraperez@gmail.com')
df.loc[filt, 'ciudad'] = 'Paris'

df
# Out:
#    nombre apellido                   email edad  salario    ciudad casado
# 0   Marta     Ruiz     martaruiz@gmail.com   35    78000    Madrid    Yes
# 1    Luis    Lopez     luislopez@gmail.com   28    25000  Valencia     No
# 2     Ana  Santana    anasantana@gmail.com   35    50000    Malaga    Yes
# 3  Andres    Lopez   andreslopez@gmail.com  NaN    17000     Cadiz     No
# 4  Monica   Romero  monicacastro@gmail.com   53    20000    Burgos    NaN
# 5     Ana    Perez     saraperez@gmail.com   67    65000     Paris    Yes

# %%
#si queremos actualizar multiples filas y convertirlas en mayusculas

df['email'].str.upper()
# Out:
# 0       MARTARUIZ@GMAIL.COM
# 1       LUISLOPEZ@GMAIL.COM
# 2      ANASANTANA@GMAIL.COM
# 3     ANDRESLOPEZ@GMAIL.COM
# 4    MONICACASTRO@GMAIL.COM
# 5       SARAPEREZ@GMAIL.COM
# Name: email, dtype: object

# %%
#si ahora queremos ver todo el DF
df['email']= df['email'].str.upper()

df
# Out:
#    nombre apellido                   email edad  salario    ciudad casado
# 0   Marta     Ruiz     MARTARUIZ@GMAIL.COM   35    78000    Madrid    Yes
# 1    Luis    Lopez     LUISLOPEZ@GMAIL.COM   28    25000  Valencia     No
# 2     Ana  Santana    ANASANTANA@GMAIL.COM   35    50000    Malaga    Yes
# 3  Andres    Lopez   ANDRESLOPEZ@GMAIL.COM  NaN    17000     Cadiz     No
# 4  Monica   Romero  MONICACASTRO@GMAIL.COM   53    20000    Burgos    NaN
# 5     Ana    Perez     SARAPEREZ@GMAIL.COM   67    65000     Paris    Yes

# %%
#vamos a usar varios metodos muy utiles para cambiar datos de una DF
#como son: apply, map, applymap y replace
#por ejemplo queremos ver la longitud de los emails

df['email'].apply(len)
# Out:
# 0    19
# 1    19
# 2    20
# 3    21
# 4    22
# 5    19
# Name: email, dtype: int64

# %%
#el apply tambien se usa con funciones que creamos nosotros
def actualiza_email(email):
  return email.lower()

df['email'].apply(actualiza_email)
# Out:
# 0       martaruiz@gmail.com
# 1       luislopez@gmail.com
# 2      anasantana@gmail.com
# 3     andreslopez@gmail.com
# 4    monicacastro@gmail.com
# 5       saraperez@gmail.com
# Name: email, dtype: object

# %%
df['email'] = df['email'].apply(actualiza_email)

df
# Out:
#    nombre apellido                   email edad  salario    ciudad casado
# 0   Marta     Ruiz     martaruiz@gmail.com   35    78000    Madrid    Yes
# 1    Luis    Lopez     luislopez@gmail.com   28    25000  Valencia     No
# 2     Ana  Santana    anasantana@gmail.com   35    50000    Malaga    Yes
# 3  Andres    Lopez   andreslopez@gmail.com  NaN    17000     Cadiz     No
# 4  Monica   Romero  monicacastro@gmail.com   53    20000    Burgos    NaN
# 5     Ana    Perez     saraperez@gmail.com   67    65000     Paris    Yes

# %%
#vamos a trabajar con el apply para DF
# si utilizamos la sintaxis que usamos antes para series(una sola columna)
#no nos muestra lo que nosotros buscabamos que era el len de todos los
#valores del DF. Solo nos muestra que cada columna tiene 6 valores
#Para DF usamos otra funcion que se llama applymap

df.apply(len)
# Out:
# nombre      6
# apellido    6
# email       6
# edad        6
# salario     6
# ciudad      6
# casado      6
# dtype: int64

# %%
#vamos a usar la funcion applymap. Nos da error porque edad y salario era
#un integer, vamos a cambiar esos valores a strings

df.applymap(len)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-90-c1dcdb105fb8> in <cell line: 4>()
#       2 #un integer, vamos a cambiar esos valores a strings
#       3
# ----> 4 df.applymap(len)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in applymap(self, func, na_action, **kwargs)
#    9651             return lib.map_infer(x.astype(object)._values, func, ignore_na=ignore_na)
#    9652
# -> 9653         return self.apply(infer).__finalize__(self, "applymap")
#    9654
#    9655     # ----------------------------------------------------------------------
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in apply(self, func, axis, raw, result_type, args, **kwargs)
#    9566             kwargs=kwargs,
#    9567         )
# -> 9568         return op.apply().__finalize__(self, method="apply")
#    9569
#    9570     def applymap(
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/apply.py in apply(self)
#     762             return self.apply_raw()
#     763
# --> 764         return self.apply_standard()
#     765
#     766     def agg(self):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/apply.py in apply_standard(self)
#     889
#     890     def apply_standard(self):
# --> 891         results, res_index = self.apply_series_generator()
#     892
#     893         # wrap results
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/apply.py in apply_series_generator(self)
#     905             for i, v in enumerate(series_gen):
#     906                 # ignore SettingWithCopy here in case the user mutates
# --> 907                 results[i] = self.f(v)
#     908                 if isinstance(results[i], ABCSeries):
#     909                     # If we have a view on v, we need to make a copy because
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in infer(x)
#    9649             if x.empty:
#    9650                 return lib.map_infer(x, func, ignore_na=ignore_na)
# -> 9651             return lib.map_infer(x.astype(object)._values, func, ignore_na=ignore_na)
#    9652
#    9653         return self.apply(infer).__finalize__(self, "applymap")
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# TypeError: object of type 'int' has no len()

# %%
#creamos una nueva DataFrame con edad y salario en tipo string
gentestr={
    'nombre': ['Marta', 'Luis', 'Ana', 'Andres', 'Monica', 'Ana'],
    'apellido': ['Ruiz', 'Lopez', 'Santana', 'Lopez', 'Castro', 'Perez'],
    'email': ['martaruiz@gmail.com', 'luislopez@gmail.com', 'anasantana@gmail.com', 'andreslopez@gmail.com', 'monicacastro@gmail.com', 'saraperez@gmail.com'],
    'edad': ['35', '28', '35', 'NaN', '53', '67'],
    'salario': ['20000', '25000', '50000', '17000', '20000', '65000'],
    'ciudad' :['Madrid', 'Valencia', 'Malaga', 'Cadiz', 'Burgos', 'Madrid'],
    'casado': ['Yes', 'No', 'Yes', 'No', 'NaN', 'Yes']
}

#NaN =   not a number

# %%
df=pd.DataFrame(gentestr)

df
# Out:
#    nombre apellido                   email edad salario    ciudad casado
# 0   Marta     Ruiz     martaruiz@gmail.com   35   20000    Madrid    Yes
# 1    Luis    Lopez     luislopez@gmail.com   28   25000  Valencia     No
# 2     Ana  Santana    anasantana@gmail.com   35   50000    Malaga    Yes
# 3  Andres    Lopez   andreslopez@gmail.com  NaN   17000     Cadiz     No
# 4  Monica   Castro  monicacastro@gmail.com   53   20000    Burgos    NaN
# 5     Ana    Perez     saraperez@gmail.com   67   65000    Madrid    Yes

# %%
# ahora si podemos aplicar la funcion len() a toda la DF y nos da
#la longitud de todos los valores de la DF
df.applymap(len)
# Out:
#    nombre  apellido  email  edad  salario  ciudad  casado
# 0       5         4     19     2        5       6       3
# 1       4         5     19     2        5       8       2
# 2       3         7     20     2        5       6       3
# 3       6         5     21     3        5       5       2
# 4       6         6     22     2        5       6       3
# 5       3         5     19     2        5       6       3

# %%
#si queremos que todos los valores de la DF pasen a mayuscula

df.applymap(str.upper)
# Out:
#    nombre apellido                   email edad salario    ciudad casado
# 0   MARTA     RUIZ     MARTARUIZ@GMAIL.COM   35   20000    MADRID    YES
# 1    LUIS    LOPEZ     LUISLOPEZ@GMAIL.COM   28   25000  VALENCIA     NO
# 2     ANA  SANTANA    ANASANTANA@GMAIL.COM   35   50000    MALAGA    YES
# 3  ANDRES    LOPEZ   ANDRESLOPEZ@GMAIL.COM  NAN   17000     CADIZ     NO
# 4  MONICA   CASTRO  MONICACASTRO@GMAIL.COM   53   20000    BURGOS    NAN
# 5     ANA    PEREZ     SARAPEREZ@GMAIL.COM   67   65000    MADRID    YES

# %%
#para dejar los valores en minuscula

df.applymap(str.lower)
# Out:
#    nombre apellido                   email edad salario    ciudad casado
# 0   marta     ruiz     martaruiz@gmail.com   35   20000    madrid    yes
# 1    luis    lopez     luislopez@gmail.com   28   25000  valencia     no
# 2     ana  santana    anasantana@gmail.com   35   50000    malaga    yes
# 3  andres    lopez   andreslopez@gmail.com  nan   17000     cadiz     no
# 4  monica   castro  monicacastro@gmail.com   53   20000    burgos    nan
# 5     ana    perez     saraperez@gmail.com   67   65000    madrid    yes

# %%
#otra funcion que funciona solo con series es  map
#queremos que nos cambie dos valores de la columna nombre
#los nombres que no se han cambiado muestra NaN

df['nombre'].map({'Marta':'Sofia','Andres':'Sandalio'})
# Out:
# 0       Sofia
# 1         NaN
# 2         NaN
# 3    Sandalio
# 4         NaN
# 5         NaN
# Name: nombre, dtype: object

# %%
#podemos usar tambien la funcion replace

df['apellido'].replace({'Lopez': 'Santos', 'Perez': 'Salmeron'})
# Out:
# 0        Ruiz
# 1      Santos
# 2     Santana
# 3      Santos
# 4      Castro
# 5    Salmeron
# Name: apellido, dtype: object

# %%
#si vemos como queda la DF original vemos que los cambios de
#apellido solo eran temporales

df
# Out:
#    nombre apellido                   email edad salario    ciudad casado
# 0   Marta     Ruiz     martaruiz@gmail.com   35   20000    Madrid    Yes
# 1    Luis    Lopez     luislopez@gmail.com   28   25000  Valencia     No
# 2     Ana  Santana    anasantana@gmail.com   35   50000    Malaga    Yes
# 3  Andres    Lopez   andreslopez@gmail.com  NaN   17000     Cadiz     No
# 4  Monica   Castro  monicacastro@gmail.com   53   20000    Burgos    NaN
# 5     Ana    Perez     saraperez@gmail.com   67   65000    Madrid    Yes

# %%
#si queremos que los cambios de apellidos queden fijos en la DF
#original entonces haremos
df['apellido'] =df['apellido'].replace({'Lopez': 'Santos', 'Perez': 'Salmeron'})

df
# Out:
#    nombre  apellido                   email edad salario    ciudad casado
# 0   Marta      Ruiz     martaruiz@gmail.com   35   20000    Madrid    Yes
# 1    Luis    Santos     luislopez@gmail.com   28   25000  Valencia     No
# 2     Ana   Santana    anasantana@gmail.com   35   50000    Malaga    Yes
# 3  Andres    Santos   andreslopez@gmail.com  NaN   17000     Cadiz     No
# 4  Monica    Castro  monicacastro@gmail.com   53   20000    Burgos    NaN
# 5     Ana  Salmeron     saraperez@gmail.com   67   65000    Madrid    Yes

# %% [markdown]
# UNIDAD 6. AÑADIR Y QUITAR FILAS Y COLUMNAS DEL DF. COMBINAR INFORMACION

# %%
#para añadir columnas usamos

df['nombre'] + ' ' + df['apellido']
# Out:
# 0       Marta Ruiz
# 1      Luis Santos
# 2      Ana Santana
# 3    Andres Santos
# 4    Monica Castro
# 5     Ana Salmeron
# dtype: object

# %%
df['nombre_apellido'] = df['nombre']+ ' ' +df['apellido']

# %%
df
# Out:
#    nombre  apellido                   email edad salario    ciudad casado  \
# 0   Marta      Ruiz     martaruiz@gmail.com   35   20000    Madrid    Yes
# 1    Luis    Santos     luislopez@gmail.com   28   25000  Valencia     No
# 2     Ana   Santana    anasantana@gmail.com   35   50000    Malaga    Yes
# 3  Andres    Santos   andreslopez@gmail.com  NaN   17000     Cadiz     No
# 4  Monica    Castro  monicacastro@gmail.com   53   20000    Burgos    NaN
# 5     Ana  Salmeron     saraperez@gmail.com   67   65000    Madrid    Yes
#
#   nombre_apellido
# 0      Marta Ruiz
# 1     Luis Santos
# 2     Ana Santana
# 3   Andres Santos
# 4   Monica Castro
# 5    Ana Salmeron

# %%
#ahora vamos a quitar una columna. usamos la funcion drop

df.drop(columns= ['nombre', 'apellido'])
# Out:
#                     email edad salario    ciudad casado nombre_apellido
# 0     martaruiz@gmail.com   35   20000    Madrid    Yes      Marta Ruiz
# 1     luislopez@gmail.com   28   25000  Valencia     No     Luis Santos
# 2    anasantana@gmail.com   35   50000    Malaga    Yes     Ana Santana
# 3   andreslopez@gmail.com  NaN   17000     Cadiz     No   Andres Santos
# 4  monicacastro@gmail.com   53   20000    Burgos    NaN   Monica Castro
# 5     saraperez@gmail.com   67   65000    Madrid    Yes    Ana Salmeron

# %%
#como en casos anteriores vemos que no ha hecho el cambio permanente
df
# Out:
#    nombre  apellido                   email edad salario    ciudad casado  \
# 0   Marta      Ruiz     martaruiz@gmail.com   35   20000    Madrid    Yes
# 1    Luis    Santos     luislopez@gmail.com   28   25000  Valencia     No
# 2     Ana   Santana    anasantana@gmail.com   35   50000    Malaga    Yes
# 3  Andres    Santos   andreslopez@gmail.com  NaN   17000     Cadiz     No
# 4  Monica    Castro  monicacastro@gmail.com   53   20000    Burgos    NaN
# 5     Ana  Salmeron     saraperez@gmail.com   67   65000    Madrid    Yes
#
#   nombre_apellido
# 0      Marta Ruiz
# 1     Luis Santos
# 2     Ana Santana
# 3   Andres Santos
# 4   Monica Castro
# 5    Ana Salmeron

# %%
df.drop(columns= ['nombre', 'apellido'], inplace=True)

# %%
#al añadirle el inplace=True si se queda fijo el cambio realizado
df
# Out:
#                     email edad salario    ciudad casado nombre_apellido
# 0     martaruiz@gmail.com   35   20000    Madrid    Yes      Marta Ruiz
# 1     luislopez@gmail.com   28   25000  Valencia     No     Luis Santos
# 2    anasantana@gmail.com   35   50000    Malaga    Yes     Ana Santana
# 3   andreslopez@gmail.com  NaN   17000     Cadiz     No   Andres Santos
# 4  monicacastro@gmail.com   53   20000    Burgos    NaN   Monica Castro
# 5     saraperez@gmail.com   67   65000    Madrid    Yes    Ana Salmeron

# %%
#para revertir y convertir nombre_apellido en dos columnas una para
#nombre y otra para apellido, necesitamos la funcion split()
df['nombre_apellido'].str.split(' ')
# Out:
# 0       [Marta, Ruiz]
# 1      [Luis, Santos]
# 2      [Ana, Santana]
# 3    [Andres, Santos]
# 4    [Monica, Castro]
# 5     [Ana, Salmeron]
# Name: nombre_apellido, dtype: object

# %%
#para que pongamos estos datos en dos columnas necesitamos la funcion expand
df['nombre_apellido'].str.split(' ', expand=True)
# Out:
#         0         1
# 0   Marta      Ruiz
# 1    Luis    Santos
# 2     Ana   Santana
# 3  Andres    Santos
# 4  Monica    Castro
# 5     Ana  Salmeron

# %%
#ahora nos quedan cambiar los nombres a estas dos columnas
df[['nombre', 'apellido']] = df['nombre_apellido'].str.split(' ', expand=True)

# %%
df
# Out:
#                     email edad salario    ciudad casado nombre_apellido  \
# 0     martaruiz@gmail.com   35   20000    Madrid    Yes      Marta Ruiz
# 1     luislopez@gmail.com   28   25000  Valencia     No     Luis Santos
# 2    anasantana@gmail.com   35   50000    Malaga    Yes     Ana Santana
# 3   andreslopez@gmail.com  NaN   17000     Cadiz     No   Andres Santos
# 4  monicacastro@gmail.com   53   20000    Burgos    NaN   Monica Castro
# 5     saraperez@gmail.com   67   65000    Madrid    Yes    Ana Salmeron
#
#    nombre  apellido
# 0   Marta      Ruiz
# 1    Luis    Santos
# 2     Ana   Santana
# 3  Andres    Santos
# 4  Monica    Castro
# 5     Ana  Salmeron

# %%
#ahora vamos a poner una fila para una persona llamada Peter
df.append({'nombre':'Peter'}, ignore_index=True)
#Solo aparecera el nombre Peter añadido y NaN en las otras celdas, puedes
#añadir al diccionario los otros valores para llenar todas las celdas
#con informacion sobre Peter
# Out:
# <ipython-input-110-080c585d63e8>:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df.append({'nombre':'Peter'}, ignore_index=True)
#                     email edad salario    ciudad casado nombre_apellido  \
# 0     martaruiz@gmail.com   35   20000    Madrid    Yes      Marta Ruiz
# 1     luislopez@gmail.com   28   25000  Valencia     No     Luis Santos
# 2    anasantana@gmail.com   35   50000    Malaga    Yes     Ana Santana
# 3   andreslopez@gmail.com  NaN   17000     Cadiz     No   Andres Santos
# 4  monicacastro@gmail.com   53   20000    Burgos    NaN   Monica Castro
# 5     saraperez@gmail.com   67   65000    Madrid    Yes    Ana Salmeron
# 6                     NaN  NaN     NaN       NaN    NaN             NaN
#
#    nombre  apellido
# 0   Marta      Ruiz
# 1    Luis    Santos
# 2     Ana   Santana
# 3  Andres    Santos
# 4  Monica    Castro
# 5     Ana  Salmeron
# 6   Peter       NaN

# %%
#para quitar filas usamos los indices

df.drop(index=5)
#para eliminar mas filas de golpe hacemos
#df.drop(index=[3,4,5])
#para eliminar mas filas usando el slicing o rango de indices
#df=df.drop(df.index[1:4])
#df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-118-bceb3878f4d9> in <cell line: 3>()
#       1 #para quitar filas usamos los indices
#       2
# ----> 3 df.drop(index=5)
#       4 #para eliminar mas filas de golpe hacemos
#       5 #df.drop(index=[3,4,5])
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5397                 weight  1.0     0.8
#    5398         """
# -> 5399         return super().drop(
#    5400             labels=labels,
#    5401             axis=axis,
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4503         for axis, labels in axes.items():
#    4504             if labels is not None:
# -> 4505                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4506
#    4507         if inplace:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors, only_slice)
#    4544                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4545             else:
# -> 4546                 new_axis = axis.drop(labels, errors=errors)
#    4547             indexer = axis.get_indexer(new_axis)
#    4548
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    6932         if mask.any():
#    6933             if errors != "ignore":
# -> 6934                 raise KeyError(f"{list(labels[mask])} not found in axis")
#    6935             indexer = indexer[~mask]
#    6936         return self.delete(indexer)
#
# KeyError: '[5] not found in axis'

# %%
df=df.drop(df.index[1:3])

df
# Out:
#                  email edad salario  ciudad casado nombre_apellido nombre  \
# 0  martaruiz@gmail.com   35   20000  Madrid    Yes      Marta Ruiz  Marta
#
#   apellido
# 0     Ruiz

# %% [markdown]
# UNIDAD 7. CLASIFICAR DATOS

# %%
import pandas as pd
gente={
    'nombre': ['Marta', 'Luis', 'Ana', 'Andres', 'Monica', 'Ana'],
    'apellido': ['Ruiz', 'Lopez', 'Santana', 'Lopez', 'Castro', 'Perez'],
    'email': ['martaruiz@gmail.com', 'luislopez@gmail.com', 'anasantana@gmail.com', 'andreslopez@gmail.com', 'monicacastro@gmail.com', 'saraperez@gmail.com'],
    'edad': [35, 28, 35, 'NaN', 53, 67],
    'salario': [20000, 25000, 50000, 17000, 20000, 65000],
    'ciudad' :['Madrid', 'Valencia', 'Malaga', 'Cadiz', 'Burgos', 'Madrid'],
    'casado': ['Yes', 'No', 'Yes', 'No', 'NaN', 'Yes']
}

# %%
df=pd.DataFrame(gente)

df
# Out:
#    nombre apellido                   email edad  salario    ciudad casado
# 0   Marta     Ruiz     martaruiz@gmail.com   35    20000    Madrid    Yes
# 1    Luis    Lopez     luislopez@gmail.com   28    25000  Valencia     No
# 2     Ana  Santana    anasantana@gmail.com   35    50000    Malaga    Yes
# 3  Andres    Lopez   andreslopez@gmail.com  NaN    17000     Cadiz     No
# 4  Monica   Castro  monicacastro@gmail.com   53    20000    Burgos    NaN
# 5     Ana    Perez     saraperez@gmail.com   67    65000    Madrid    Yes

# %%
#vamos a ordenar

df.sort_values(by='nombre')
# Out:
#    nombre apellido                   email edad  salario    ciudad casado
# 2     Ana  Santana    anasantana@gmail.com   35    50000    Malaga    Yes
# 5     Ana    Perez     saraperez@gmail.com   67    65000    Madrid    Yes
# 3  Andres    Lopez   andreslopez@gmail.com  NaN    17000     Cadiz     No
# 1    Luis    Lopez     luislopez@gmail.com   28    25000  Valencia     No
# 0   Marta     Ruiz     martaruiz@gmail.com   35    20000    Madrid    Yes
# 4  Monica   Castro  monicacastro@gmail.com   53    20000    Burgos    NaN

# %%
#si queremos que esta vez sea en orden descendente

df.sort_values(by='nombre', ascending=False)
# Out:
#    nombre apellido                   email edad  salario    ciudad casado
# 4  Monica   Castro  monicacastro@gmail.com   53    20000    Burgos    NaN
# 0   Marta     Ruiz     martaruiz@gmail.com   35    20000    Madrid    Yes
# 1    Luis    Lopez     luislopez@gmail.com   28    25000  Valencia     No
# 3  Andres    Lopez   andreslopez@gmail.com  NaN    17000     Cadiz     No
# 2     Ana  Santana    anasantana@gmail.com   35    50000    Malaga    Yes
# 5     Ana    Perez     saraperez@gmail.com   67    65000    Madrid    Yes

# %%
#para ordenar los apellidos en orden ascendente y los nombres tambien hacemos
#esto y vemos que los nombres Andres y Luis, de los dos apellidos Lopez tambien estan en orden
#ascendente
df.sort_values(by=['apellido', 'nombre'])
# Out:
#    nombre apellido                   email edad  salario    ciudad casado
# 4  Monica   Castro  monicacastro@gmail.com   53    20000    Burgos    NaN
# 3  Andres    Lopez   andreslopez@gmail.com  NaN    17000     Cadiz     No
# 1    Luis    Lopez     luislopez@gmail.com   28    25000  Valencia     No
# 5     Ana    Perez     saraperez@gmail.com   67    65000    Madrid    Yes
# 0   Marta     Ruiz     martaruiz@gmail.com   35    20000    Madrid    Yes
# 2     Ana  Santana    anasantana@gmail.com   35    50000    Malaga    Yes

# %%
#si ahora queremos que los apellidos esten en orden descendente y los nombres
#en orden ascendente usamos booleanos
df.sort_values(by=['apellido', 'nombre'], ascending=[False, True])
# Out:
#    nombre apellido                   email edad  salario    ciudad casado
# 2     Ana  Santana    anasantana@gmail.com   35    50000    Malaga    Yes
# 0   Marta     Ruiz     martaruiz@gmail.com   35    20000    Madrid    Yes
# 5     Ana    Perez     saraperez@gmail.com   67    65000    Madrid    Yes
# 3  Andres    Lopez   andreslopez@gmail.com  NaN    17000     Cadiz     No
# 1    Luis    Lopez     luislopez@gmail.com   28    25000  Valencia     No
# 4  Monica   Castro  monicacastro@gmail.com   53    20000    Burgos    NaN

# %%
#de nuevo si queremos dejar fijos estos cambios añadiremos el inplace=True
#al final del parentesis y despues de una coma
#df.sort_values(by=['apellido', 'nombre'], ascending=[False, True], inplace=True)

# %%
#si queremos tener los indices ordenados otra vez 0, 1, 2, 3, etc,
#escribimos

df.sort_index()
# Out:
#    nombre apellido                   email edad  salario    ciudad casado
# 0   Marta     Ruiz     martaruiz@gmail.com   35    20000    Madrid    Yes
# 1    Luis    Lopez     luislopez@gmail.com   28    25000  Valencia     No
# 2     Ana  Santana    anasantana@gmail.com   35    50000    Malaga    Yes
# 3  Andres    Lopez   andreslopez@gmail.com  NaN    17000     Cadiz     No
# 4  Monica   Castro  monicacastro@gmail.com   53    20000    Burgos    NaN
# 5     Ana    Perez     saraperez@gmail.com   67    65000    Madrid    Yes

# %%
#si queremos ordenar los datos de una sola columna por ejemplo apellido

df['apellido'].sort_values()
# Out:
# 4     Castro
# 1      Lopez
# 3      Lopez
# 5      Perez
# 0       Ruiz
# 2    Santana
# Name: apellido, dtype: object

# %%
#si queremos ver solo los 3 salarios mas altos usamos otra
#funcion nlargest()

df['salario'].nlargest(3)
# Out:
# 5    65000
# 2    50000
# 1    25000
# Name: salario, dtype: int64

# %%
#para que nos muestre toda la informacion de esas personas con los 3
#salarios mas altos haremos

df.nlargest(3, 'salario')
# Out:
#   nombre apellido                 email edad  salario    ciudad casado
# 5    Ana    Perez   saraperez@gmail.com   67    65000    Madrid    Yes
# 2    Ana  Santana  anasantana@gmail.com   35    50000    Malaga    Yes
# 1   Luis    Lopez   luislopez@gmail.com   28    25000  Valencia     No

# %%
#si queremos hacer lo contrario

df.nsmallest(2, 'salario')
# Out:
#    nombre apellido                  email edad  salario  ciudad casado
# 3  Andres    Lopez  andreslopez@gmail.com  NaN    17000   Cadiz     No
# 0   Marta     Ruiz    martaruiz@gmail.com   35    20000  Madrid    Yes

# %% [markdown]
# UNIDAD 8. AGREGAR Y AGRUPAR DATOS

# %%
import pandas as pd


gentestr={
    'nombre': ['Marta', 'Luis', 'Ana', 'Andres', 'Monica', 'Ana', 'Rocio', 'Pepe'],
    'apellido': ['Ruiz', 'Lopez', 'Santana', 'Lopez', 'Castro', 'Perez', 'Iglesias', 'Fuentes'],
    'email': ['martaruiz@gmail.com', 'luislopez@gmail.com', 'anasantana@gmail.com', 'andreslopez@gmail.com',
    'monicacastro@gmail.com', 'saraperez@gmail.com', 'rocioiglesias@gmail.com', 'pepefuentes@gmail.com'],
    'edad': [35, 28, 35, 49, 53, 67, 73, 19],
    'salario': ['20000', '25000', '50000', '17000', '20000', '65000', '83000', '97000'],
    'ciudad' :['Madrid', 'Valencia', 'Malaga', 'Cadiz', 'Burgos', 'Madrid', 'Madrid', 'Madrid'],
    'casado': ['Yes', 'No', 'Yes', 'No', 'NaN', 'Yes', 'Yes', 'No']
}

# %%
df=pd.DataFrame(gentestr)

df
# Out:
#    nombre  apellido                    email  edad salario    ciudad casado
# 0   Marta      Ruiz      martaruiz@gmail.com    35   20000    Madrid    Yes
# 1    Luis     Lopez      luislopez@gmail.com    28   25000  Valencia     No
# 2     Ana   Santana     anasantana@gmail.com    35   50000    Malaga    Yes
# 3  Andres     Lopez    andreslopez@gmail.com    49   17000     Cadiz     No
# 4  Monica    Castro   monicacastro@gmail.com    53   20000    Burgos    NaN
# 5     Ana     Perez      saraperez@gmail.com    67   65000    Madrid    Yes
# 6   Rocio  Iglesias  rocioiglesias@gmail.com    73   83000    Madrid    Yes
# 7    Pepe   Fuentes    pepefuentes@gmail.com    19   97000    Madrid     No

# %%
#empezamos con funciones de agregacion, empezamos con la mediana de salarios
df['salario'].median()
# Out:
# 37500.0

# %%
#la moda o numero mas repetido de la lista
df['salario'].mode()
# Out:
# 0    20000
# Name: salario, dtype: object

# %%
#tambien podemos ver la mediana de todo el DF
df.median()
# Out:
# <ipython-input-28-e1ad2147fe65>:2: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.median()
# edad          42.0
# salario    37500.0
# dtype: float64

# %%
df.describe()
# Out:
#             edad
# count   8.000000
# mean   44.875000
# std    18.946824
# min    19.000000
# 25%    33.250000
# 50%    42.000000
# 75%    56.500000
# max    73.000000

# %%
#la funcion count() nos da el numero de personas que contestan
df['casado'].count()
# Out:
# 8

# %%
#para saber cuantos contestaron Yes y cuantos No usamos otra funcion
df['casado'].value_counts()
# Out:
# Yes    4
# No     3
# NaN    1
# Name: casado, dtype: int64

# %%
#si queremos ver cual es la ciudad mas comun en nuestro DF
df['ciudad'].value_counts()
# Out:
# Madrid      4
# Valencia    1
# Malaga      1
# Cadiz       1
# Burgos      1
# Name: ciudad, dtype: int64

# %%
#si queremos ver los resultados anteriores pero en porcentajes usamos
#la funcion normalize
df['ciudad'].value_counts(normalize=True)
# Out:
# Madrid      0.500
# Valencia    0.125
# Malaga      0.125
# Cadiz       0.125
# Burgos      0.125
# Name: ciudad, dtype: float64

# %%
#vamos a ver otras funciones de agregacion como groupby() y get_group()

df.groupby(['ciudad'])

# %%
ciudad_grupo=df.groupby(['ciudad'])

# %%
#queremos que nos agregue toda la informacion que tiene la ciudad Madrid
ciudad_grupo.get_group('Madrid')
# Out:
#   nombre  apellido                    email  edad salario  ciudad casado
# 0  Marta      Ruiz      martaruiz@gmail.com    35   20000  Madrid    Yes
# 5    Ana     Perez      saraperez@gmail.com    67   65000  Madrid    Yes
# 6  Rocio  Iglesias  rocioiglesias@gmail.com    73   83000  Madrid    Yes
# 7   Pepe   Fuentes    pepefuentes@gmail.com    19   97000  Madrid     No

# %%
#deberiamos obtener el mismo resultado creando una variable filt como
#hicimos anteriormente

filt = df['ciudad'] == 'Madrid'
df.loc[filt]
# Out:
#   nombre  apellido                    email  edad salario  ciudad casado
# 0  Marta      Ruiz      martaruiz@gmail.com    35   20000  Madrid    Yes
# 5    Ana     Perez      saraperez@gmail.com    67   65000  Madrid    Yes
# 6  Rocio  Iglesias  rocioiglesias@gmail.com    73   83000  Madrid    Yes
# 7   Pepe   Fuentes    pepefuentes@gmail.com    19   97000  Madrid     No

# %%
#si del grupo anterior solo nos interesa ahora saber los salarios que
#algunas personas ganan en Madrid usaremos

filt = df['ciudad'] == 'Madrid'
df.loc[filt]['salario'].value_counts()
# Out:
# 20000    1
# 65000    1
# 83000    1
# 97000    1
# Name: salario, dtype: int64

# %%
#queremos saber cuantas personas de Madrid tienen la letra Y en la respuesta
#sobre si estan casados o no. usamos funcion contains() y la funcion sum()
filt=df['ciudad']== 'Madrid'
df.loc[filt]['casado'].str.contains('Y').sum()
# Out:
# 3

# %%
#si queremos ver cuantas personas tienen la letra 'o' en su respuesta
filt=df['ciudad']== 'Madrid'
df.loc[filt]['casado'].str.contains('o').sum()
# Out:
# 1

# %%
#si queremos ver cuantas personas en la ciudad de Madrid tienen la letra 'u' en
#su apellido
filt=df['ciudad']== 'Madrid'
df.loc[filt]['apellido'].str.contains('u').sum()
# Out:
# 2

# %%
#muestra en pantalla los nombres de las personas de Madrid cuyos apellidos
#contienen una letra 'i'
filt = (df['ciudad'] == 'Madrid') & df['apellido'].str.contains('I', case=False)
nombre_filtro = df.loc[filt, 'nombre']
nombre_filtro
# Out:
# 0    Marta
# 6    Rocio
# Name: nombre, dtype: object

# %%
#muestra en pantalla los nombres de las personas de Madrid cuyos apellidos
#contienen una letra 'i' y tambien tienen mas de 50 años
filt = (df['ciudad'] == 'Madrid') & (df['edad']>50) & df['apellido'].str.contains('I', case=False)
nombre_filtro = df.loc[filt, 'nombre']
nombre_filtro
# Out:
# 6    Rocio
# Name: nombre, dtype: object

# %% [markdown]
# UNIDAD 9. LIMPIEZA DE DATOS

# %%
import pandas as pd

# %%
gentelimp={
    'nombre': ['Marta', 'Luis', 'Ana', 'Andres', None, 'Ana'],
    'apellido': ['Ruiz', 'Lopez', 'Santana', None, 'Castro', 'Perez'],
    'email': ['martaruiz@gmail.com', 'luislopez@gmail.com', 'anasantana@gmail.com', 'andreslopez@gmail.com', None, 'saraperez@gmail.com'],
    'edad': [35, 28, 35, 49, 53, 67],
    'salario': [20000, 25000, None, 17000, 20000, 65000],
    'ciudad' :['Madrid', 'Valencia', 'Malaga', 'Cadiz', 'Burgos', None],
    'casado': ['Yes', 'No', 'Yes', 'No', None, None]
}

# %%
df=pd.DataFrame(gentelimp)

df
# Out:
#    nombre apellido                  email  edad  salario    ciudad casado
# 0   Marta     Ruiz    martaruiz@gmail.com    35  20000.0    Madrid    Yes
# 1    Luis    Lopez    luislopez@gmail.com    28  25000.0  Valencia     No
# 2     Ana  Santana   anasantana@gmail.com    35      NaN    Malaga    Yes
# 3  Andres     None  andreslopez@gmail.com    49  17000.0     Cadiz     No
# 4    None   Castro                   None    53  20000.0    Burgos   None
# 5     Ana    Perez    saraperez@gmail.com    67  65000.0      None   None

# %%
#algunas veces los mejor es eliminar las filas que contienen
#datos sucios o faltantes. vamos a usar la funcion dropna()
#drop (suprimir) na (not available o no disponible)

df.dropna()
# Out:
#   nombre apellido                email  edad  salario    ciudad casado
# 0  Marta     Ruiz  martaruiz@gmail.com    35  20000.0    Madrid    Yes
# 1   Luis    Lopez  luislopez@gmail.com    28  25000.0  Valencia     No

# %%
#para entender como funciona la funcion dropna() vamos a usar una sintaxis
#mas completa y vemos que nos da el mismo resultado que antes. 'axis' puede ser
#igual a  'index' para referirse a filas o a 'columns' para referirse a columnas
#'how' puede ser 'any' es decir con que haya una sola celda con None elimina toda
#la fila o columna y 'how' tambien puede ser 'all' en cuyo caso solo elimina
#la fila o la columna si todas las celdas tienen None

df.dropna(axis='index', how='any')
# Out:
#   nombre apellido                email  edad  salario    ciudad casado
# 0  Marta     Ruiz  martaruiz@gmail.com    35  20000.0    Madrid    Yes
# 1   Luis    Lopez  luislopez@gmail.com    28  25000.0  Valencia     No

# %%
df.dropna(axis='columns', how='any')
# Out:
#    edad
# 0    35
# 1    28
# 2    35
# 3    49
# 4    53
# 5    67

# %%
df.dropna(axis='index', how='all')
# Out:
#    nombre apellido                  email  edad  salario    ciudad casado
# 0   Marta     Ruiz    martaruiz@gmail.com    35  20000.0    Madrid    Yes
# 1    Luis    Lopez    luislopez@gmail.com    28  25000.0  Valencia     No
# 2     Ana  Santana   anasantana@gmail.com    35      NaN    Malaga    Yes
# 3  Andres     None  andreslopez@gmail.com    49  17000.0     Cadiz     No
# 4    None   Castro                   None    53  20000.0    Burgos   None
# 5     Ana    Perez    saraperez@gmail.com    67  65000.0      None   None

# %%
#vamos a eliminar filas o columnas que no tengan emails ya que consideramos
#imprescindible que tengan el email como minimo
#vamos a usar otro parametro que se llama 'subset'

df.dropna(axis='index', how='any', subset = ['email'])
# Out:
#    nombre apellido                  email  edad  salario    ciudad casado
# 0   Marta     Ruiz    martaruiz@gmail.com    35  20000.0    Madrid    Yes
# 1    Luis    Lopez    luislopez@gmail.com    28  25000.0  Valencia     No
# 2     Ana  Santana   anasantana@gmail.com    35      NaN    Malaga    Yes
# 3  Andres     None  andreslopez@gmail.com    49  17000.0     Cadiz     No
# 5     Ana    Perez    saraperez@gmail.com    67  65000.0      None   None

# %%
#podemos pasarle varias columnas a la funcion 'subset'
df.dropna(axis='index', how='any', subset = ['email', 'casado'])
# Out:
#    nombre apellido                  email  edad  salario    ciudad casado
# 0   Marta     Ruiz    martaruiz@gmail.com    35  20000.0    Madrid    Yes
# 1    Luis    Lopez    luislopez@gmail.com    28  25000.0  Valencia     No
# 2     Ana  Santana   anasantana@gmail.com    35      NaN    Malaga    Yes
# 3  Andres     None  andreslopez@gmail.com    49  17000.0     Cadiz     No

# %%
#si tanto email como casado tiene que ser None entonces usaremos
#el how='all'

df.dropna(axis='index', how='all', subset = ['email', 'casado'])
# Out:
#    nombre apellido                  email edad salario    ciudad casado
# 0   Marta     Ruiz    martaruiz@gmail.com   35   20000    Madrid    Yes
# 1    Luis    Lopez    luislopez@gmail.com   28   25000  Valencia     No
# 2     Ana  Santana   anasantana@gmail.com   35    None    Malaga    Yes
# 3  Andres    Lopez  andreslopez@gmail.com   49   17000     Cadiz     No
# 5     Ana    Perez    saraperez@gmail.com   67   65000    Madrid   None

# %%
import pandas as pd

gentelimp2={
    'nombre': ['Marta', 'Luis', 'Ana', 'Andres', None, 'Ana'],
    'apellido': ['Ruiz', 'Lopez', 'Santana', None, 'Castro', 'Perez'],
    'email': ['martaruiz@gmail.com', 'luislopez@gmail.com', 'anasantana@gmail.com', 'andreslopez@gmail.com', None, 'saraperez@gmail.com'],
    'edad': [35, 28, 35, 49, 53, 67],
    'salario': [20000, 25000, None, 17000, 20000, 65000],
    'ciudad' :['Madrid', 'Valencia', 'Malaga', 'Cadiz', 'Burgos', None],
    'casado': ['Yes', 'No', 'Yes', 'No','Missing', 'None']
}

# %%
df=pd.DataFrame(gentelimp2)

df
# Out:
#    nombre apellido                  email  edad  salario    ciudad   casado
# 0   Marta     Ruiz    martaruiz@gmail.com    35  20000.0    Madrid      Yes
# 1    Luis    Lopez    luislopez@gmail.com    28  25000.0  Valencia       No
# 2     Ana  Santana   anasantana@gmail.com    35      NaN    Malaga      Yes
# 3  Andres     None  andreslopez@gmail.com    49  17000.0     Cadiz       No
# 4    None   Castro                   None    53  20000.0    Burgos  Missing
# 5     Ana    Perez    saraperez@gmail.com    67  65000.0      None     None

# %%
#si queremos substituir los 'Missing' y los 'NA' por None lo
#podemos hacer asi
df.replace('na', None)
df.replace('Missing', None)
# Out:
#    nombre apellido                  email  edad  salario    ciudad casado
# 0   Marta     Ruiz    martaruiz@gmail.com    35  20000.0    Madrid    Yes
# 1    Luis    Lopez    luislopez@gmail.com    28  25000.0  Valencia     No
# 2     Ana  Santana   anasantana@gmail.com    35      NaN    Malaga    Yes
# 3  Andres     None  andreslopez@gmail.com    49  17000.0     Cadiz     No
# 4    None   Castro                   None    53  20000.0    Burgos   None
# 5     Ana    Perez    saraperez@gmail.com    67  65000.0      None   None

# %%
#si queremos ver que celdas tienen datos faltantes o extraños podemos
#usar la funcion isna()

df.isna()
# Out:
#    nombre  apellido  email   edad  salario  ciudad  casado
# 0   False     False  False  False    False   False   False
# 1   False     False  False  False    False   False   False
# 2   False     False  False  False     True   False   False
# 3   False      True  False  False    False   False   False
# 4    True     False   True  False    False   False   False
# 5   False     False  False  False    False    True   False

# %%
#si queremos llenar los None (que previamente, hemos cambiado con el replace
#no olvidar inplace=True),
#con algun tipo de datos por ejemplo con NO SABE NO CONTESTA. usamos la funcion
#fillna()


df.fillna('NSNC')
# Out:
#    nombre apellido                  email  edad  salario    ciudad   casado
# 0   Marta     Ruiz    martaruiz@gmail.com    35  20000.0    Madrid      Yes
# 1    Luis    Lopez    luislopez@gmail.com    28  25000.0  Valencia       No
# 2     Ana  Santana   anasantana@gmail.com    35     NSNC    Malaga      Yes
# 3  Andres     NSNC  andreslopez@gmail.com    49  17000.0     Cadiz       No
# 4    NSNC   Castro                   NSNC    53  20000.0    Burgos  Missing
# 5     Ana    Perez    saraperez@gmail.com    67  65000.0      NSNC     None

# %%
#otra cosa que podemos hacer es ver si nuestras celdas tienen un string
#o un integer, es decir queremos saber el tipo de dato. object es lo
#mismo que string en Pandas

df.dtypes
# Out:
# nombre       object
# apellido     object
# email        object
# edad          int64
# salario     float64
# ciudad       object
# casado       object
# dtype: object

# %%
df['edad']=df['edad'].astype(int)

# %%
#podiamos haberlo cambiado a un float tambien
df.dtypes
# Out:
# nombre       object
# apellido     object
# email        object
# edad          int64
# salario     float64
# ciudad       object
# casado       object
# dtype: object

# %%
#ahora podemos calcular la media de edad de la DF

df['edad'].mean()
# Out:
# 44.5

# %%
#existe otra funcion unique() para saber cuantos diferentes tipos de datos puede
#tener una columna por ejemplo, vamos a verlo para la columna 'casado'
df['casado'].unique()
# Out:
# array(['Yes', 'No', None], dtype=object)
