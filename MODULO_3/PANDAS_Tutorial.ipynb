# %% [markdown]
# ### <u>***UNIDAD 1. DESCARGAR BASES DE DATOS E INFORMACION BASICA DE LA BASE DE DATOS***</u>

# %% [markdown]
# Pandas es la librería más popular de Python para el análisis de datos.
#
# En Pandas, hay dos objetos principales: el ***DataFrame*** y la ***Serie***.
#
# Un ***DataFrame*** es una tabla. Contiene un array de entradas individuales, cada una de las cuales tiene un valor determinado. Cada entrada corresponde a una fila (o registro) y a una columna. Al final es como una tabla de una base de datos.

# %%
# Importamos la librería de Pandas

import pandas as pd

# %% [markdown]
# A continuación, creamos un dataframe a partir de un archivo de excel, usando un método de Pandas llamado <code>read_csv()</code>. El primer parámetro es el nombre del archivo del que vamos a leer, y el segundo parámetro se indica para eliminar la columna de indice que por defecto nos da un dataframe.
#
# Podeis realizar vuestras pruebas quitando y poniendo parámetros.
#
# Mas info en la web de [Pandas](https://pandas.pydata.org/docs/reference/api/pandas.read_csv.html)
#
#
# ---

# %%
# (Descargar archivo del projecto de Github)

df=pd.read_csv('Advertising.csv', index_col=0)
df
# Out:
#         TV  Radio  Newspaper  Sales
# 1    230.1   37.8       69.2   22.1
# 2     44.5   39.3       45.1   10.4
# 3     17.2   45.9       69.3    9.3
# 4    151.5   41.3       58.5   18.5
# 5    180.8   10.8       58.4   12.9
# ..     ...    ...        ...    ...
# 196   38.2    3.7       13.8    7.6
# 197   94.2    4.9        8.1    9.7
# 198  177.0    9.3        6.4   12.8
# 199  283.6   42.0       66.2   25.5
# 200  232.1    8.6        8.7   13.4
#
# [200 rows x 4 columns]

# %% [markdown]
# Creamos otro dataframe a partir de un archivo csv utilizando, de nuevo, el método de Pandas <code>read_csv()</code>.
#
# También podemos leer de otros muchos tipos de archivos (*excel, json, sql, html, xml, sas, etc...*), para crear un dataframe.
#
# Mas info en [Pandas](https://pandas.pydata.org/docs/reference/io.html)

# %%
# (Descargar archivo del projecto de Github)

df= pd.read_csv('ds_salaries.csv')

df
# Out:
#       work_year experience_level employment_type                  job_title  \
# 0          2023               EN              FT          Applied Scientist
# 1          2023               EN              FT          Applied Scientist
# 2          2023               EN              FT       Data Quality Analyst
# 3          2023               EN              FT    Compliance Data Analyst
# 4          2023               EN              FT          Applied Scientist
# ...         ...              ...             ...                        ...
# 3756       2020               SE              FT   Principal Data Scientist
# 3757       2020               SE              FT             Data Scientist
# 3758       2020               SE              FT       Data Science Manager
# 3759       2020               SE              FT  Machine Learning Engineer
# 3760       2020               SE              FT             Data Scientist
#
#       salary salary_currency  salary_in_usd company_location company_size
# 0     213660             USD         213660               US            L
# 1     130760             USD         130760               US            L
# 2     100000             USD         100000               NG            L
# 3      30000             USD          30000               NG            L
# 4     204620             USD         204620               US            L
# ...      ...             ...            ...              ...          ...
# 3756  130000             EUR         148261               DE            M
# 3757   80000             EUR          91237               AT            S
# 3758  190200             USD         190200               US            M
# 3759   40000             EUR          45618               HR            S
# 3760  412000             USD         412000               US            L
#
# [3761 rows x 9 columns]

# %% [markdown]
# ---
#
#
#
# Para ver el numero de filas y columnas usamos la propiedad de Pandas <code>shape</code>

# %%
df.shape
# Out:
# (3761, 9)

# %% [markdown]
# ---
#
#
# Podemos ver el dataframe completo usando el método <code>to_string()</code>.
#
# Este método muestra un DataFrame en una salida tabular amigable para la consola.

# %%
# Para poder ver la DF completa usamos el método to_string()

print(df.to_string())
# Out:
#       work_year experience_level employment_type                                 job_title    salary salary_currency  salary_in_usd company_location company_size
# 0          2023               EN              FT                         Applied Scientist    213660             USD         213660               US            L
# 1          2023               EN              FT                         Applied Scientist    130760             USD         130760               US            L
# 2          2023               EN              FT                      Data Quality Analyst    100000             USD         100000               NG            L
# 3          2023               EN              FT                   Compliance Data Analyst     30000             USD          30000               NG            L
# 4          2023               EN              FT                         Applied Scientist    204620             USD         204620               US            L
# 5          2023               EN              FT                         Applied Scientist    110680             USD         110680               US            L
# 6          2023               EN              FT                 Machine Learning Engineer    163196             USD         163196               US            M
# 7          2023               EN              FT                 Machine Learning Engineer    145885             USD         145885               US            M
# 8          2023               EN              FT                        Research Scientist    220000             USD         220000               US            L
# 9          2023               EN              FT                             Data Engineer     85000             USD          85000               US            M
# 10         2023               EN              FT                             Data Engineer     65000             USD          65000               US            M
# 11         2023               EN              FT                              Data Analyst     75000             USD          75000               US            M
# 12         2023               EN              FT                              Data Analyst     70000             USD          70000               US            M
# 13         2023               EN              FT                              Data Analyst     85000             USD          85000               US            M
# 14         2023               EN              FT                              Data Analyst     75000             USD          75000               US            M
# 15         2023               EN              FT                             Data Engineer   1400000             INR          17022               IN            L
# 16         2023               EN              FT                             Data Engineer     85000             USD          85000               US            M
# 17         2023               EN              FT                             Data Engineer     65000             USD          65000               US            M
# 18         2023               EN              FT                              Data Analyst     55000             CAD          40663               CA            L
# 19         2023               EN              FT                            Data Scientist     70000             CAD          51753               CA            L
# 20         2023               EN              FT                            Data Scientist    130001             USD         130001               US            M
# 21         2023               EN              FT                            Data Scientist     71907             USD          71907               US            M
# 22         2023               EN              FT                             Data Engineer     85000             USD          85000               US            M
# 23         2023               EN              FT                             Data Engineer     65000             USD          65000               US            M
# 24         2023               EN              FT                         Applied Scientist    213660             USD         213660               US            L
# 25         2023               EN              FT                         Applied Scientist    130760             USD         130760               US            L
# 26         2023               EN              FT                          BI Data Engineer     60000             USD          60000               US            M
# 27         2023               EN              FT                             Data Engineer     85000             USD          85000               US            M
# 28         2023               EN              FT                             Data Engineer     65000             USD          65000               US            M
# 29         2023               EN              FT                         Research Engineer    155000             USD         155000               US            M
# 30         2023               EN              FT                         Research Engineer    125000             USD         125000               US            M
# 31         2023               EN              FT                         Research Engineer    155000             USD         155000               US            M
# 32         2023               EN              FT                         Research Engineer    125000             USD         125000               US            M
# 33         2023               EN              FT                              Data Analyst     64200             USD          64200               US            M
# 34         2023               EN              FT                              Data Analyst     56100             USD          56100               US            M
# 35         2023               EN              FT                             Data Engineer     92700             USD          92700               US            M
# 36         2023               EN              FT                             Data Engineer     61800             USD          61800               US            M
# 37         2023               EN              FT                     Business Data Analyst     20000             EUR          21461               ES            M
# 38         2023               EN              FT                         Research Engineer    160000             USD         160000               US            M
# 39         2023               EN              FT                         Research Engineer    120000             USD         120000               US            M
# 40         2023               EN              FT             Autonomous Vehicle Technician      7000             USD           7000               GH            S
# 41         2023               EN              FT        Applied Machine Learning Scientist     40000             EUR          42923               DE            M
# 42         2023               EN              FT                            Data Scientist    190000             USD         190000               US            M
# 43         2023               EN              FT                            Data Scientist    120000             USD         120000               US            M
# 44         2023               EN              FT                            Data Scientist    112000             CHF         121093               CH            L
# 45         2023               EN              FT                              Data Analyst     85000             USD          85000               US            M
# 46         2023               EN              FT                              Data Analyst     75000             USD          75000               US            M
# 47         2023               EN              FT                             Data Engineer     92700             USD          92700               US            M
# 48         2023               EN              FT                             Data Engineer     61800             USD          61800               US            M
# 49         2023               EN              FT                             Data Engineer     62000             USD          62000               US            M
# 50         2023               EN              FT                             Data Engineer     58000             USD          58000               US            M
# 51         2023               EN              FT                             Data Engineer    125000             USD         125000               US            M
# 52         2023               EN              FT                             Data Engineer     90000             USD          90000               US            M
# 53         2023               EN              FT                              Data Analyst     95000             USD          95000               US            M
# 54         2023               EN              FT                              Data Analyst     70000             USD          70000               US            M
# 55         2023               EN              FT                             Data Engineer    115100             USD         115100               US            M
# 56         2023               EN              FT                             Data Engineer     73900             USD          73900               US            M
# 57         2023               EN              FT                             AI Programmer     70000             USD          70000               AU            L
# 58         2023               EN              FT                              AI Developer     80000             USD          80000               SE            M
# 59         2023               EN              FT                        Research Scientist    150000             USD         150000               US            M
# 60         2023               EN              FT                        Research Scientist    100000             USD         100000               US            M
# 61         2023               EN              FT                              Data Analyst     75000             USD          75000               US            M
# 62         2023               EN              FT                              Data Analyst     60000             USD          60000               US            M
# 63         2023               EN              FT                             Data Engineer    125000             USD         125000               US            M
# 64         2023               EN              FT                             Data Engineer     90000             USD          90000               US            M
# 65         2023               EN              FT                              AI Developer    200000             EUR         214618               DE            L
# 66         2023               EN              FT                              Data Analyst    100000             USD         100000               US            L
# 67         2023               EN              FT                              Data Analyst    150000             USD         150000               US            M
# 68         2023               EN              FT                              Data Analyst    100000             USD         100000               US            M
# 69         2023               EN              FT                        Research Scientist    150000             USD         150000               US            M
# 70         2023               EN              FT                        Research Scientist    100000             USD         100000               US            M
# 71         2023               EN              FT                              Data Analyst     85000             USD          85000               US            M
# 72         2023               EN              FT                              Data Analyst     75000             USD          75000               US            M
# 73         2023               EN              FT                              Data Analyst     30000             USD          30000               IN            M
# 74         2023               EN              FT                  Computer Vision Engineer    220000             USD         220000               US            M
# 75         2023               EN              FT                              AI Developer     60000             EUR          64385               DE            M
# 76         2023               EN              FT                              Data Analyst     55000             USD          55000               US            M
# 77         2023               EN              FT                              Data Analyst     48000             USD          48000               US            M
# 78         2023               EN              PT                              Data Analyst     78000             PLN          17779               IN            L
# 79         2023               EN              FT                            Data Scientist    101400             BRL          19522               BR            L
# 80         2023               EN              FT                              Data Analyst     75000             USD          75000               US            M
# 81         2023               EN              FT                              Data Analyst     60000             USD          60000               US            M
# 82         2023               EN              FT                         Research Engineer    120000             USD         120000               GB            M
# 83         2023               EN              FT                         Research Engineer     60000             USD          60000               GB            M
# 84         2023               EN              FT                              Data Analyst     60000             USD          60000               US            L
# 85         2023               EN              FT                              Data Analyst     50000             USD          50000               US            L
# 86         2023               EN              FT                            Data Scientist    800000             INR           9727               IN            L
# 87         2023               EN              FT                              Data Analyst     85000             USD          85000               US            M
# 88         2023               EN              FT                              Data Analyst     75000             USD          75000               US            M
# 89         2023               EN              FT                             Data Engineer     12000             USD          12000               VN            L
# 90         2023               EN              FT                              Data Analyst     55000             USD          55000               US            M
# 91         2023               EN              FT                              Data Analyst     48000             USD          48000               US            M
# 92         2023               EN              FT                              Data Analyst    100000             USD         100000               US            M
# 93         2023               EN              FT                            Data Scientist    110000             USD         110000               US            S
# 94         2023               EN              FT                            Data Scientist   1050000             INR          12767               IN            L
# 95         2023               EN              FT                             Data Engineer     25000             EUR          26827               DE            L
# 96         2023               EN              FT                              BI Developer    160000             USD         160000               US            M
# 97         2023               EN              FT                              BI Developer    100000             USD         100000               US            M
# 98         2023               EN              FT                         Big Data Engineer    130000             USD         130000               SE            S
# 99         2023               EN              FT                             Data Engineer    160000             USD         160000               US            M
# 100        2023               EN              FT                             Data Engineer    135000             USD         135000               US            M
# 101        2023               EN              FT                              Data Analyst     30000             USD          30000               US            S
# 102        2023               EN              FT                            Data Scientist    124234             USD         124234               US            M
# 103        2023               EN              FT                            Data Scientist     74540             USD          74540               US            M
# 104        2023               EN              FT                            Data Scientist   1060000             INR          12888               IN            S
# 105        2023               EN              FT                              AI Developer    120000             USD         120000               BA            S
# 106        2023               EN              FT                     Business Data Analyst     12000             EUR          12877               GR            L
# 107        2023               EN              FT                             Data Engineer    160000             USD         160000               US            M
# 108        2023               EN              FT                             Data Engineer    135000             USD         135000               US            M
# 109        2023               EN              FT                            Data Scientist     50000             USD          50000               US            M
# 110        2023               EN              FT                             Data Engineer    160000             USD         160000               US            M
# 111        2023               EN              FT                             Data Engineer    135000             USD         135000               US            M
# 112        2023               EN              FT                         Research Engineer    160000             USD         160000               US            M
# 113        2023               EN              FT                         Research Engineer    120000             USD         120000               US            M
# 114        2023               EN              FT                    Deep Learning Engineer    150000             USD         150000               US            M
# 115        2023               EN              FT                    Deep Learning Engineer    120000             USD         120000               US            M
# 116        2023               EN              FT                             Data Engineer    160000             USD         160000               US            M
# 117        2023               EN              FT                             Data Engineer    135000             USD         135000               US            M
# 118        2023               EX              FT                            Data Scientist    258750             USD         258750               US            M
# 119        2023               EX              FT                            Data Scientist    185000             USD         185000               US            M
# 120        2023               EX              FT                             Data Engineer    220000             USD         220000               US            M
# 121        2023               EX              FT                             Data Engineer    205000             USD         205000               US            M
# 122        2023               EX              FT                              Head of Data    329500             USD         329500               US            M
# 123        2023               EX              FT                              Head of Data    269600             USD         269600               US            M
# 124        2023               EX              FT                             Data Engineer    145000             USD         145000               US            M
# 125        2023               EX              FT                             Data Engineer    115000             USD         115000               US            M
# 126        2023               EX              FT                             Data Engineer    175000             USD         175000               US            M
# 127        2023               EX              FT                             Data Engineer    110000             USD         110000               US            M
# 128        2023               EX              FT                        Analytics Engineer    221000             USD         221000               US            M
# 129        2023               EX              FT                        Analytics Engineer    153000             USD         153000               US            M
# 130        2023               EX              FT                            Data Scientist    200000             USD         200000               US            M
# 131        2023               EX              FT                            Data Scientist    145000             USD         145000               US            M
# 132        2023               EX              FT                            Data Architect    180000             USD         180000               US            M
# 133        2023               EX              FT                            Data Architect    155000             USD         155000               US            M
# 134        2023               EX              FT                             Data Engineer    286000             USD         286000               US            M
# 135        2023               EX              FT                             Data Engineer    207000             USD         207000               US            M
# 136        2023               EX              FT                  Director of Data Science    353200             USD         353200               US            M
# 137        2023               EX              FT                  Director of Data Science    249300             USD         249300               US            M
# 138        2023               EX              FT                            Data Scientist    145000             USD         145000               US            M
# 139        2023               EX              FT                            Data Scientist    100000             USD         100000               US            M
# 140        2023               EX              FT                             Data Engineer    265000             USD         265000               US            M
# 141        2023               EX              FT                             Data Engineer    235000             USD         235000               US            M
# 142        2023               EX              FT                             Data Engineer    194500             USD         194500               US            M
# 143        2023               EX              FT                             Data Engineer    115500             USD         115500               US            M
# 144        2023               EX              FT                            Data Scientist    200000             USD         200000               US            M
# 145        2023               EX              FT                            Data Scientist    145000             USD         145000               US            M
# 146        2023               EX              FT                             Data Engineer    210914             USD         210914               US            M
# 147        2023               EX              FT                             Data Engineer    116704             USD         116704               US            M
# 148        2023               EX              FT                             Data Engineer    167500             USD         167500               US            M
# 149        2023               EX              FT                             Data Engineer    106500             USD         106500               US            M
# 150        2023               EX              FT                             Data Engineer    310000             USD         310000               US            M
# 151        2023               EX              FT                             Data Engineer    239000             USD         239000               US            M
# 152        2023               EX              FT                             Data Engineer    310000             USD         310000               US            M
# 153        2023               EX              FT                             Data Engineer    239000             USD         239000               US            M
# 154        2023               EX              FT                      Head of Data Science    131899             GBP         160288               GB            M
# 155        2023               EX              FT                      Head of Data Science    104891             GBP         127467               GB            M
# 156        2023               EX              FT                             Data Engineer    310000             USD         310000               US            M
# 157        2023               EX              FT                             Data Engineer    239000             USD         239000               US            M
# 158        2023               EX              FT                             Data Engineer    235000             USD         235000               US            M
# 159        2023               EX              FT                             Data Engineer    210000             USD         210000               US            M
# 160        2023               EX              FT                             Data Engineer    210914             USD         210914               US            M
# 161        2023               EX              FT                             Data Engineer    116704             USD         116704               US            M
# 162        2023               EX              FT                             Data Engineer    284000             USD         284000               US            M
# 163        2023               EX              FT                             Data Engineer    236000             USD         236000               US            M
# 164        2023               EX              FT                    Data Analytics Manager    155000             USD         155000               US            M
# 165        2023               EX              FT                    Data Analytics Manager    140000             USD         140000               US            M
# 166        2023               EX              FT                             Data Engineer    175000             USD         175000               US            M
# 167        2023               EX              FT                             Data Engineer    110000             USD         110000               US            M
# 168        2023               EX              FT                      Head of Data Science    314100             USD         314100               US            M
# 169        2023               EX              FT                      Head of Data Science    195800             USD         195800               US            M
# 170        2023               EX              FT                             Data Engineer    200000             USD         200000               US            M
# 171        2023               EX              FT                             Data Engineer    145000             USD         145000               US            M
# 172        2023               EX              FT                             Data Engineer    310000             USD         310000               US            M
# 173        2023               EX              FT                             Data Engineer    239000             USD         239000               US            M
# 174        2023               EX              FT                            Data Scientist    300000             USD         300000               US            M
# 175        2023               EX              FT                            Data Scientist    200000             USD         200000               US            M
# 176        2023               EX              FT                             Data Engineer    196200             USD         196200               US            M
# 177        2023               EX              FT                             Data Engineer    150900             USD         150900               US            M
# 178        2023               MI              CT                               ML Engineer     30000             USD          30000               US            S
# 179        2023               MI              CT                               ML Engineer     25500             USD          25500               US            S
# 180        2023               MI              FT                              Data Analyst    150000             USD         150000               US            M
# 181        2023               MI              FT                              Data Analyst    110000             USD         110000               US            M
# 182        2023               MI              FT                             Data Engineer    162500             USD         162500               US            M
# 183        2023               MI              FT                             Data Engineer    130000             USD         130000               US            M
# 184        2023               MI              FT                              Data Analyst    105380             USD         105380               US            M
# 185        2023               MI              FT                              Data Analyst     64500             USD          64500               US            M
# 186        2023               MI              FT                            Data Scientist    510000             HKD          65062               HK            L
# 187        2023               MI              FT         Applied Machine Learning Engineer     65000             EUR          69751               DE            S
# 188        2023               MI              FT                 Machine Learning Engineer     90000             EUR          96578               NL            L
# 189        2023               MI              FT                    Data Analytics Manager    155000             USD         155000               US            M
# 190        2023               MI              FT                    Data Analytics Manager    140000             USD         140000               US            M
# 191        2023               MI              FT                             Data Engineer    100000             USD         100000               US            M
# 192        2023               MI              FT                             Data Engineer     70000             USD          70000               US            M
# 193        2023               MI              FT                             Data Engineer    100000             USD         100000               US            M
# 194        2023               MI              FT                             Data Engineer     70000             USD          70000               US            M
# 195        2023               MI              FT                     Business Data Analyst    105000             USD         105000               US            L
# 196        2023               MI              FT                    Applied Data Scientist   1700000             INR          20670               IN            L
# 197        2023               MI              FT                              Data Analyst     38000             GBP          46178               GB            M
# 198        2023               MI              FT                              Data Analyst     35000             GBP          42533               GB            M
# 199        2023               MI              FT                             Data Engineer    162500             USD         162500               US            M
# 200        2023               MI              FT                             Data Engineer    130000             USD         130000               US            M
# 201        2023               MI              FT                            Data Scientist     55000             GBP          66837               GB            M
# 202        2023               MI              FT                            Data Scientist     45000             GBP          54685               GB            M
# 203        2023               MI              FT                              ETL Engineer     70000             GBP          85066               GB            M
# 204        2023               MI              FT                              ETL Engineer     47500             GBP          57723               GB            M
# 205        2023               MI              FT                 Machine Learning Engineer    300000             USD         300000               US            M
# 206        2023               MI              FT                 Machine Learning Engineer    250000             USD         250000               US            M
# 207        2023               MI              FT                         Research Engineer    230000             USD         230000               US            M
# 208        2023               MI              FT                         Research Engineer    200000             USD         200000               US            M
# 209        2023               MI              FT                             Data Engineer    180000             USD         180000               US            M
# 210        2023               MI              FT                             Data Engineer    130000             USD         130000               US            M
# 211        2023               MI              FT                              AI Developer    100000             SGD          75020               FI            M
# 212        2023               MI              FT                              AI Developer    200000             USD         200000               US            M
# 213        2023               MI              FT                 Machine Learning Engineer    280700             USD         280700               US            M
# 214        2023               MI              FT                 Machine Learning Engineer    150450             USD         150450               US            M
# 215        2023               MI              FT                            Data Scientist     93918             USD          93918               US            M
# 216        2023               MI              FT                            Data Scientist     51962             USD          51962               US            M
# 217        2023               MI              FT                         Big Data Engineer     45000             EUR          48289               ES            M
# 218        2023               MI              FT                              Data Analyst     90000             USD          90000               US            M
# 219        2023               MI              FT                              Data Analyst     75000             USD          75000               US            M
# 220        2023               MI              FT                        Research Scientist    161200             GBP         195895               GB            M
# 221        2023               MI              FT                        Research Scientist     84570             GBP         102772               GB            M
# 222        2023               MI              FT                           Data Specialist    130000             USD         130000               US            M
# 223        2023               MI              FT                           Data Specialist     80000             USD          80000               US            M
# 224        2023               MI              FT                            Data Scientist    180000             USD         180000               US            M
# 225        2023               MI              FT                            Data Scientist    140000             USD         140000               US            M
# 226        2023               MI              FT                         Lead Data Analyst     68000             USD          68000               US            L
# 227        2023               MI              FT                             Data Engineer    125000             USD         125000               US            M
# 228        2023               MI              FT                             Data Engineer     90000             USD          90000               US            M
# 229        2023               MI              FT                              Data Manager    135000             USD         135000               US            M
# 230        2023               MI              FT                              Data Manager    120000             USD         120000               US            M
# 231        2023               MI              FT                              Data Analyst    182500             USD         182500               US            M
# 232        2023               MI              FT                              Data Analyst    101500             USD         121500               US            M
# 233        2023               MI              FT                              Data Analyst     90000             GBP          72914               GB            M
# 234        2023               MI              FT                              Data Analyst    121500             USD         121500               US            M
# 235        2023               MI              FT                              Data Analyst     60000             GBP          72914               GB            M
# 236        2023               MI              FT                              Data Analyst     45000             GBP          54685               GB            M
# 237        2023               MI              FT                            Data Architect    167500             USD         167500               US            M
# 238        2023               MI              FT                            Data Architect    106500             USD         106500               US            M
# 239        2023               MI              FT                             Data Engineer    146000             USD         146000               US            M
# 240        2023               MI              FT                             Data Engineer     75000             USD          75000               US            M
# 241        2023               MI              FT                Machine Learning Scientist    230000             USD         230000               US            M
# 242        2023               MI              FT                Machine Learning Scientist    220000             USD         220000               US            M
# 243        2023               MI              FT                        Research Scientist    210000             USD         210000               US            M
# 244        2023               MI              FT                        Research Scientist    151800             USD         151800               US            M
# 245        2023               MI              FT                            MLOps Engineer    134000             USD         135000               US            L
# 246        2023               MI              FT                            MLOps Engineer    124000             USD         104000               US            L
# 247        2023               MI              FT                            MLOps Engineer    134000             USD         134000               US            M
# 248        2023               MI              FT                            MLOps Engineer    124000             USD         124000               US            M
# 249        2023               MI              FT                            Data Architect    167500             USD         167500               US            M
# 250        2023               MI              FT                            Data Architect    106500             USD         106500               US            M
# 251        2023               MI              FT                 Machine Learning Engineer    135000             USD         135000               US            L
# 252        2023               MI              FT                             Data Engineer    143865             USD         143865               US            M
# 253        2023               MI              FT                             Data Engineer    115092             USD         115092               US            M
# 254        2023               MI              FT                 Machine Learning Engineer    130000             USD         130000               US            M
# 255        2023               MI              FT                 Machine Learning Engineer     90000             USD          90000               US            M
# 256        2023               MI              FT                             Data Engineer    149600             USD         149600               US            M
# 257        2023               MI              FT                             Data Engineer    102000             USD         102000               US            M
# 258        2023               MI              FT                            Data Scientist     90000             EUR          96578               IE            M
# 259        2023               MI              FT                            Data Scientist     75000             EUR          80481               IE            M
# 260        2023               MI              FT                              Data Analyst    128000             USD         128000               US            M
# 261        2023               MI              FT                              Data Analyst     85000             USD          85000               US            M
# 262        2023               MI              FT                             Data Engineer    151000             USD         151000               US            M
# 263        2023               MI              FT                             Data Engineer    140000             USD         140000               US            M
# 264        2023               MI              FT                              Data Analyst    154000             USD         154000               US            M
# 265        2023               MI              FT                              Data Analyst    143000             USD         143000               US            M
# 266        2023               MI              FT                            Data Scientist     65000             GBP          78990               GB            M
# 267        2023               MI              FT                            Data Scientist     42000             GBP          51039               GB            M
# 268        2023               MI              FT                            Data Scientist     70000             GBP          85066               GB            M
# 269        2023               MI              FT                            Data Scientist     42000             GBP          51039               GB            M
# 270        2023               MI              FT                            Data Scientist     90000             GBP         109371               GB            M
# 271        2023               MI              FT                            Data Scientist     60000             GBP          72914               GB            M
# 272        2023               MI              FT                             Data Engineer     75000             USD          75000               US            M
# 273        2023               MI              FT                             Data Engineer     60400             USD          60400               US            M
# 274        2023               MI              FT                            Data Scientist     56000             EUR          60093               DE            M
# 275        2023               MI              FT                              Data Analyst     83500             USD          83500               US            M
# 276        2023               MI              FT                              Data Analyst     52500             USD          52500               US            M
# 277        2023               MI              FT                             Data Engineer     90000             USD          90000               US            M
# 278        2023               MI              FT                             Data Engineer     90000             USD          90000               US            M
# 279        2023               MI              FT                             Data Engineer    145000             USD         145000               US            M
# 280        2023               MI              FT                             Data Engineer    120000             USD         120000               US            M
# 281        2023               MI              FT                              Data Analyst    206000             USD         206000               US            M
# 282        2023               MI              FT                              Data Analyst    130000             USD         130000               US            M
# 283        2023               MI              FT                              Data Analyst    160000             USD         160000               US            M
# 284        2023               MI              FT                              Data Analyst    112000             USD         112000               US            M
# 285        2023               MI              FT                             Data Engineer    162500             USD         162500               US            M
# 286        2023               MI              FT                             Data Engineer    130000             USD         130000               US            M
# 287        2023               MI              FT                            Data Scientist    145000             USD         145000               US            M
# 288        2023               MI              FT                            Data Scientist    100000             USD         100000               US            M
# 289        2023               MI              FT                            Data Scientist    145000             USD         145000               US            M
# 290        2023               MI              FT                            Data Scientist    100000             USD         100000               US            M
# 291        2023               MI              FT                              Data Analyst    100000             USD         100000               US            M
# 292        2023               MI              FT                              Data Analyst     85000             USD          85000               US            M
# 293        2023               MI              FT                             Data Engineer     70000             GBP          85066               GB            M
# 294        2023               MI              FT                             Data Engineer     47500             GBP          57723               GB            M
# ...
# 3663       2021               SE              FT                 Machine Learning Engineer   1799997             INR          24342               IN            L
# 3664       2021               SE              FT                        Research Scientist    120500             CAD          96113               CA            L
# 3665       2021               SE              FT                      Data Science Manager    174000             USD         174000               US            L
# 3666       2021               SE              FT                   Data Analytics Engineer     50000             USD          50000               GB            M
# 3667       2021               SE              FT  Machine Learning Infrastructure Engineer    195000             USD         195000               US            M
# 3668       2021               SE              FT                Machine Learning Scientist    225000             USD         225000               CA            L
# 3669       2021               SE              FT                    Data Analytics Manager    120000             USD         120000               US            L
# 3670       2021               SE              FT                 Machine Learning Engineer    200000             USD         200000               US            L
# 3671       2021               SE              FT                        Research Scientist     50000             USD          50000               US            S
# 3672       2021               SE              FT                             Data Engineer    165000             USD         165000               US            M
# 3673       2021               SE              FT                   Principal Data Engineer    185000             USD         185000               US            L
# 3674       2021               SE              FT                    Data Analytics Manager    140000             USD         140000               US            L
# 3675       2021               SE              FT                            Data Scientist    110000             CAD          87738               CA            S
# 3676       2021               SE              FT                      Finance Data Analyst     45000             GBP          61896               GB            L
# 3677       2021               SE              FT                             Data Engineer     65000             EUR          76833               GB            S
# 3678       2021               SE              FT                      Data Science Manager    152000             USD         152000               FR            L
# 3679       2021               SE              FT                  Computer Vision Engineer    102000             BRL          18907               BR            M
# 3680       2021               SE              FT                  Principal Data Scientist    147000             EUR         173762               DE            M
# 3681       2021               SE              FT                  Principal Data Scientist    235000             USD         235000               US            L
# 3682       2021               SE              FT                  Director of Data Science    168000             USD         168000               JP            S
# 3683       2021               SE              FT                           Data Specialist    165000             USD         165000               US            L
# 3684       2021               SE              FT                      Data Science Manager   7000000             INR          94665               IN            L
# 3685       2020               EN              FT                             Data Engineer   1000000             INR          13493               IN            L
# 3686       2020               EN              FT                             Data Engineer   1000000             INR          13493               IN            L
# 3687       2020               EN              FT                              Data Analyst     20000             EUR          22809               PT            M
# 3688       2020               EN              FT                            Data Scientist     43200             EUR          49268               DE            S
# 3689       2020               EN              FT                             Data Engineer     48000             EUR          54742               DE            L
# 3690       2020               EN              FT                         Big Data Engineer     70000             USD          70000               US            L
# 3691       2020               EN              FT                 Machine Learning Engineer    250000             USD         250000               US            L
# 3692       2020               EN              FT                              Data Analyst     10000             USD          10000               NG            S
# 3693       2020               EN              FT                 Machine Learning Engineer    138000             USD         138000               US            S
# 3694       2020               EN              PT                               ML Engineer     14000             EUR          15966               DE            S
# 3695       2020               EN              FT                              Data Analyst    450000             INR           6072               IN            S
# 3696       2020               EN              FT                              Data Analyst     91000             USD          91000               US            L
# 3697       2020               EN              FT                        Research Scientist     42000             USD          42000               NL            L
# 3698       2020               EN              FT                              Data Analyst     72000             USD          72000               US            L
# 3699       2020               EN              FT                            Data Scientist     45000             EUR          51321               FR            S
# 3700       2020               EN              FT                            Data Scientist     35000             EUR          39916               FR            M
# 3701       2020               EN              FT                             Data Engineer   4450000             JPY          41689               JP            S
# 3702       2020               EN              FT                   Data Science Consultant    423000             INR           5707               IN            M
# 3703       2020               EN              FT                              AI Scientist    300000             DKK          45896               DK            S
# 3704       2020               EN              FT                            Data Scientist     55000             EUR          62726               DE            S
# 3705       2020               EN              PT                            Data Scientist     19000             EUR          21669               IT            S
# 3706       2020               EN              FT                            Data Scientist    105000             USD         105000               US            S
# 3707       2020               EN              CT                     Business Data Analyst    100000             USD         100000               US            L
# 3708       2020               EX              FT                        Staff Data Analyst     15000             USD          15000               CA            M
# 3709       2020               EX              FT                             Data Engineer     70000             EUR          79833               ES            L
# 3710       2020               EX              FT                  Director of Data Science    325000             USD         325000               US            L
# 3711       2020               MI              FT                     Business Data Analyst     95000             USD          95000               US            M
# 3712       2020               MI              FT                      Product Data Analyst     20000             USD          20000               HN            S
# 3713       2020               MI              FT                             Data Engineer     51999             EUR          59303               DE            S
# 3714       2020               MI              FT                        Research Scientist    450000             USD         450000               US            M
# 3715       2020               MI              FT                              Data Analyst     41000             EUR          46759               FR            L
# 3716       2020               MI              FT                             Data Engineer     65000             EUR          74130               AT            L
# 3717       2020               MI              FT                   Data Science Consultant    103000             USD         103000               US            L
# 3718       2020               MI              FT                            Data Scientist     45760             USD          45760               US            S
# 3719       2020               MI              FT  Machine Learning Infrastructure Engineer     44000             EUR          50180               PT            M
# 3720       2020               MI              FT                             Data Engineer    106000             USD         106000               US            L
# 3721       2020               MI              FT                             Data Engineer     88000             GBP         112872               GB            L
# 3722       2020               MI              FT                            Data Scientist     60000             GBP          76958               GB            S
# 3723       2020               MI              FT                            Data Scientist    105000             USD         105000               US            L
# 3724       2020               MI              FT                             Data Engineer     61500             EUR          70139               FR            L
# 3725       2020               MI              FT                       Lead Data Scientist    115000             USD         115000               AE            L
# 3726       2020               MI              FT                            Data Scientist     70000             EUR          79833               DE            L
# 3727       2020               MI              FT                            Data Scientist  11000000             HUF          35735               HU            L
# 3728       2020               MI              FT                     Business Data Analyst    135000             USD         135000               US            L
# 3729       2020               MI              FT                            Data Scientist   3000000             INR          40481               IN            L
# 3730       2020               MI              FT                         Lead Data Analyst     87000             USD          87000               US            L
# 3731       2020               MI              FT                              Data Analyst     85000             USD          85000               US            L
# 3732       2020               MI              FT                              Data Analyst      8000             USD           8000               PK            L
# 3733       2020               MI              FT                        Lead Data Engineer     56000             USD          56000               US            M
# 3734       2020               MI              FT                      Product Data Analyst    450000             INR           6072               IN            L
# 3735       2020               MI              FT                           BI Data Analyst     98000             USD          98000               US            M
# 3736       2020               MI              FT                            Data Scientist     37000             EUR          42197               FR            S
# 3737       2020               MI              FT                             Data Engineer    110000             USD         110000               US            L
# 3738       2020               MI              FT                            Data Scientist     34000             EUR          38776               ES            M
# 3739       2020               MI              FT                            Data Scientist     55000             EUR          62726               LU            S
# 3740       2020               MI              FT                            Data Scientist    118000             USD         118000               US            M
# 3741       2020               MI              FT                            Data Scientist    138350             USD         138350               US            M
# 3742       2020               MI              FT                             Data Engineer    130800             USD         130800               US            M
# 3743       2020               SE              FT                  Machine Learning Manager    157000             CAD         117104               CA            L
# 3744       2020               SE              FT                            Data Scientist     60000             EUR          68428               US            L
# 3745       2020               SE              FT                             Data Engineer    188000             USD         188000               US            L
# 3746       2020               SE              FT                             Data Engineer    720000             MXN          33511               MX            S
# 3747       2020               SE              FT                Machine Learning Scientist    260000             USD         260000               JP            S
# 3748       2020               SE              FT                         Big Data Engineer     85000             GBP         109024               GB            M
# 3749       2020               SE              FT                 Machine Learning Engineer    150000             USD         150000               US            L
# 3750       2020               SE              FT                       Lead Data Scientist    190000             USD         190000               US            S
# 3751       2020               SE              FT                        Lead Data Engineer    125000             USD         125000               NZ            S
# 3752       2020               SE              FT                         Big Data Engineer    100000             EUR         114047               GB            S
# 3753       2020               SE              FT                             Data Engineer     42000             EUR          47899               GR            L
# 3754       2020               SE              FT                            Data Scientist    120000             USD         120000               US            L
# 3755       2020               SE              FL                  Computer Vision Engineer     60000             USD          60000               US            S
# 3756       2020               SE              FT                  Principal Data Scientist    130000             EUR         148261               DE            M
# 3757       2020               SE              FT                            Data Scientist     80000             EUR          91237               AT            S
# 3758       2020               SE              FT                      Data Science Manager    190200             USD         190200               US            M
# 3759       2020               SE              FT                 Machine Learning Engineer     40000             EUR          45618               HR            S
# 3760       2020               SE              FT                            Data Scientist    412000             USD         412000               US            L

# %% [markdown]
# ---
#
#
# Para ver mas informacion usamos el método de Pandas <code>info()</code> esta vez va con parentesis porque es una funcion (metodo).
#
# > *Recordemos que los métodos son funciones que pertenecen a una clase.*
#
#
# Los *object* que se ven en la columna de "tipos de datos" (Dtype) son *strings*

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3761 entries, 0 to 3760
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   work_year         3761 non-null   int64
#  1   experience_level  3761 non-null   object
#  2   employment_type   3761 non-null   object
#  3   job_title         3761 non-null   object
#  4   salary            3761 non-null   int64
#  5   salary_currency   3761 non-null   object
#  6   salary_in_usd     3761 non-null   int64
#  7   company_location  3761 non-null   object
#  8   company_size      3761 non-null   object
# dtypes: int64(3), object(6)
# memory usage: 264.6+ KB

# %% [markdown]
# ---
#
#
#
# El método de Pandas <code>head()</code> muestra el número de filas que queremos visualizar desde el principio (cabecera) del dataframe (df), pasándole el número de filas como parámetro de la función. Si no se indica el número de filas en el método, muestra las 5 primeras filas por defecto.
#
# Más info en [Pandas](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.head.html#pandas.DataFrame.head).

# %%
# Nos muestra las 20 primeras filas del dataframe.

df.head(20)
# Out:
#     work_year experience_level employment_type                  job_title  \
# 0        2023               EN              FT          Applied Scientist
# 1        2023               EN              FT          Applied Scientist
# 2        2023               EN              FT       Data Quality Analyst
# 3        2023               EN              FT    Compliance Data Analyst
# 4        2023               EN              FT          Applied Scientist
# 5        2023               EN              FT          Applied Scientist
# 6        2023               EN              FT  Machine Learning Engineer
# 7        2023               EN              FT  Machine Learning Engineer
# 8        2023               EN              FT         Research Scientist
# 9        2023               EN              FT              Data Engineer
# 10       2023               EN              FT              Data Engineer
# 11       2023               EN              FT               Data Analyst
# 12       2023               EN              FT               Data Analyst
# 13       2023               EN              FT               Data Analyst
# 14       2023               EN              FT               Data Analyst
# 15       2023               EN              FT              Data Engineer
# 16       2023               EN              FT              Data Engineer
# 17       2023               EN              FT              Data Engineer
# 18       2023               EN              FT               Data Analyst
# 19       2023               EN              FT             Data Scientist
#
#      salary salary_currency  salary_in_usd company_location company_size
# 0    213660             USD         213660               US            L
# 1    130760             USD         130760               US            L
# 2    100000             USD         100000               NG            L
# 3     30000             USD          30000               NG            L
# 4    204620             USD         204620               US            L
# 5    110680             USD         110680               US            L
# 6    163196             USD         163196               US            M
# 7    145885             USD         145885               US            M
# 8    220000             USD         220000               US            L
# 9     85000             USD          85000               US            M
# 10    65000             USD          65000               US            M
# 11    75000             USD          75000               US            M
# 12    70000             USD          70000               US            M
# 13    85000             USD          85000               US            M
# 14    75000             USD          75000               US            M
# 15  1400000             INR          17022               IN            L
# 16    85000             USD          85000               US            M
# 17    65000             USD          65000               US            M
# 18    55000             CAD          40663               CA            L
# 19    70000             CAD          51753               CA            L

# %% [markdown]
# ---
#
#
#
# El método de Pandas <code>tail()</code> muestra el número de filas que queremos visualizar desde el final (cola) del dataframe (df), pasándole el número de filas como parámetro de la función. Si no se indica el número de filas en el método, muestra las 5 últimas filas por defecto.
#
# Más info en [Pandas](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.tail.html#pandas.DataFrame.tail).

# %%
# Nos muestra las 15 ultimas filas del dataframe.

df.tail(15)
# Out:
#       work_year experience_level employment_type                   job_title  \
# 3746       2020               SE              FT               Data Engineer
# 3747       2020               SE              FT  Machine Learning Scientist
# 3748       2020               SE              FT           Big Data Engineer
# 3749       2020               SE              FT   Machine Learning Engineer
# 3750       2020               SE              FT         Lead Data Scientist
# 3751       2020               SE              FT          Lead Data Engineer
# 3752       2020               SE              FT           Big Data Engineer
# 3753       2020               SE              FT               Data Engineer
# 3754       2020               SE              FT              Data Scientist
# 3755       2020               SE              FL    Computer Vision Engineer
# 3756       2020               SE              FT    Principal Data Scientist
# 3757       2020               SE              FT              Data Scientist
# 3758       2020               SE              FT        Data Science Manager
# 3759       2020               SE              FT   Machine Learning Engineer
# 3760       2020               SE              FT              Data Scientist
#
#       salary salary_currency  salary_in_usd company_location company_size
# 3746  720000             MXN          33511               MX            S
# 3747  260000             USD         260000               JP            S
# 3748   85000             GBP         109024               GB            M
# 3749  150000             USD         150000               US            L
# 3750  190000             USD         190000               US            S
# 3751  125000             USD         125000               NZ            S
# 3752  100000             EUR         114047               GB            S
# 3753   42000             EUR          47899               GR            L
# 3754  120000             USD         120000               US            L
# 3755   60000             USD          60000               US            S
# 3756  130000             EUR         148261               DE            M
# 3757   80000             EUR          91237               AT            S
# 3758  190200             USD         190200               US            M
# 3759   40000             EUR          45618               HR            S
# 3760  412000             USD         412000               US            L

# %% [markdown]
# ---
#
#
#
# Pandas tiene un sistema de opciones que permite personalizar algunos aspectos de su comportamiento, siendo las opciones relacionadas con la visualización las que el usuario es más propenso a ajustar.
#
# Esto lo conseguimos con el método <code>set_option()</code>.
#
# En el siguiente snippet, cambiamos la opción de visualización máxima de columnas a 11.
#
# Más info en [Pandas](https://pandas.pydata.org/docs/reference/api/pandas.set_option.html#pandas-set-option).

# %%
pd.set_option('display.max_columns', 11)

# %%
df
# Out:
#       work_year experience_level employment_type                  job_title  \
# 0          2023               EN              FT          Applied Scientist
# 1          2023               EN              FT          Applied Scientist
# 2          2023               EN              FT       Data Quality Analyst
# 3          2023               EN              FT    Compliance Data Analyst
# 4          2023               EN              FT          Applied Scientist
# ...         ...              ...             ...                        ...
# 3756       2020               SE              FT   Principal Data Scientist
# 3757       2020               SE              FT             Data Scientist
# 3758       2020               SE              FT       Data Science Manager
# 3759       2020               SE              FT  Machine Learning Engineer
# 3760       2020               SE              FT             Data Scientist
#
#       salary salary_currency  salary_in_usd company_location company_size
# 0     213660             USD         213660               US            L
# 1     130760             USD         130760               US            L
# 2     100000             USD         100000               NG            L
# 3      30000             USD          30000               NG            L
# 4     204620             USD         204620               US            L
# ...      ...             ...            ...              ...          ...
# 3756  130000             EUR         148261               DE            M
# 3757   80000             EUR          91237               AT            S
# 3758  190200             USD         190200               US            M
# 3759   40000             EUR          45618               HR            S
# 3760  412000             USD         412000               US            L
#
# [3761 rows x 9 columns]

# %% [markdown]
# ---
#
#
#
# La función <code>describe()</code> genera estadísticas descriptivas del dataframe, como la media (**mean**), la desviación estándar (**std**), los porcentiles (**25%, 50% y 75%**), el valor mínimo (**min**) y el valor máximo (**max**), además del recuento (**count**) de todos los valores de cada columna (excluyendo los valores NaN, es decir, aquellos valores que no son númericos).

# %%
df.describe()
# round(df.describe(),2) ---> Redondeamos los valores estadísticos a 2 decimales.
# Out:
#          work_year        salary  salary_in_usd
# count  3761.000000  3.761000e+03    3761.000000
# mean   2022.374103  1.905999e+05  137555.178942
# std       0.691252  6.711457e+05   63022.267974
# min    2020.000000  6.000000e+03    5132.000000
# 25%    2022.000000  1.000000e+05   95000.000000
# 50%    2022.000000  1.375000e+05  135000.000000
# 75%    2023.000000  1.800000e+05  175000.000000
# max    2023.000000  3.040000e+07  450000.000000

# %% [markdown]
# ### <u>***UNIDAD 2: DATAFRAME Y SERIES***</u>

# %% [markdown]
# ---
#
# Anteriomente, vimos la definición de un dataframe. Una **Serie**, por el contrario, e**s una secuencia de valores de datos**.
#
# > ***Si un DataFrame es una tabla, una Serie es una lista.***
#
# Podemos crear un dataframe desde cero, mediante los ***diccionarios*** de Python.
#
# Recordemos que un diccionario es una estructura de datos de Python donde se almacenan pares de Clave-Valor, separados por dos puntos (:), y cada par separado por comas.
#
# A continuación, vamos a ver diferentes formas de crear el diccionario:

# %%
# Usando un diccionario básico tenemos
gente= {
    'nombre':'Marta',
    'apellido': 'Ruiz',
    'email': 'martaruiz@gmail.com'
}

# %%
# Diccionario con listas de una sola persona
gente={
    'nombre': ['Marta'],
    'apellido': ['Ruiz'],
    'email': ['martaruiz@gmail.com']
}

# %%
# Diccionario con listas de varias personas
gente={
    'nombre': ['Marta', 'Luis', 'Ana'],
    'apellido': ['Ruiz', 'Lopez', 'Santana'],
    'email': ['martaruiz@gmail.com', 'luislopez@gmail.com', 'anasantana@gmail.com']
}

# %%
# imprimimos los valores de la clave "email"

gente['email']
# Out:
# ['martaruiz@gmail.com', 'luislopez@gmail.com', 'anasantana@gmail.com']

# %% [markdown]
# ---
#
#
# Para crear un dataframe con el diccionario anterior usamos el constructor de Pandas <code>pd.DataFrame()</code> ("pd" es el alias que hemos puesto al importar la librería de Pandas), y le pasamos como parámetro el diccionario.
#
# Más info en [Pandas](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.html).

# %%
df=pd.DataFrame(gente)

df
# Out:
#   nombre apellido                 email
# 0  Marta     Ruiz   martaruiz@gmail.com
# 1   Luis    Lopez   luislopez@gmail.com
# 2    Ana  Santana  anasantana@gmail.com

# %%
# Para acceder a informacion y ver los indices

df['email']
# Out:
# 0     martaruiz@gmail.com
# 1     luislopez@gmail.com
# 2    anasantana@gmail.com
# Name: email, dtype: object

# %%
# También podemos acceder a la información de una columna de la siguiente manera:

df.email
# Out:
# 0     martaruiz@gmail.com
# 1     luislopez@gmail.com
# 2    anasantana@gmail.com
# Name: email, dtype: object

# %% [markdown]
# ---
#
#
#
# Cuando pedimos que nos diga el tipo (type) de una columna de un dataframe, vemos que lo que nos devuelve es una *Serie*.

# %%
type(df['email'])
# Out:
# pandas.core.series.Series

# %% [markdown]
# ---
#
#
# Si queremos acceder a varias columnas, hace falta el doble corchete para evitar que pandas piense que los dos strings son el nombre de una sola
# columna

# %%
df[['apellido', 'email']]
# Out:
#   apellido                 email
# 0     Ruiz   martaruiz@gmail.com
# 1    Lopez   luislopez@gmail.com
# 2  Santana  anasantana@gmail.com

# %% [markdown]
# ---
#
#
# Para acceder a los nombres de las columnas podemos usar la propiedad de Pandas <code>columns</code>

# %%
df.columns
# Out:
# Index(['nombre', 'apellido', 'email'], dtype='object')

# %% [markdown]
# ---
#
#
# La indexación en Pandas funciona en uno de los dos siguientes paradigmas:
# *   Selección basada en índices.
# *   Selección basada en etiquetas.
#
# La selección basada en índices selecciona los datos basándose en su posición numérica en el dataframe. La propiedad <code>iloc</code> sigue este paradigma.

# %%
# Para ver las filas usamos los indices y la funcion iloc y la notación de
# índices (integer location)

df.iloc[0]
# Out:
# nombre                    Marta
# apellido                   Ruiz
# email       martaruiz@gmail.com
# Name: 0, dtype: object

# %%
# Si queremos ver dos filas usamos una lista numérica dentro de la notación
# de índices

df.iloc[[0,1]]
# Out:
#   nombre apellido                email
# 0  Marta     Ruiz  martaruiz@gmail.com
# 1   Luis    Lopez  luislopez@gmail.com

# %%
# Si queremos mostrar dos filas y la columna con el indice 2

df.iloc[[0, 1], 2]
# Out:
# 0    martaruiz@gmail.com
# 1    luislopez@gmail.com
# Name: email, dtype: object

# %% [markdown]
# ---
#
#
# En el paradigma de la selección basada en etiquetas lo que importa es el valor del índice del dato, no su posición.
#
# <code>iloc</code> es conceptualmente más sencillo que <code>loc</code> porque ignora los índices del conjunto de datos. Cuando usamos <code>iloc</code> tratamos el conjunto de datos como una gran matriz (una lista de listas), en la que tenemos que indexar por posición.
#
# <code>loc</code>, por el contrario, usa la información de los índices para hacer su trabajo. Dado que el conjunto de datos suele tener índices significativos, suele ser más fácil hacer las cosas con <code>loc</code>.

# %%
# Mostramos otra vez nuestra tabla o DataFrame

df
# Out:
#   nombre apellido                 email
# 0  Marta     Ruiz   martaruiz@gmail.com
# 1   Luis    Lopez   luislopez@gmail.com
# 2    Ana  Santana  anasantana@gmail.com

# %%
# Accedemos a datos del primer registro igual que hacíamos con iloc.

df.loc[0]
# Out:
# nombre                    Marta
# apellido                   Ruiz
# email       martaruiz@gmail.com
# Name: 0, dtype: object

# %%
# Podemos acceder a unos registros (filas) concretas del dataframe
# y a unas columnas concretas, de la siguiente manera:

df.loc[[0,1], ['email', 'apellido']]
# Out:
#                  email apellido
# 0  martaruiz@gmail.com     Ruiz
# 1  luislopez@gmail.com    Lopez

# %%
# También podemos usar el slicing o loncheado de la notación de índices.
# No hay doble corchete porque no estamos pasando una lista como antes.

df.loc[0:2, 'email']
# Out:
# 0     martaruiz@gmail.com
# 1     luislopez@gmail.com
# 2    anasantana@gmail.com
# Name: email, dtype: object

# %%
# Igualmente, podemos usar el slicing para filas y columnas.

df.loc[0:2, 'nombre': 'email']
# Out:
#   nombre apellido                 email
# 0  Marta     Ruiz   martaruiz@gmail.com
# 1   Luis    Lopez   luislopez@gmail.com
# 2    Ana  Santana  anasantana@gmail.com

# %% [markdown]
# ### <u>***UNIDAD 3: INDICES (set, reset, etc.)***</u>

# %%
# Diccionario con listas de varias personas

gente={
    'nombre': ['Marta', 'Luis', 'Ana'],
    'apellido': ['Ruiz', 'Lopez', 'Santana'],
    'email': ['martaruiz@gmail.com', 'luislopez@gmail.com', 'anasantana@gmail.com']
}

# %%
# Creamos el dataframe utilizando el diccionario del snippet anterior.

df=pd.DataFrame(gente)

df
# Out:
#   nombre apellido                 email
# 0  Marta     Ruiz   martaruiz@gmail.com
# 1   Luis    Lopez   luislopez@gmail.com
# 2    Ana  Santana  anasantana@gmail.com

# %% [markdown]
# ---
#
#
# Podemos cambiar los indices numéricos por defecto de los dataframe, usando el método de Pandas `set_index()`. Este método establece el índice del DataFrame (etiquetas de fila) utilizando una o más columnas o arrays existentes (de la longitud correcta).
#
# > *El índice puede sustituir al índice existente o ampliarlo*.
#
# En el siguiente snippet, vamos a cambiar los índices predeterminados (0, 1, 2, ...) por los valores de la columna "emails" que también son valores únicos en cada fila y, por tanto, para cada persona del DF. (Esto es similar a establecer una ***primary key*** en SQL).
#
# El parámetro `inplace=True` acepta valores booleanos y se utiliza para indicar si se modifica el DataFrame en lugar de crear uno nuevo. Por defecto, el valor es `False`, y este ejemplo en concreto estamos creando un dataframe nuevo.
#
# Mas info en [Pandas](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.set_index.html#pandas.DataFrame.set_index).

# %%
df.set_index('email', inplace=True)

df
# Out:
#                      nombre apellido
# email
# martaruiz@gmail.com   Marta     Ruiz
# luislopez@gmail.com    Luis    Lopez
# anasantana@gmail.com    Ana  Santana

# %% [markdown]
# ---
#
#
# Si queremos poner los nuevos indices por orden alfabetico usamos la funcion `sort_index()`.
#
# Más info en [Pandas](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.sort_index.html).

# %%
df.sort_index()
# Out:
#                      nombre apellido
# email
# anasantana@gmail.com    Ana  Santana
# luislopez@gmail.com    Luis    Lopez
# martaruiz@gmail.com   Marta     Ruiz

# %% [markdown]
# Para que el orden sea el contrario (descendente) al alfabetico usamos el
# parámetro `ascending = False`

# %%
df.sort_index(ascending=False)
# Out:
#                      nombre apellido
# email
# martaruiz@gmail.com   Marta     Ruiz
# luislopez@gmail.com    Luis    Lopez
# anasantana@gmail.com    Ana  Santana

# %%
# Usamos la propiedad "index" para ver los índices del dataframe.

df.index
# Out:
# Index(['martaruiz@gmail.com', 'luislopez@gmail.com', 'anasantana@gmail.com'], dtype='object', name='email')

# %% [markdown]
# ---
#
#
# Después de los cambios realizados en el índice de las filas, donde antes usábamos el índice numérico (0, 1, 2, ...), ahora vamos a usar el valor string de la columna "email", junto con la propiedad `loc`.

# %%
df.loc['anasantana@gmail.com']
# Out:
# nombre          Ana
# apellido    Santana
# Name: anasantana@gmail.com, dtype: object

# %%
# También podemos detallar mas la consulta, añadiendo una columna:

df.loc['anasantana@gmail.com', 'apellido']
# Out:
# 'Santana'

# %% [markdown]
# ---
#
#
# Como comentamos anteriormente, teniendo en cuenta los paradisgmas que usan las propiedades `loc` e `iloc` respectivamente, al no usar ya índices numéricos, no podemos usarlos en la propiedad `loc`, ya que ésta nos arrojaría un error.

# %%
# La ejecución de este snippet causa un error.

df.loc[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-38-46bddd906ad3> in <cell line: 3>()
#       1 # La ejecución de este snippet causa un error.
#       2
# ----> 3 df.loc[0]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1071
#    1072             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1073             return self._getitem_axis(maybe_callable, axis=axis)
#    1074
#    1075     def _is_scalar_access(self, key: tuple):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1310         # fall thru to straight lookup
#    1311         self._validate_key(key, axis)
# -> 1312         return self._get_label(key, axis=axis)
#    1313
#    1314     def _get_slice_axis(self, slice_obj: slice, axis: int):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in _get_label(self, label, axis)
#    1258     def _get_label(self, label, axis: int):
#    1259         # GH#5567 this will fail if the label is not present in the axis.
# -> 1260         return self.obj.xs(label, axis=axis)
#    1261
#    1262     def _handle_lowerdim_multi_index_axis0(self, tup: tuple):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in xs(self, key, axis, level, drop_level)
#    4054                     new_index = index[loc]
#    4055         else:
# -> 4056             loc = index.get_loc(key)
#    4057
#    4058             if isinstance(loc, np.ndarray):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
# -> 3804                 raise KeyError(key) from err
#    3805             except TypeError:
#    3806                 # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 0

# %% [markdown]
# Sin embargo, con la propiedad `iloc` si podemos seguir usando los indices numericos anteriores.

# %%
df.iloc[0]
# Out:
# nombre      Marta
# apellido     Ruiz
# Name: martaruiz@gmail.com, dtype: object

# %% [markdown]
# ---
#
#
# Si queremos volver a poner los indices por defecto, usamos la funcion `reset_index()`.
#
# En el siguiente snippet volvemos a usar el parámetro `inplace=True`.
#
# Más info en [Pandas](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.reset_index.html).

# %%
df.reset_index(inplace=True)

df
# Out:
#                   email nombre apellido
# 0   martaruiz@gmail.com  Marta     Ruiz
# 1   luislopez@gmail.com   Luis    Lopez
# 2  anasantana@gmail.com    Ana  Santana

# %% [markdown]
# ### <u>***UNIDAD 4. FILTRAR DATAFRAME Y BUSCAR DATOS QUE CUMPLAN DETERMINADAS CONDICIONES (and Y or)***</u>

# %% [markdown]
# Comenzamos esta sección creando un dataframe a partir de un diccionario que vamos a definir, y mediante el constructor de Pandas `pd.Dataframe()`.

# %%
gente={
    'nombre': ['Marta', 'Luis', 'Ana', 'Andres', 'Monica', 'Ana'],
    'apellido': ['Ruiz', 'Lopez', 'Santana', 'Lopez', 'Castro', 'Perez'],
    'email': ['martaruiz@gmail.com', 'luislopez@gmail.com', 'anasantana@gmail.com', 'andreslopez@gmail.com', 'monicacastro@gmail.com', 'saraperez@gmail.com'],
    'edad': [35, 28, 35, 'NaN', 53, 67],
    'salario': [20000, 25000, 50000, 17000, 20000, 65000],
    'ciudad' :['Madrid', 'Valencia', 'Malaga', 'Cadiz', 'Burgos', 'Madrid'],
    'casado': ['Yes', 'No', 'Yes', 'No', 'NaN', 'Yes']
}

#NaN =   not a number

# %%
df=pd.DataFrame(gente)

df
# Out:
#    nombre apellido                   email edad  salario    ciudad casado
# 0   Marta     Ruiz     martaruiz@gmail.com   35    20000    Madrid    Yes
# 1    Luis    Lopez     luislopez@gmail.com   28    25000  Valencia     No
# 2     Ana  Santana    anasantana@gmail.com   35    50000    Malaga    Yes
# 3  Andres    Lopez   andreslopez@gmail.com  NaN    17000     Cadiz     No
# 4  Monica   Castro  monicacastro@gmail.com   53    20000    Burgos    NaN
# 5     Ana    Perez     saraperez@gmail.com   67    65000    Madrid    Yes

# %% [markdown]
# <u>*Filtro 1*</u>: ¿Quienes tienen el apellido López?

# %%
# Al usar el operador de comparación "igual" (==), el resultado es un valor
# booleano para cada fila.

df['apellido'] == 'Lopez'
# Out:
# 0    False
# 1     True
# 2    False
# 3     True
# 4    False
# 5    False
# Name: apellido, dtype: bool

# %% [markdown]
# <u>*Filtro 2*</u>: Mostrar todos los registros que contengan el apellido "López".

# %%
# Vamos a crear una variable llamada "filt" (no uses "filter" porque es una palabra
# clave de Python), donde guardaremos la consulta del snippet anterior.

filt= df['apellido'] == 'Lopez'

# %%
# Usamos la variable "filt" en el dataframe para visualizar los registros de
# la consulta.

df[filt]
# Out:
#    nombre apellido                  email edad  salario    ciudad casado
# 1    Luis    Lopez    luislopez@gmail.com   28    25000  Valencia     No
# 3  Andres    Lopez  andreslopez@gmail.com  NaN    17000     Cadiz     No

# %%
# Si usamos la propiedad "loc" podemos buscar alguna columna de la busqueda anterior

df.loc[filt, 'email']
# Out:
# 1      luislopez@gmail.com
# 3    andreslopez@gmail.com
# Name: email, dtype: object

# %% [markdown]
# > En Pandas, el operador `and` se representa con el símbolo `&`, y el operador `or` se representa con el símbolo `|` (este símbolo se consigue pulsando las teclas: <mark>*alt gr* + 1</mark>).
#
# <u>*Filtro 3*</u>: Mostrar los registros cuyo apellido sea López ***y*** cuyo nombre sea Andrés.

# %%
filt= (df['apellido'] == 'Lopez') & (df['nombre'] == 'Andres')

df[filt]
# Out:
#    nombre apellido                  email edad  salario ciudad casado
# 3  Andres    Lopez  andreslopez@gmail.com  NaN    17000  Cadiz     No

# %% [markdown]
# <u>*Filtro 4*</u>: Mostrar los registros cuyo apellido sea López ***o*** cuyo nombre sea Andrés.

# %%
#vamos a usar ahora el 'o' que en Pandas es igual a |
filt= (df['apellido'] == 'Lopez') | (df['nombre'] == 'Ana')
df[filt]
# Out:
#    nombre apellido                  email edad  salario    ciudad casado
# 1    Luis    Lopez    luislopez@gmail.com   28    25000  Valencia     No
# 2     Ana  Santana   anasantana@gmail.com   35    50000    Malaga    Yes
# 3  Andres    Lopez  andreslopez@gmail.com  NaN    17000     Cadiz     No
# 5     Ana    Perez    saraperez@gmail.com   67    65000    Madrid    Yes

# %% [markdown]
# > La negación lógica (***not***) en Pandas se representa con el símbolo `~` (este símbolo se consigue pulsando las teclas: <mark>*alt gr* + 4</mark> y luego pulsando la tecla <mark>espacio</mark>.
#
# <u>*Filtro 5*</u>: Mostrar los registros cuyo apellido <u>no</u> sea López ***o*** cuyo nombre <u>no</u> sea Andrés.

# %%
filt= (df['apellido'] == 'Lopez') | (df['nombre'] == 'Ana')

df[~filt]
# Out:
#    nombre apellido                   email edad  salario  ciudad casado
# 0   Marta     Ruiz     martaruiz@gmail.com   35    20000  Madrid    Yes
# 4  Monica   Castro  monicacastro@gmail.com   53    20000  Burgos    NaN

# %% [markdown]
# <u>*Filtro 6*</u>: Mostrar los registros de aquellas personas que ganen más de 35000€ de salario.
#
# Esta vez, creamos una variable llamada `salario_alto` donde guardaremos el filtro (que ya sabemos que nos devuelve valores booleanos) y la usamos en el dataframe como notación de índices.

# %%
salario_alto = (df['salario'] > 35000)

df[salario_alto]
# Out:
#   nombre apellido                 email edad  salario  ciudad casado
# 2    Ana  Santana  anasantana@gmail.com   35    50000  Malaga    Yes
# 5    Ana    Perez   saraperez@gmail.com   67    65000  Madrid    Yes

# %%
# Podemos filtrar aún más la busqueda anteior:

df.loc[salario_alto, ['edad', 'ciudad']]
# Out:
#   edad  ciudad
# 2   35  Malaga
# 5   67  Madrid

# %% [markdown]
# <u>*Filtro 7*</u>: Mostrar los registros de aquellas personas que vivan en Madrid y Málaga.
#
# >El método `isin()` nos permite pasarle como parámetros un valor iterable (Series, Dataframe o diccionario) y nos devuelve un valor booleano de cada elemento del dataframe, indicando si está presente en el dataframe o columna(s) del dataframe en cuestión.
# >
# >Los pasos para crear este filtro son:
# 1.  Creamos una lista `ciudades` con los valores que queremos buscar en el dataframe.
# 2.  Creamos la variable `filt` con el filtro que nos devolverá valores booleanos.
# 3.  Pasamos la variable `filt` a la propiedad `loc` para mostrar los registros resultantes del filtro.
#
# Más info del método `isin()` en [Pandas](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.isin.html).

# %%
ciudades=['Madrid', 'Malaga']

filt= df['ciudad'].isin(ciudades)

df.loc[filt]
# Out:
#   nombre apellido                 email edad  salario  ciudad casado
# 0  Marta     Ruiz   martaruiz@gmail.com   35    20000  Madrid    Yes
# 2    Ana  Santana  anasantana@gmail.com   35    50000  Malaga    Yes
# 5    Ana    Perez   saraperez@gmail.com   67    65000  Madrid    Yes

# %% [markdown]
# <u>*Filtro 8*</u>: Mostrar los registros de aquellas personas cuya ciudad contenga la letra "g".
#
# >Para este filtro, usaremos el método `str.contains()` de las Series de Pandas, que nos permite comprobar si un patrón o regex (expresión regular, en íngles) está contenido en una cadena de una Serie o Índice .
# >
# >El parametro `regex=False` es un valor booleano que:
# +   Si es `True`, asume que el patrón es una expresión regular.
# +   Si es `False`, trata el patrón como una cadena literal (string).

# %%
filt = df['ciudad'].str.contains('g', regex='False')

df.loc[filt]
# Out:
#    nombre apellido                   email edad  salario  ciudad casado
# 2     Ana  Santana    anasantana@gmail.com   35    50000  Malaga    Yes
# 4  Monica   Castro  monicacastro@gmail.com   53    20000  Burgos    NaN

# %% [markdown]
# ### <u>***UNIDAD 5. CAMBIAR DATOS EN EL DATAFRAME***</u>

# %%
# Vamos a ver que columnas tiene nuestro DF

df.columns
# Out:
# Index(['nombre', 'apellido', 'email', 'edad', 'salario', 'ciudad', 'casado'], dtype='object')

# %% [markdown]
# Vamos a cambiar el nombre de todas las columnas al ingles

# %%
df.columns=['name', 'last_name', 'email', 'age', 'salary', 'city', 'married']

df.columns
# Out:
# Index(['name', 'last_name', 'email', 'age', 'salary', 'city', 'married'], dtype='object')

# %%
# Para ver todo el DF

df
# Out:
#      name last_name                   email  age  salary      city married
# 0   Marta      Ruiz     martaruiz@gmail.com   35   20000    Madrid     Yes
# 1    Luis     Lopez     luislopez@gmail.com   28   25000  Valencia      No
# 2     Ana   Santana    anasantana@gmail.com   35   50000    Malaga     Yes
# 3  Andres     Lopez   andreslopez@gmail.com  NaN   17000     Cadiz      No
# 4  Monica    Castro  monicacastro@gmail.com   53   20000    Burgos     NaN
# 5     Ana     Perez     saraperez@gmail.com   67   65000    Madrid     Yes

# %% [markdown]
# Si queremos que los nombres de las columnas esten en mayusculas, utilizaremos una compresión de lista para las columnas y usaremos el método `upper()` de los *Strings* el la variable temporal del bucle `for`.

# %%
df.columns = [x.upper() for x in df.columns]

df
# Out:
#      NAME LAST_NAME                   EMAIL  AGE  SALARY      CITY MARRIED
# 0   Marta      Ruiz     martaruiz@gmail.com   35   20000    Madrid     Yes
# 1    Luis     Lopez     luislopez@gmail.com   28   25000  Valencia      No
# 2     Ana   Santana    anasantana@gmail.com   35   50000    Malaga     Yes
# 3  Andres     Lopez   andreslopez@gmail.com  NaN   17000     Cadiz      No
# 4  Monica    Castro  monicacastro@gmail.com   53   20000    Burgos     NaN
# 5     Ana     Perez     saraperez@gmail.com   67   65000    Madrid     Yes

# %% [markdown]
# Si quieres quitar espacios entre palabras y meter guiones bajos por ejemplo, o hacer lo contrario, usaremos el método `str.replace()` de los Strings en las columnas del dataframe.

# %%
df.columns= df.columns.str.replace('_', ' ')

df
# Out:
#      NAME LAST NAME                   EMAIL  AGE  SALARY      CITY MARRIED
# 0   Marta      Ruiz     martaruiz@gmail.com   35   20000    Madrid     Yes
# 1    Luis     Lopez     luislopez@gmail.com   28   25000  Valencia      No
# 2     Ana   Santana    anasantana@gmail.com   35   50000    Malaga     Yes
# 3  Andres     Lopez   andreslopez@gmail.com  NaN   17000     Cadiz      No
# 4  Monica    Castro  monicacastro@gmail.com   53   20000    Burgos     NaN
# 5     Ana     Perez     saraperez@gmail.com   67   65000    Madrid     Yes

# %% [markdown]
# Vamos a dejar los nombres de las columnas en minusculas otra vez usando, esta vez, el método `lower()` de los Strings en la compresión de listas.

# %%
df.columns = [x.lower() for x in df.columns]

df
# Out:
#      name last name                   email  age  salary      city married
# 0   Marta      Ruiz     martaruiz@gmail.com   35   20000    Madrid     Yes
# 1    Luis     Lopez     luislopez@gmail.com   28   25000  Valencia      No
# 2     Ana   Santana    anasantana@gmail.com   35   50000    Malaga     Yes
# 3  Andres     Lopez   andreslopez@gmail.com  NaN   17000     Cadiz      No
# 4  Monica    Castro  monicacastro@gmail.com   53   20000    Burgos     NaN
# 5     Ana     Perez     saraperez@gmail.com   67   65000    Madrid     Yes

# %% [markdown]
# Si solo queremos cambiar el nombre de algunas columnas, usamos el método `rename` de dataframes en Pandas y un diccionario.
#
# Más info en [Pandas](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.rename.html#pandas.DataFrame.rename).

# %%
df.rename(columns={'name': 'nombre', 'last name': 'apellido', 'age':'edad', 'city': 'ciudad'}, inplace=True)

df
# Out:
#    nombre apellido                   email edad  salary    ciudad married
# 0   Marta     Ruiz     martaruiz@gmail.com   35   20000    Madrid     Yes
# 1    Luis    Lopez     luislopez@gmail.com   28   25000  Valencia      No
# 2     Ana  Santana    anasantana@gmail.com   35   50000    Malaga     Yes
# 3  Andres    Lopez   andreslopez@gmail.com  NaN   17000     Cadiz      No
# 4  Monica   Castro  monicacastro@gmail.com   53   20000    Burgos     NaN
# 5     Ana    Perez     saraperez@gmail.com   67   65000    Madrid     Yes

# %% [markdown]
# Si queremos cambiar un solo valor dentro del dataframe, por ejemplo, cambiar el apellido a Monica Castro, utilizaremos la propiedad `loc` indicando el índice de
# fila y la columna a cambiar.

# %%
df.loc[4, 'apellido'] = 'Romero'

df
# Out:
#    nombre apellido                   email edad  salary    ciudad married
# 0   Marta     Ruiz     martaruiz@gmail.com   35   20000    Madrid     Yes
# 1    Luis    Lopez     luislopez@gmail.com   28   25000  Valencia      No
# 2     Ana  Santana    anasantana@gmail.com   35   50000    Malaga     Yes
# 3  Andres    Lopez   andreslopez@gmail.com  NaN   17000     Cadiz      No
# 4  Monica   Romero  monicacastro@gmail.com   53   20000    Burgos     NaN
# 5     Ana    Perez     saraperez@gmail.com   67   65000    Madrid     Yes

# %% [markdown]
# En esta ocasión, vamos a cambiar la edad y el salario de Marta Ruiz.

# %%
df.loc[0, ['edad', 'salary']] =[70, 78000]

df
# Out:
#    nombre apellido                   email edad  salary    ciudad married
# 0   Marta     Ruiz     martaruiz@gmail.com   70   78000    Madrid     Yes
# 1    Luis    Lopez     luislopez@gmail.com   28   25000  Valencia      No
# 2     Ana  Santana    anasantana@gmail.com   35   50000    Malaga     Yes
# 3  Andres    Lopez   andreslopez@gmail.com  NaN   17000     Cadiz      No
# 4  Monica   Romero  monicacastro@gmail.com   53   20000    Burgos     NaN
# 5     Ana    Perez     saraperez@gmail.com   67   65000    Madrid     Yes

# %% [markdown]
# Una propiedad parecida a `loc` es la funcion `at` pero ésta solo cambia un único dato.
#
# En el siguiente snippet, vamos a darle a Marta Ruiz de nuevo su edad a 35 usando la propiedad `at`.
#
# Más info en [Pandas](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.at.html#pandas.DataFrame.at).

# %%
df.at[0, 'edad'] = 35

df
# Out:
#    nombre apellido                   email edad  salary    ciudad married
# 0   Marta     Ruiz     martaruiz@gmail.com   35   78000    Madrid     Yes
# 1    Luis    Lopez     luislopez@gmail.com   28   25000  Valencia      No
# 2     Ana  Santana    anasantana@gmail.com   35   50000    Malaga     Yes
# 3  Andres    Lopez   andreslopez@gmail.com  NaN   17000     Cadiz      No
# 4  Monica   Romero  monicacastro@gmail.com   53   20000    Burgos     NaN
# 5     Ana    Perez     saraperez@gmail.com   67   65000    Madrid     Yes

# %% [markdown]
# Vamos a cambiar los nombres de columnas que quedaban en ingles al español (salary y married).

# %%
df.rename(columns={'salary': 'salario', 'married': 'casado'}, inplace=True)

df
# Out:
#    nombre apellido                   email edad  salario    ciudad casado
# 0   Marta     Ruiz     martaruiz@gmail.com   35    78000    Madrid    Yes
# 1    Luis    Lopez     luislopez@gmail.com   28    25000  Valencia     No
# 2     Ana  Santana    anasantana@gmail.com   35    50000    Malaga    Yes
# 3  Andres    Lopez   andreslopez@gmail.com  NaN    17000     Cadiz     No
# 4  Monica   Romero  monicacastro@gmail.com   53    20000    Burgos    NaN
# 5     Ana    Perez     saraperez@gmail.com   67    65000    Madrid    Yes

# %% [markdown]
# Esta vez queremos cambiar la ciudad de la fila en la que el email es "saraperez@gmail.com".
#
# De nuevo, usamos una variable (`filt`) para almacenar los valores booleanos del filtro creado y luego lo usamos en la propiedad `loc`.

# %%
filt= (df['email'] == 'saraperez@gmail.com')

filt
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5     True
# Name: email, dtype: bool

# %%
df.loc[filt, 'ciudad'] = 'Paris'

df
# Out:
#    nombre apellido                   email edad  salario    ciudad casado
# 0   Marta     Ruiz     martaruiz@gmail.com   35    78000    Madrid    Yes
# 1    Luis    Lopez     luislopez@gmail.com   28    25000  Valencia     No
# 2     Ana  Santana    anasantana@gmail.com   35    50000    Malaga    Yes
# 3  Andres    Lopez   andreslopez@gmail.com  NaN    17000     Cadiz     No
# 4  Monica   Romero  monicacastro@gmail.com   53    20000    Burgos    NaN
# 5     Ana    Perez     saraperez@gmail.com   67    65000     Paris    Yes

# %% [markdown]
# Si queremos actualizar multiples filas y convertirlas en mayúsculas, usaremos el método `str.upper()` de los Strings en la columna que queramos modificar.

# %%
df['email'].str.upper()
# Out:
# 0       MARTARUIZ@GMAIL.COM
# 1       LUISLOPEZ@GMAIL.COM
# 2      ANASANTANA@GMAIL.COM
# 3     ANDRESLOPEZ@GMAIL.COM
# 4    MONICACASTRO@GMAIL.COM
# 5       SARAPEREZ@GMAIL.COM
# Name: email, dtype: object

# %% [markdown]
# Si ahora queremos ver todo el dataframe con los emails conertidos a mayúsculas, aplicaremos la sentencia del snippet anterior a la columna "email" de nuestro dataframe.

# %%
df['email']= df['email'].str.upper()

df
# Out:
#    nombre apellido                   email edad  salario    ciudad casado
# 0   Marta     Ruiz     MARTARUIZ@GMAIL.COM   35    78000    Madrid    Yes
# 1    Luis    Lopez     LUISLOPEZ@GMAIL.COM   28    25000  Valencia     No
# 2     Ana  Santana    ANASANTANA@GMAIL.COM   35    50000    Malaga    Yes
# 3  Andres    Lopez   ANDRESLOPEZ@GMAIL.COM  NaN    17000     Cadiz     No
# 4  Monica   Romero  MONICACASTRO@GMAIL.COM   53    20000    Burgos    NaN
# 5     Ana    Perez     SARAPEREZ@GMAIL.COM   67    65000     Paris    Yes

# %% [markdown]
# ---
#
#
# Vamos a usar varios métodos muy utiles para cambiar datos de un dataframe como son:
# +   `apply()`. Mas info en [Pandas](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.apply.html).
# +   `map()`. Mas info en [Pandas](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.map.html).
# +   `applymap()`. Mas info en [Pandas](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.applymap.html). *Este método ya está obsoleto a partir de la versión 2.1.0 de Pandas, y en su lugar se usa `map()`*.
# +   `replace()`. Mas info en [Pandas](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.replace.html).

# %% [markdown]
# El método `apply()` aplica una función a lo largo de un eje (fila o columna) del dataFrame.
#
# En esta ocasión aplica la función `len` (sin paréntesis) para que nos devuelva la longitud de los valores de la columna "*email*".

# %%
df['email'].apply(len)
# Out:
# 0    19
# 1    19
# 2    20
# 3    21
# 4    22
# 5    19
# Name: email, dtype: int64

# %% [markdown]
# El método `apply()` también se puede usar con funciones propias creadas por nosotros.

# %%
def actualiza_email(email):
  return email.lower()

df['email'].apply(actualiza_email)  # En esta sentencia solo visualizamos la aplicación de la función que hemos creado.
# Out:
# 0       martaruiz@gmail.com
# 1       luislopez@gmail.com
# 2      anasantana@gmail.com
# 3     andreslopez@gmail.com
# 4    monicacastro@gmail.com
# 5       saraperez@gmail.com
# Name: email, dtype: object

# %% [markdown]
# A continuación, aplicamos los cambios de la función creada anteriormente `actualiza_email()`, a nuestro dataframe.

# %%
df['email'] = df['email'].apply(actualiza_email)

df
# Out:
#    nombre apellido                   email edad  salario    ciudad casado
# 0   Marta     Ruiz     martaruiz@gmail.com   35    78000    Madrid    Yes
# 1    Luis    Lopez     luislopez@gmail.com   28    25000  Valencia     No
# 2     Ana  Santana    anasantana@gmail.com   35    50000    Malaga    Yes
# 3  Andres    Lopez   andreslopez@gmail.com  NaN    17000     Cadiz     No
# 4  Monica   Romero  monicacastro@gmail.com   53    20000    Burgos    NaN
# 5     Ana    Perez     saraperez@gmail.com   67    65000     Paris    Yes

# %% [markdown]
# ---
#
#
#
# Si utilizamos el método `appy()` para Series (una sola columna)
# no nos muestra lo que nosotros buscabamos que era la longitud (*len*) de todos los valores del dataframe. Solo nos muestra la cantidad de elementos que contiene cada columna, que son 6.
#
#
# > Para Dataframes usamos el método `applymap()`.

# %%
df.apply(len)
# Out:
# nombre      6
# apellido    6
# email       6
# edad        6
# salario     6
# ciudad      6
# casado      6
# dtype: int64

# %% [markdown]
# Vamos a usar el método `applymap()` a continuación.
#
# El siguiente snippet nos da error porque las columnas "*edad*" y "*salario*" tienen valores ***integer***. Más adelante tendremos que cambiar esos valores a *strings*.

# %%
df.applymap(len)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-108-d38ddfc50172> in <cell line: 1>()
# ----> 1 df.applymap(len)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in applymap(self, func, na_action, **kwargs)
#    9651             return lib.map_infer(x.astype(object)._values, func, ignore_na=ignore_na)
#    9652
# -> 9653         return self.apply(infer).__finalize__(self, "applymap")
#    9654
#    9655     # ----------------------------------------------------------------------
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in apply(self, func, axis, raw, result_type, args, **kwargs)
#    9566             kwargs=kwargs,
#    9567         )
# -> 9568         return op.apply().__finalize__(self, method="apply")
#    9569
#    9570     def applymap(
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/apply.py in apply(self)
#     762             return self.apply_raw()
#     763
# --> 764         return self.apply_standard()
#     765
#     766     def agg(self):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/apply.py in apply_standard(self)
#     889
#     890     def apply_standard(self):
# --> 891         results, res_index = self.apply_series_generator()
#     892
#     893         # wrap results
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/apply.py in apply_series_generator(self)
#     905             for i, v in enumerate(series_gen):
#     906                 # ignore SettingWithCopy here in case the user mutates
# --> 907                 results[i] = self.f(v)
#     908                 if isinstance(results[i], ABCSeries):
#     909                     # If we have a view on v, we need to make a copy because
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in infer(x)
#    9649             if x.empty:
#    9650                 return lib.map_infer(x, func, ignore_na=ignore_na)
# -> 9651             return lib.map_infer(x.astype(object)._values, func, ignore_na=ignore_na)
#    9652
#    9653         return self.apply(infer).__finalize__(self, "applymap")
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# TypeError: object of type 'int' has no len()

# %% [markdown]
# En esta ocasión, vamos a crear un nuevo dataframe pero con las columnas "*edad*" y "*salario*" de tipo *string*.
#
# Nuevamente, creamos un diccionario con los nombres las columnas y los valores de cada columna en una lista.
#
# Luego, como siempre, pasaremos ese diccionario a un dataframe.

# %%
gentestr={
    'nombre': ['Marta', 'Luis', 'Ana', 'Andres', 'Monica', 'Ana'],
    'apellido': ['Ruiz', 'Lopez', 'Santana', 'Lopez', 'Castro', 'Perez'],
    'email': ['martaruiz@gmail.com', 'luislopez@gmail.com', 'anasantana@gmail.com', 'andreslopez@gmail.com', 'monicacastro@gmail.com', 'saraperez@gmail.com'],
    'edad': ['35', '28', '35', 'NaN', '53', '67'],
    'salario': ['20000', '25000', '50000', '17000', '20000', '65000'],
    'ciudad' :['Madrid', 'Valencia', 'Malaga', 'Cadiz', 'Burgos', 'Madrid'],
    'casado': ['Yes', 'No', 'Yes', 'No', 'NaN', 'Yes']
}

#NaN =   not a number

# %%
df=pd.DataFrame(gentestr)

df
# Out:
#    nombre apellido                   email edad salario    ciudad casado
# 0   Marta     Ruiz     martaruiz@gmail.com   35   20000    Madrid    Yes
# 1    Luis    Lopez     luislopez@gmail.com   28   25000  Valencia     No
# 2     Ana  Santana    anasantana@gmail.com   35   50000    Malaga    Yes
# 3  Andres    Lopez   andreslopez@gmail.com  NaN   17000     Cadiz     No
# 4  Monica   Castro  monicacastro@gmail.com   53   20000    Burgos    NaN
# 5     Ana    Perez     saraperez@gmail.com   67   65000    Madrid    Yes

# %% [markdown]
# Ahora si podemos aplicar la funcion `len()` a todo el dataframe y nos da la longitud de todos los valores de cada columna del dataframe.

# %%
df.applymap(len)
# Out:
#    nombre  apellido  email  edad  salario  ciudad  casado
# 0       5         4     19     2        5       6       3
# 1       4         5     19     2        5       8       2
# 2       3         7     20     2        5       6       3
# 3       6         5     21     3        5       5       2
# 4       6         6     22     2        5       6       3
# 5       3         5     19     2        5       6       3

# %% [markdown]
# Si queremos que todos los valores del dataframe pasen a mayúsculas, aplicamos el método `str.upper()` pasándolo como parámetro de nuestro método para dataframes `applymap()`.

# %%
df.applymap(str.upper)
# Out:
#    nombre apellido                   email edad salario    ciudad casado
# 0   MARTA     RUIZ     MARTARUIZ@GMAIL.COM   35   20000    MADRID    YES
# 1    LUIS    LOPEZ     LUISLOPEZ@GMAIL.COM   28   25000  VALENCIA     NO
# 2     ANA  SANTANA    ANASANTANA@GMAIL.COM   35   50000    MALAGA    YES
# 3  ANDRES    LOPEZ   ANDRESLOPEZ@GMAIL.COM  NAN   17000     CADIZ     NO
# 4  MONICA   CASTRO  MONICACASTRO@GMAIL.COM   53   20000    BURGOS    NAN
# 5     ANA    PEREZ     SARAPEREZ@GMAIL.COM   67   65000    MADRID    YES

# %% [markdown]
# Volvemos a dejar los valores en minúsculas.

# %%
df.applymap(str.lower)
# Out:
#    nombre apellido                   email edad salario    ciudad casado
# 0   marta     ruiz     martaruiz@gmail.com   35   20000    madrid    yes
# 1    luis    lopez     luislopez@gmail.com   28   25000  valencia     no
# 2     ana  santana    anasantana@gmail.com   35   50000    malaga    yes
# 3  andres    lopez   andreslopez@gmail.com  nan   17000     cadiz     no
# 4  monica   castro  monicacastro@gmail.com   53   20000    burgos    nan
# 5     ana    perez     saraperez@gmail.com   67   65000    madrid    yes

# %% [markdown]
# ---
#
# Como dijimos anteriormente, el método `map()` sustituye al método `applymap()`, quedando este último obsoleto a partir de la versión 2.1.0 de Pandas.
#
# En el siguiente snippet, queremos cambiar dos valores de la columna "*nombre*".
#
# <mark>* *Los nombres que no se han cambiado muestra NaN (Not A Number)*</mark>

# %%
df['nombre'].map({'Marta':'Sofia','Andres':'Sandalio'})
# Out:
# 0       Sofia
# 1         NaN
# 2         NaN
# 3    Sandalio
# 4         NaN
# 5         NaN
# Name: nombre, dtype: object

# %% [markdown]
# También podemos usar el método de Pandas `replace()`.

# %%
df['apellido'].replace({'Lopez': 'Santos', 'Perez': 'Salmeron'})
# Out:
# 0        Ruiz
# 1      Santos
# 2     Santana
# 3      Santos
# 4      Castro
# 5    Salmeron
# Name: apellido, dtype: object

# %% [markdown]
# Si vemos como queda el dataframe original vemos que los cambios realizados en las columnas "*nombre*" y "*apellido*" con ambos métodos solo eran temporales.

# %%
df
# Out:
#    nombre apellido                   email edad salario    ciudad casado
# 0   Marta     Ruiz     martaruiz@gmail.com   35   20000    Madrid    Yes
# 1    Luis    Lopez     luislopez@gmail.com   28   25000  Valencia     No
# 2     Ana  Santana    anasantana@gmail.com   35   50000    Malaga    Yes
# 3  Andres    Lopez   andreslopez@gmail.com  NaN   17000     Cadiz     No
# 4  Monica   Castro  monicacastro@gmail.com   53   20000    Burgos    NaN
# 5     Ana    Perez     saraperez@gmail.com   67   65000    Madrid    Yes

# %% [markdown]
# Por tanto, tal y como hemos hecho en snippets anteriores, si queremos que los cambios queden fijos en el dataframe original entonces haremos lo siguiente, en este caso para la columna "*apellido*" y usando el método `replace()`.

# %%
df['apellido'] =df['apellido'].replace({'Lopez': 'Santos', 'Perez': 'Salmeron'})

df
# Out:
#    nombre  apellido                   email edad salario    ciudad casado
# 0   Marta      Ruiz     martaruiz@gmail.com   35   20000    Madrid    Yes
# 1    Luis    Santos     luislopez@gmail.com   28   25000  Valencia     No
# 2     Ana   Santana    anasantana@gmail.com   35   50000    Malaga    Yes
# 3  Andres    Santos   andreslopez@gmail.com  NaN   17000     Cadiz     No
# 4  Monica    Castro  monicacastro@gmail.com   53   20000    Burgos    NaN
# 5     Ana  Salmeron     saraperez@gmail.com   67   65000    Madrid    Yes

# %% [markdown]
# ### <u>***UNIDAD 6. AÑADIR Y QUITAR FILAS Y COLUMNAS DEL DATAFRAME. - COMBINAR INFORMACION***</u>

# %% [markdown]
# Podemos añadir una columna con la siguiente sintaxis:
#
# 1. Primero vemos como concatenar los valores de dos columnas.

# %%
#para añadir columnas usamos

df['nombre'] + ' ' + df['apellido']
# Out:
# 0       Marta Ruiz
# 1      Luis Santos
# 2      Ana Santana
# 3    Andres Santos
# 4    Monica Castro
# 5     Ana Salmeron
# dtype: object

# %% [markdown]
# 2. Luego, en este caso, queremos crear una nueva columna "*nombre_apellido*", que contenga los valores de las columnas "*nombre*" y "*apellido*" separados por un espacio.

# %%
df['nombre_apellido'] = df['nombre']+ ' ' +df['apellido']

df
# Out:
#    nombre  apellido                   email edad salario    ciudad casado  \
# 0   Marta      Ruiz     martaruiz@gmail.com   35   20000    Madrid    Yes
# 1    Luis    Santos     luislopez@gmail.com   28   25000  Valencia     No
# 2     Ana   Santana    anasantana@gmail.com   35   50000    Malaga    Yes
# 3  Andres    Santos   andreslopez@gmail.com  NaN   17000     Cadiz     No
# 4  Monica    Castro  monicacastro@gmail.com   53   20000    Burgos    NaN
# 5     Ana  Salmeron     saraperez@gmail.com   67   65000    Madrid    Yes
#
#   nombre_apellido
# 0      Marta Ruiz
# 1     Luis Santos
# 2     Ana Santana
# 3   Andres Santos
# 4   Monica Castro
# 5    Ana Salmeron

# %% [markdown]
# ---
#
#
# Ahora vamos a quitar columnas utilizando el método `drop()` de Pandas.
#
# Más info en [Pandas](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.drop.html).

# %%
df.drop(columns= ['nombre', 'apellido'])
# Out:
#                     email edad salario    ciudad casado nombre_apellido
# 0     martaruiz@gmail.com   35   20000    Madrid    Yes      Marta Ruiz
# 1     luislopez@gmail.com   28   25000  Valencia     No     Luis Santos
# 2    anasantana@gmail.com   35   50000    Malaga    Yes     Ana Santana
# 3   andreslopez@gmail.com  NaN   17000     Cadiz     No   Andres Santos
# 4  monicacastro@gmail.com   53   20000    Burgos    NaN   Monica Castro
# 5     saraperez@gmail.com   67   65000    Madrid    Yes    Ana Salmeron

# %%
# Como en casos anteriores, vemos que no ha hecho el cambio permanente.

df
# Out:
#    nombre  apellido                   email edad salario    ciudad casado  \
# 0   Marta      Ruiz     martaruiz@gmail.com   35   20000    Madrid    Yes
# 1    Luis    Santos     luislopez@gmail.com   28   25000  Valencia     No
# 2     Ana   Santana    anasantana@gmail.com   35   50000    Malaga    Yes
# 3  Andres    Santos   andreslopez@gmail.com  NaN   17000     Cadiz     No
# 4  Monica    Castro  monicacastro@gmail.com   53   20000    Burgos    NaN
# 5     Ana  Salmeron     saraperez@gmail.com   67   65000    Madrid    Yes
#
#   nombre_apellido
# 0      Marta Ruiz
# 1     Luis Santos
# 2     Ana Santana
# 3   Andres Santos
# 4   Monica Castro
# 5    Ana Salmeron

# %% [markdown]
# Procedemos a realizar el cambio permanente, que se consigue con el parámetro `inplace=True`

# %%
df.drop(columns= ['nombre', 'apellido'], inplace=True)

df
# Out:
#                     email edad salario    ciudad casado nombre_apellido
# 0     martaruiz@gmail.com   35   20000    Madrid    Yes      Marta Ruiz
# 1     luislopez@gmail.com   28   25000  Valencia     No     Luis Santos
# 2    anasantana@gmail.com   35   50000    Malaga    Yes     Ana Santana
# 3   andreslopez@gmail.com  NaN   17000     Cadiz     No   Andres Santos
# 4  monicacastro@gmail.com   53   20000    Burgos    NaN   Monica Castro
# 5     saraperez@gmail.com   67   65000    Madrid    Yes    Ana Salmeron

# %% [markdown]
# Para revertir lo hecho y convertir la columna "*nombre_apellido*" en dos columnas una para "*nombre*" y otra para "*apellido*", necesitamos utilizar el método `str.split()` de Series de Pandas.
#
# Más info en [Pandas](https://pandas.pydata.org/docs/reference/api/pandas.Series.str.split.html#pandas.Series.str.split).
#
# 1. Primero vemos cómo funciona el método `str.split()`.

# %%
df['nombre_apellido'].str.split(' ')
# Out:
# 0       [Marta, Ruiz]
# 1      [Luis, Santos]
# 2      [Ana, Santana]
# 3    [Andres, Santos]
# 4    [Monica, Castro]
# 5     [Ana, Salmeron]
# Name: nombre_apellido, dtype: object

# %% [markdown]
# 2. Ahora, para que pongamos estos datos en dos columnas necesitamos usar el parámetro `expand=True`.
#
# >> Este parámetro expande las cadenas divididas en columnas separadas, de tal forma que:
# +   Si es `True`, devuelve DataFrame / MultiIndice expandiendo la dimensionalidad (creando una columna para cada string resultante de la división (split).
# +   Si es `False`, devuelve Series/Index, que contiene listas de cadenas.

# %%
df['nombre_apellido'].str.split(' ', expand=True)
# Out:
#         0         1
# 0   Marta      Ruiz
# 1    Luis    Santos
# 2     Ana   Santana
# 3  Andres    Santos
# 4  Monica    Castro
# 5     Ana  Salmeron

# %% [markdown]
# Evidentemente, ahora toca realizar esta acción en el dataframe, creando las dos nuevas columnas "*nombre*" y "*apellido*" y asignandoles como valores el resultado de divivir el valor de la columna "*nombre_apellido*", tal y como hemos hecho en la sentencia del snippet anterior.

# %%
df[['nombre', 'apellido']] = df['nombre_apellido'].str.split(' ', expand=True)

# %%
# Visualizamos los cambios realizados.

df
# Out:
#                     email edad salario    ciudad casado nombre_apellido  \
# 0     martaruiz@gmail.com   35   20000    Madrid    Yes      Marta Ruiz
# 1     luislopez@gmail.com   28   25000  Valencia     No     Luis Santos
# 2    anasantana@gmail.com   35   50000    Malaga    Yes     Ana Santana
# 3   andreslopez@gmail.com  NaN   17000     Cadiz     No   Andres Santos
# 4  monicacastro@gmail.com   53   20000    Burgos    NaN   Monica Castro
# 5     saraperez@gmail.com   67   65000    Madrid    Yes    Ana Salmeron
#
#    nombre  apellido
# 0   Marta      Ruiz
# 1    Luis    Santos
# 2     Ana   Santana
# 3  Andres    Santos
# 4  Monica    Castro
# 5     Ana  Salmeron

# %% [markdown]
# ---
#
#
# Podemos añadir una fila a un dataframe, sin importar si queremos rellenar todos los valores de todas las columnas o solo una parte de ellas.
#
# En el siguiente snippet, vamos a añadir una nueva persona y solo vamos a añadir el campo "*nombre*". El resto de columnas se rellenarán como ***NaN***.

# %%
fila = {'nombre':'Peter'}

df.loc[len(df)] = fila

# Puedes añadir al diccionario los otros valores para llenar todas las celdas
# con informacion sobre Peter si quieres hacer pruebas.

# %%
df
# Out:
#                     email edad salario    ciudad casado nombre_apellido  \
# 0     martaruiz@gmail.com   35   20000    Madrid    Yes      Marta Ruiz
# 1     luislopez@gmail.com   28   25000  Valencia     No     Luis Santos
# 2    anasantana@gmail.com   35   50000    Malaga    Yes     Ana Santana
# 3   andreslopez@gmail.com  NaN   17000     Cadiz     No   Andres Santos
# 4  monicacastro@gmail.com   53   20000    Burgos    NaN   Monica Castro
# 5     saraperez@gmail.com   67   65000    Madrid    Yes    Ana Salmeron
# 6                     NaN  NaN     NaN       NaN    NaN             NaN
#
#    nombre  apellido
# 0   Marta      Ruiz
# 1    Luis    Santos
# 2     Ana   Santana
# 3  Andres    Santos
# 4  Monica    Castro
# 5     Ana  Salmeron
# 6   Peter       NaN

# %%
# Para quitar filas usamos los indices

df = df.drop(index=6)
# Out:
#                     email edad salario    ciudad casado nombre_apellido  \
# 0     martaruiz@gmail.com   35   20000    Madrid    Yes      Marta Ruiz
# 1     luislopez@gmail.com   28   25000  Valencia     No     Luis Santos
# 2    anasantana@gmail.com   35   50000    Malaga    Yes     Ana Santana
# 3   andreslopez@gmail.com  NaN   17000     Cadiz     No   Andres Santos
# 4  monicacastro@gmail.com   53   20000    Burgos    NaN   Monica Castro
# 5     saraperez@gmail.com   67   65000    Madrid    Yes    Ana Salmeron
#
#    nombre  apellido
# 0   Marta      Ruiz
# 1    Luis    Santos
# 2     Ana   Santana
# 3  Andres    Santos
# 4  Monica    Castro
# 5     Ana  Salmeron

# %%
# Para eliminar mas filas de golpe enumeramos los índices a eliminar.

df = df.drop(index=[3,4,5])

df
# Out:
#                   email edad salario    ciudad casado nombre_apellido nombre  \
# 0   martaruiz@gmail.com   35   20000    Madrid    Yes      Marta Ruiz  Marta
# 1   luislopez@gmail.com   28   25000  Valencia     No     Luis Santos   Luis
# 2  anasantana@gmail.com   35   50000    Malaga    Yes     Ana Santana    Ana
#
#   apellido
# 0     Ruiz
# 1   Santos
# 2  Santana

# %%
# Para eliminar mas filas usando el slicing o rango de indices

df=df.drop(df.index[1:3])

df
# Out:
#                  email edad salario  ciudad casado nombre_apellido nombre  \
# 0  martaruiz@gmail.com   35   20000  Madrid    Yes      Marta Ruiz  Marta
#
#   apellido
# 0     Ruiz

# %% [markdown]
# ### <u>***UNIDAD 7. CLASIFICAR DATOS***</u>

# %% [markdown]
# En esta unidad volvemos a crear un diccionario que nos servirá soporte para introducir datos en el dataframe.

# %%
gente={
    'nombre': ['Marta', 'Luis', 'Ana', 'Andres', 'Monica', 'Ana'],
    'apellido': ['Ruiz', 'Lopez', 'Santana', 'Lopez', 'Castro', 'Perez'],
    'email': ['martaruiz@gmail.com', 'luislopez@gmail.com', 'anasantana@gmail.com', 'andreslopez@gmail.com', 'monicacastro@gmail.com', 'saraperez@gmail.com'],
    'edad': [35, 28, 35, 'NaN', 53, 67],
    'salario': [20000, 25000, 50000, 17000, 20000, 65000],
    'ciudad' :['Madrid', 'Valencia', 'Malaga', 'Cadiz', 'Burgos', 'Madrid'],
    'casado': ['Yes', 'No', 'Yes', 'No', 'NaN', 'Yes']
}

# %%
df=pd.DataFrame(gente)

df
# Out:
#    nombre apellido                   email edad  salario    ciudad casado
# 0   Marta     Ruiz     martaruiz@gmail.com   35    20000    Madrid    Yes
# 1    Luis    Lopez     luislopez@gmail.com   28    25000  Valencia     No
# 2     Ana  Santana    anasantana@gmail.com   35    50000    Malaga    Yes
# 3  Andres    Lopez   andreslopez@gmail.com  NaN    17000     Cadiz     No
# 4  Monica   Castro  monicacastro@gmail.com   53    20000    Burgos    NaN
# 5     Ana    Perez     saraperez@gmail.com   67    65000    Madrid    Yes

# %% [markdown]
# ---
#
#
#
# Ordenamos el dataframe por la columna "nombre" usando el método `sort_values()` y el parámetro *`by=nombre_de_columna`*.
#
# Mas info en [Pandas](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.sort_values.html).

# %%
df.sort_values(by='nombre')
# Out:
#    nombre apellido                   email edad  salario    ciudad casado
# 2     Ana  Santana    anasantana@gmail.com   35    50000    Malaga    Yes
# 5     Ana    Perez     saraperez@gmail.com   67    65000    Madrid    Yes
# 3  Andres    Lopez   andreslopez@gmail.com  NaN    17000     Cadiz     No
# 1    Luis    Lopez     luislopez@gmail.com   28    25000  Valencia     No
# 0   Marta     Ruiz     martaruiz@gmail.com   35    20000    Madrid    Yes
# 4  Monica   Castro  monicacastro@gmail.com   53    20000    Burgos    NaN

# %% [markdown]
# Si queremos que el orden sea descendente, usaremos el parámento *`ascending=False`*

# %%
df.sort_values(by='nombre', ascending=False)
# Out:
#    nombre apellido                   email edad  salario    ciudad casado
# 4  Monica   Castro  monicacastro@gmail.com   53    20000    Burgos    NaN
# 0   Marta     Ruiz     martaruiz@gmail.com   35    20000    Madrid    Yes
# 1    Luis    Lopez     luislopez@gmail.com   28    25000  Valencia     No
# 3  Andres    Lopez   andreslopez@gmail.com  NaN    17000     Cadiz     No
# 2     Ana  Santana    anasantana@gmail.com   35    50000    Malaga    Yes
# 5     Ana    Perez     saraperez@gmail.com   67    65000    Madrid    Yes

# %% [markdown]
# Si queremos ordenar por más de una columna, y ambas en orden ascendente, añadiremos enel parametro `ascending` una lista de las columnas a ordenar.
#
# En nuestro caso, vamos a ordenar por "*apellido*" en orden ascendente y por "*nombre*" y podemos ver que los nombres de "Andres" y "Luis", ambos el apellido "Lopez" tambien están en orden ascendente.

# %%
df.sort_values(by=['apellido', 'nombre'])
# Out:
#    nombre apellido                   email edad  salario    ciudad casado
# 4  Monica   Castro  monicacastro@gmail.com   53    20000    Burgos    NaN
# 3  Andres    Lopez   andreslopez@gmail.com  NaN    17000     Cadiz     No
# 1    Luis    Lopez     luislopez@gmail.com   28    25000  Valencia     No
# 5     Ana    Perez     saraperez@gmail.com   67    65000    Madrid    Yes
# 0   Marta     Ruiz     martaruiz@gmail.com   35    20000    Madrid    Yes
# 2     Ana  Santana    anasantana@gmail.com   35    50000    Malaga    Yes

# %% [markdown]
# Si ahora queremos que los apellidos esten en orden descendente y los nombres en orden ascendente usamos una lista de booleanos en el parametro `ascending`.

# %%
df.sort_values(by=['apellido', 'nombre'], ascending=[False, True])
# Out:
#    nombre apellido                   email edad  salario    ciudad casado
# 2     Ana  Santana    anasantana@gmail.com   35    50000    Malaga    Yes
# 0   Marta     Ruiz     martaruiz@gmail.com   35    20000    Madrid    Yes
# 5     Ana    Perez     saraperez@gmail.com   67    65000    Madrid    Yes
# 3  Andres    Lopez   andreslopez@gmail.com  NaN    17000     Cadiz     No
# 1    Luis    Lopez     luislopez@gmail.com   28    25000  Valencia     No
# 4  Monica   Castro  monicacastro@gmail.com   53    20000    Burgos    NaN

# %% [markdown]
# De nuevo, si queremos dejar fijos estos cambios añadiremos el parámetro `inplace=True` al final del parentesis y despues de una coma

# %%
df.sort_values(by=['apellido', 'nombre'], ascending=[False, True], inplace=True)

# %% [markdown]
# Si queremos tener los indices ordenados otra vez (0, 1, 2, 3, etc...), usaremos el método `sort_index()`.

# %%
df.sort_index()
# Out:
#    nombre apellido                   email edad  salario    ciudad casado
# 0   Marta     Ruiz     martaruiz@gmail.com   35    20000    Madrid    Yes
# 1    Luis    Lopez     luislopez@gmail.com   28    25000  Valencia     No
# 2     Ana  Santana    anasantana@gmail.com   35    50000    Malaga    Yes
# 3  Andres    Lopez   andreslopez@gmail.com  NaN    17000     Cadiz     No
# 4  Monica   Castro  monicacastro@gmail.com   53    20000    Burgos    NaN
# 5     Ana    Perez     saraperez@gmail.com   67    65000    Madrid    Yes

# %% [markdown]
# Si queremos ordenar los datos de una sola columna, por ejemplo "*apellido*", aplicaremos el método `sort_values()` en la columna pertinente del dataframe.

# %%
df['apellido'].sort_values()
# Out:
# 4     Castro
# 1      Lopez
# 3      Lopez
# 5      Perez
# 0       Ruiz
# 2    Santana
# Name: apellido, dtype: object

# %% [markdown]
# > El método `nlargest()` de dataframe de Pandas, devuelve las *n* primeras filas ordenadas por columnas en orden descendente.
#
# Si queremos ver, por ejemplo,  los 3 salarios más altos en nuestro dataframe, pasaremos el número de filas como parámetro de el método `nlargest()`.
#
# Más info en [Pandas](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.nlargest.html).

# %%
df['salario'].nlargest(3)
# Out:
# 5    65000
# 2    50000
# 1    25000
# Name: salario, dtype: int64

# %% [markdown]
# Si queremos que nos muestre toda la informacion de las personas con los 3 salarios mas altos, llamaremos al método `nlargest()` directamente sobre el dataframe, añadiendo como parámetro la columna pertinente, en vez de aplicar el método sobre la columna del dataframe.

# %%
df.nlargest(3, 'salario')
# Out:
#   nombre apellido                 email edad  salario    ciudad casado
# 5    Ana    Perez   saraperez@gmail.com   67    65000    Madrid    Yes
# 2    Ana  Santana  anasantana@gmail.com   35    50000    Malaga    Yes
# 1   Luis    Lopez   luislopez@gmail.com   28    25000  Valencia     No

# %% [markdown]
# ---
#
#
# > El método `nsmallest()` Devuelve las *n* primeras filas ordenadas por columnas en orden ascendente.
#
# En nuestro dataframe,por el contrario, si lo que queremos es mostrar la información de los 2 salarios más bajos, utilizaremos el método `nsmallest()` e incluiremos los parámetros de números de filas a devolver y la columna a mostrar.

# %%
df.nsmallest(2, 'salario')
# Out:
#    nombre apellido                  email edad  salario  ciudad casado
# 3  Andres    Lopez  andreslopez@gmail.com  NaN    17000   Cadiz     No
# 0   Marta     Ruiz    martaruiz@gmail.com   35    20000  Madrid    Yes

# %% [markdown]
# ### <u>***UNIDAD 8. AGREGAR Y AGRUPAR DATOS***</u>

# %% [markdown]
# Creamos un nuevo dataframe.

# %%
gentestr={
    'nombre': ['Marta', 'Luis', 'Ana', 'Andres', 'Monica', 'Ana', 'Rocio', 'Pepe'],
    'apellido': ['Ruiz', 'Lopez', 'Santana', 'Lopez', 'Castro', 'Perez', 'Iglesias', 'Fuentes'],
    'email': ['martaruiz@gmail.com', 'luislopez@gmail.com', 'anasantana@gmail.com', 'andreslopez@gmail.com',
    'monicacastro@gmail.com', 'saraperez@gmail.com', 'rocioiglesias@gmail.com', 'pepefuentes@gmail.com'],
    'edad': [35, 28, 35, 49, 53, 67, 73, 19],
    'salario': ['20000', '25000', '50000', '17000', '20000', '65000', '83000', '97000'],
    'ciudad' :['Madrid', 'Valencia', 'Malaga', 'Cadiz', 'Burgos', 'Madrid', 'Madrid', 'Madrid'],
    'casado': ['Yes', 'No', 'Yes', 'No', 'NaN', 'Yes', 'Yes', 'No']
}

# %%
df=pd.DataFrame(gentestr)

df
# Out:
#    nombre  apellido                    email  edad salario    ciudad casado
# 0   Marta      Ruiz      martaruiz@gmail.com    35   20000    Madrid    Yes
# 1    Luis     Lopez      luislopez@gmail.com    28   25000  Valencia     No
# 2     Ana   Santana     anasantana@gmail.com    35   50000    Malaga    Yes
# 3  Andres     Lopez    andreslopez@gmail.com    49   17000     Cadiz     No
# 4  Monica    Castro   monicacastro@gmail.com    53   20000    Burgos    NaN
# 5     Ana     Perez      saraperez@gmail.com    67   65000    Madrid    Yes
# 6   Rocio  Iglesias  rocioiglesias@gmail.com    73   83000    Madrid    Yes
# 7    Pepe   Fuentes    pepefuentes@gmail.com    19   97000    Madrid     No

# %% [markdown]
# ---
#
#
#
# Comencemos con las funciones de agregación.
#
# > El método `median()`, devuelve la mediana de los valores sobre el eje (fila o columna) solicitado.
#
# Si queremos mostrar la mediana de una columna en concreto, aplicaremos el método `median()` sobre la columna del dataframe.
#
# Más info en [Pandas](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.median.html).

# %%
df['salario'].median()
# Out:
# 37500.0

# %% [markdown]
# > El método `mode()` obtiene el modo(s) de cada elemento a lo largo del eje seleccionado.
#
# Nuevamente, aplicamos el método sobre una columna del dataframe en concreto.
#
# Más info en [Pandas](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.mode.html).

# %%
df['salario'].mode()
# Out:
# 0    20000
# Name: salario, dtype: object

# %% [markdown]
# Por supuesto, es posible aplicar los métodos sobre todo el dataframe, lo que nos devolverá el resultado de aquellas columnas que sean numéricas.

# %%
df.median()
# Out:
# <ipython-input-18-6d467abf240d>:1: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.median()
# edad          42.0
# salario    37500.0
# dtype: float64

# %%
df.describe()
# Out:
#             edad
# count   8.000000
# mean   44.875000
# std    18.946824
# min    19.000000
# 25%    33.250000
# 50%    42.000000
# 75%    56.500000
# max    73.000000

# %% [markdown]
# > El método `count()` cuenta las celdas que no son numéricas en cada columna o fila.
#
# Otra vez, aplicamos este método en una columna concreta.
#
# Más info en [Pandas](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.count.html).

# %%
df['casado'].count()
# Out:
# 8

# %% [markdown]
# > El método `value_counts()` devuelve una *Series* que contiene la frecuencia de cada fila distinta del Dataframe.
#
# Para saber cuantos contestaron *Yes* y cuantos *No* en la columna "*casado*" usamos este método.
#
# Más info en [Pandas](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.value_counts.html#pandas.DataFrame.value_counts).

# %%
df['casado'].value_counts()
# Out:
# Yes    4
# No     3
# NaN    1
# Name: casado, dtype: int64

# %% [markdown]
# Si queremos ver cual es la ciudad mas comun en nuestro dataframe:

# %%
df['ciudad'].value_counts()
# Out:
# Madrid      4
# Valencia    1
# Malaga      1
# Cadiz       1
# Burgos      1
# Name: ciudad, dtype: int64

# %% [markdown]
# Si queremos ver los resultados anteriores pero en porcentajes usaremos el parámetro `normalize=True` en el método `value_counts()`.

# %%
df['ciudad'].value_counts(normalize=True)
# Out:
# Madrid      0.500
# Valencia    0.125
# Malaga      0.125
# Cadiz       0.125
# Burgos      0.125
# Name: ciudad, dtype: float64

# %% [markdown]
# Vamos a ver otras métodos de agregacion como son `groupby()` y `get_group()`
#
# > El método `groupby()` agrupa el DataFrame usando un mapeador o a través de una *Series* de columnas.
#
# > El método `get_group()` construye un DataFrame a partir de un grupo con el nombre proporcionado. *Este método ya no se usa a partir de la versión 2.1.0 de Pandas*.

# %%
df.groupby(['ciudad'])

# %%
ciudad_grupo=df.groupby(['ciudad'])

# %% [markdown]
# Si queremos que nos agregue toda la informacion que tiene la ciudad Madrid, podemos usar el método `get_group()` y le pasamos como parámetro la columna a agrupar.

# %%
ciudad_grupo.get_group('Madrid')
# Out:
#   nombre  apellido                    email  edad salario  ciudad casado
# 0  Marta      Ruiz      martaruiz@gmail.com    35   20000  Madrid    Yes
# 5    Ana     Perez      saraperez@gmail.com    67   65000  Madrid    Yes
# 6  Rocio  Iglesias  rocioiglesias@gmail.com    73   83000  Madrid    Yes
# 7   Pepe   Fuentes    pepefuentes@gmail.com    19   97000  Madrid     No

# %% [markdown]
# Deberiamos obtener el mismo resultado creando una variable `filt` como hicimos anteriormente.

# %%
filt = df['ciudad'] == 'Madrid'
df.loc[filt]
# Out:
#   nombre  apellido                    email  edad salario  ciudad casado
# 0  Marta      Ruiz      martaruiz@gmail.com    35   20000  Madrid    Yes
# 5    Ana     Perez      saraperez@gmail.com    67   65000  Madrid    Yes
# 6  Rocio  Iglesias  rocioiglesias@gmail.com    73   83000  Madrid    Yes
# 7   Pepe   Fuentes    pepefuentes@gmail.com    19   97000  Madrid     No

# %% [markdown]
# Si del grupo anterior solo nos interesa ahora saber los salarios que algunas personas ganan en Madrid usaremos el método `value_counts()` y la propiedad `loc`.

# %%
filt = df['ciudad'] == 'Madrid'
df.loc[filt]['salario'].value_counts()
# Out:
# 20000    1
# 65000    1
# 83000    1
# 97000    1
# Name: salario, dtype: int64

# %% [markdown]
# Ahora queremos saber cuantas personas de Madrid tienen la letra "Y" en la respuesta sobre si estan casados o no. Para ello, usamos el método de Series `contains()` y la funcion `sum()`.

# %%
filt=df['ciudad']== 'Madrid'
df.loc[filt]['casado'].str.contains('Y').sum()
# Out:
# 3

# %% [markdown]
# Si queremos ver cuantas personas tienen la letra 'o' en su respuesta, sería de la siguiente manera:

# %%
filt=df['ciudad']== 'Madrid'
df.loc[filt]['casado'].str.contains('o').sum()
# Out:
# 1

# %% [markdown]
# Si queremos ver cuantas personas en la ciudad de Madrid tienen la letra 'u' en su apellido

# %%
filt=df['ciudad']== 'Madrid'
df.loc[filt]['apellido'].str.contains('u').sum()
# Out:
# 2

# %% [markdown]
# En esta ocasión, vamos a mostrar en pantalla los nombres de las personas de Madrid cuyos apellidos contienen una letra 'i'.

# %%
filt = (df['ciudad'] == 'Madrid') & df['apellido'].str.contains('I', case=False)
nombre_filtro = df.loc[filt, 'nombre']
nombre_filtro
# Out:
# 0    Marta
# 6    Rocio
# Name: nombre, dtype: object

# %% [markdown]
# Y ahora mostramos en pantalla los nombres de las personas de Madrid cuyos apellidos contienen una letra 'i' y tambien tienen mas de 50 años.
#
# > *Recordemos que en la variable `filt` se guardaran los resultados booleanos del filtro que hemos creado, y luego usamosla variable el la propiedad `loc`*.

# %%
filt = (df['ciudad'] == 'Madrid') & (df['edad']>50) & df['apellido'].str.contains('I', case=False)
nombre_filtro = df.loc[filt, 'nombre']
nombre_filtro
# Out:
# 6    Rocio
# Name: nombre, dtype: object

# %% [markdown]
# ### <u>***UNIDAD 9. LIMPIEZA DE DATOS***</u>

# %% [markdown]
# Volvemos a crear un datframe a partir de un diccionario.

# %%
gentelimp={
    'nombre': ['Marta', 'Luis', 'Ana', 'Andres', None, 'Ana'],
    'apellido': ['Ruiz', 'Lopez', 'Santana', None, 'Castro', 'Perez'],
    'email': ['martaruiz@gmail.com', 'luislopez@gmail.com', 'anasantana@gmail.com', 'andreslopez@gmail.com', None, 'saraperez@gmail.com'],
    'edad': [35, 28, 35, 49, 53, 67],
    'salario': [20000, 25000, None, 17000, 20000, 65000],
    'ciudad' :['Madrid', 'Valencia', 'Malaga', 'Cadiz', 'Burgos', None],
    'casado': ['Yes', 'No', 'Yes', 'No', None, None]
}

# %%
df=pd.DataFrame(gentelimp)

df
# Out:
#    nombre apellido                  email  edad  salario    ciudad casado
# 0   Marta     Ruiz    martaruiz@gmail.com    35  20000.0    Madrid    Yes
# 1    Luis    Lopez    luislopez@gmail.com    28  25000.0  Valencia     No
# 2     Ana  Santana   anasantana@gmail.com    35      NaN    Malaga    Yes
# 3  Andres     None  andreslopez@gmail.com    49  17000.0     Cadiz     No
# 4    None   Castro                   None    53  20000.0    Burgos   None
# 5     Ana    Perez    saraperez@gmail.com    67  65000.0      None   None

# %% [markdown]
# Algunas veces lo mejor es eliminar las filas que contienen
# datos sucios o faltantes.
#
# Para ello, vamos a usar los métodos `dropna()`
# y `drop()` (suprimir).
#
# El "na" significa "not available" o "no disponible".
#
# > El método `dropna()` elimina los valores que faltan o "na". Mas info en [Pandas](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.dropna.html).
#
# > El método `drop()` elimina etiquetas especificadas de filas o columnas. Mas info en [Pandas](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.drop.html).

# %%
df.dropna()
# Out:
#   nombre apellido                email  edad  salario    ciudad casado
# 0  Marta     Ruiz  martaruiz@gmail.com    35  20000.0    Madrid    Yes
# 1   Luis    Lopez  luislopez@gmail.com    28  25000.0  Valencia     No

# %% [markdown]
# Para entender como funciona el método `dropna()` vamos a usar una sintaxis
# mas completa y vemos que nos da el mismo resultado que antes.
#
# >El parámetro `axis` puede ser igual al valor `=index` para referirse a filas o al valor `=columns` para referirse a columnas.
# >
# >El parámetro `how` determinar si la fila o columna se elimina de DataFrame, cuando tenemos al menos un NA o todos los NA. Los valores pueden ser:
# +   `=any`, es decir, con que haya una sola celda con `None` elimina toda
#  la fila o columna.
# +   `=all` en cuyo caso solo elimina la fila o la columna si todas las celdas tienen `None`.
#
# A continuación,veamos varios ejemplos del método `dropna`:

# %%
df.dropna(axis='index', how='any')
# Out:
#   nombre apellido                email  edad  salario    ciudad casado
# 0  Marta     Ruiz  martaruiz@gmail.com    35  20000.0    Madrid    Yes
# 1   Luis    Lopez  luislopez@gmail.com    28  25000.0  Valencia     No

# %%
df.dropna(axis='columns', how='any')
# Out:
#    edad
# 0    35
# 1    28
# 2    35
# 3    49
# 4    53
# 5    67

# %%
df.dropna(axis='index', how='all')
# Out:
#    nombre apellido                  email  edad  salario    ciudad casado
# 0   Marta     Ruiz    martaruiz@gmail.com    35  20000.0    Madrid    Yes
# 1    Luis    Lopez    luislopez@gmail.com    28  25000.0  Valencia     No
# 2     Ana  Santana   anasantana@gmail.com    35      NaN    Malaga    Yes
# 3  Andres     None  andreslopez@gmail.com    49  17000.0     Cadiz     No
# 4    None   Castro                   None    53  20000.0    Burgos   None
# 5     Ana    Perez    saraperez@gmail.com    67  65000.0      None   None

# %% [markdown]
# En el siguiente snippet, vamos a eliminar filas o columnas que no tengan emails ya que consideramos imprescindible que tengan el email como minimo.
#
# Por tanto, vamos a usar otro parametro que se llama `subset` cuyo valor es el nombre de la columna a tener en cuenta, pasado como una lista.

# %%
df.dropna(axis='index', how='any', subset = ['email'])
# Out:
#    nombre apellido                  email  edad  salario    ciudad casado
# 0   Marta     Ruiz    martaruiz@gmail.com    35  20000.0    Madrid    Yes
# 1    Luis    Lopez    luislopez@gmail.com    28  25000.0  Valencia     No
# 2     Ana  Santana   anasantana@gmail.com    35      NaN    Malaga    Yes
# 3  Andres     None  andreslopez@gmail.com    49  17000.0     Cadiz     No
# 5     Ana    Perez    saraperez@gmail.com    67  65000.0      None   None

# %% [markdown]
# Al pasar los valores como una lista en el parámetro `subset`, podemos pasarle varias columnas a este parámetro.

# %%
df.dropna(axis='index', how='any', subset = ['email', 'casado'])
# Out:
#    nombre apellido                  email  edad  salario    ciudad casado
# 0   Marta     Ruiz    martaruiz@gmail.com    35  20000.0    Madrid    Yes
# 1    Luis    Lopez    luislopez@gmail.com    28  25000.0  Valencia     No
# 2     Ana  Santana   anasantana@gmail.com    35      NaN    Malaga    Yes
# 3  Andres     None  andreslopez@gmail.com    49  17000.0     Cadiz     No

# %% [markdown]
# Si tanto la columna "*email*" como la columna "*casado*" tiene que ser `None` entonces usaremos el parámetro `how='all'`.

# %%
df.dropna(axis='index', how='all', subset = ['email', 'casado'])
# Out:
#    nombre apellido                  email  edad  salario    ciudad casado
# 0   Marta     Ruiz    martaruiz@gmail.com    35  20000.0    Madrid    Yes
# 1    Luis    Lopez    luislopez@gmail.com    28  25000.0  Valencia     No
# 2     Ana  Santana   anasantana@gmail.com    35      NaN    Malaga    Yes
# 3  Andres     None  andreslopez@gmail.com    49  17000.0     Cadiz     No
# 5     Ana    Perez    saraperez@gmail.com    67  65000.0      None   None

# %% [markdown]
# Volvemos a inicializar nuestro dataframe, creándolo de nuevo.

# %%
gentelimp2={
    'nombre': ['Marta', 'Luis', 'Ana', 'Andres', None, 'Ana'],
    'apellido': ['Ruiz', 'Lopez', 'Santana', None, 'Castro', 'Perez'],
    'email': ['martaruiz@gmail.com', 'luislopez@gmail.com', 'anasantana@gmail.com', 'andreslopez@gmail.com', None, 'saraperez@gmail.com'],
    'edad': ['35', '28', '35', '49', '53', '67'],
    'salario': [20000, 25000, None, 17000, 20000, 65000],
    'ciudad' :['Madrid', 'Valencia', 'Malaga', 'Cadiz', 'Burgos', None],
    'casado': ['Yes', 'No', 'Yes', 'No','Missing', None]
}

# %%
df=pd.DataFrame(gentelimp2)

df
# Out:
#    nombre apellido                  email edad  salario    ciudad   casado
# 0   Marta     Ruiz    martaruiz@gmail.com   35  20000.0    Madrid      Yes
# 1    Luis    Lopez    luislopez@gmail.com   28  25000.0  Valencia       No
# 2     Ana  Santana   anasantana@gmail.com   35      NaN    Malaga      Yes
# 3  Andres     None  andreslopez@gmail.com   49  17000.0     Cadiz       No
# 4    None   Castro                   None   53  20000.0    Burgos  Missing
# 5     Ana    Perez    saraperez@gmail.com   67  65000.0      None     None

# %% [markdown]
# Si queremos substituir los valores '*Missing*' (faltantes) y los '*NA*' por el valor `None` lo podemos hacer usando el método de la clase Dataframe en Pandas `replace()`.
#
# Este método admite cambiar un valor que sea numérico o string por otro de estos tipos, ademas del tipo None o NaN.
#
# > *Recordemos que si no aplicamos el parámetro `inplace=True` a estos métodos, los cambios no se harán efectivos en el dataframe y solo te mostrará una imagen de como quedaría el dataframe si le aplicas el método.*
# >
# > *Una buena práctica es ejecutar los métodos sin este parámetro, para ver cómo quedaría el dataframe y cuando veamos que el resultado es el esperado, volvemos a ejecutar el método pertinente con el parámetro `inplace`.*
#
# Mas info del método en [Pandas](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.replace.html).

# %%
df.replace('Missing', None, inplace=True)

# %% [markdown]
# Sin embargo, si queremos cambiar un valor None o NaN por un tecto o un valor numérico, deberemos usar el método `fillna()`.

# %%
df.fillna('Nulo', inplace=True)

# %% [markdown]
# Vemos como queda el dataframe con los cambios anteriores.

# %%
df
# Out:
#    nombre apellido                  email edad  salario    ciudad casado
# 0   Marta     Ruiz    martaruiz@gmail.com   35  20000.0    Madrid    Yes
# 1    Luis    Lopez    luislopez@gmail.com   28  25000.0  Valencia     No
# 2     Ana  Santana   anasantana@gmail.com   35     Nulo    Malaga    Yes
# 3  Andres     Nulo  andreslopez@gmail.com   49  17000.0     Cadiz     No
# 4    Nulo   Castro                   Nulo   53  20000.0    Burgos   Nulo
# 5     Ana    Perez    saraperez@gmail.com   67  65000.0      Nulo   Nulo

# %% [markdown]
# Si queremos ver que celdas tienen datos faltantes o extraños podemos usar el método `isna()`. El resutado será el valor booleano de todos los valores del dataframe en relación a si tienen datos faltantes o no.

# %%
df.isna()
# Out:
#    nombre  apellido  email   edad  salario  ciudad  casado
# 0   False     False  False  False    False   False   False
# 1   False     False  False  False    False   False   False
# 2   False     False  False  False    False   False   False
# 3   False     False  False  False    False   False   False
# 4   False     False  False  False    False   False   False
# 5   False     False  False  False    False   False   False

# %% [markdown]
# Si queremos llenar los valores `None` (que previamente, hemos cambiado con el método `replace`, sin olvidar el parámetro `inplace=True`), con algun tipo de datos, por ejemplo, con NO SABE NO CONTESTA (NSNC), usaremos el método `fillna()`.
#
# > El método `fillna()` rellena los valores NA/NaN con el valor que le indiquemos, como parámetro.
#
# Mas info en [Pandas](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.fillna.html).

# %%
df.fillna('NSNC')
# Out:
#    nombre apellido                  email edad  salario    ciudad casado
# 0   Marta     Ruiz    martaruiz@gmail.com   35  20000.0    Madrid    Yes
# 1    Luis    Lopez    luislopez@gmail.com   28  25000.0  Valencia     No
# 2     Ana  Santana   anasantana@gmail.com   35     Nulo    Malaga    Yes
# 3  Andres     Nulo  andreslopez@gmail.com   49  17000.0     Cadiz     No
# 4    Nulo   Castro                   Nulo   53  20000.0    Burgos   Nulo
# 5     Ana    Perez    saraperez@gmail.com   67  65000.0      Nulo   Nulo

# %% [markdown]
# Otra cosa que podemos hacer es ver si nuestras celdas tienen un "*string*" o un "*integer*", es decir, queremos saber el tipo de dato.
#
# Recordemos que `object` es lo mismo que "*string*" en Pandas.

# %%
df.dtypes
# Out:
# nombre      object
# apellido    object
# email       object
# edad        object
# salario     object
# ciudad      object
# casado      object
# dtype: object

# %% [markdown]
# > El método `astype()` convierte un objeto (object) Pandas a un tipo (dtype) especificado y viceversa.

# %%
df['edad']=df['edad'].astype(int)

# %%
# Podiamos haberlo cambiado a un float tambien.
# df['edad']=df['edad'].astype(float)

df.dtypes
# Out:
# nombre      object
# apellido    object
# email       object
# edad         int64
# salario     object
# ciudad      object
# casado      object
# dtype: object

# %% [markdown]
# Y ahora podemos calcular la media de la columna "*edad*" del dataframe.

# %%
df['edad'].mean()
# Out:
# 44.5

# %% [markdown]
# Existe otro método llamado `unique()` para saber cuantos diferentes tipos de valores puede tener una columna.
#
# > La función `unique()` devuelve los valores únicos de una columna.
# >
# > Mas info en [Pandas](https://pandas.pydata.org/docs/reference/api/pandas.unique.html).
#
# En el siguiente snippet, vamos a verlo para la columna "*casado*".

# %%
df['casado'].unique()
# Out:
# array(['Yes', 'No', 'Nulo'], dtype=object)
